# %%
from ultralytics import YOLO
from ultralytics.utils.plotting import Annotator

# %%
model = YOLO("yolov8n.pt")
# Out:
# ...
# 100%|██████████| 6.25M/6.25M [00:00<00:00, 7.29MB/s]

# %%
import cv2
import urllib.parse
import time
import datetime
import os

def unv_url(username, password, ip, port, channel,start_time, end_time):
    encoded_password = urllib.parse.quote(password)

    rtsp_url = (f"rtsp://{username}:{encoded_password}@{ip}:{port}/"
                f"c{channel}/b{start_time}/e{end_time}/replay/")
    
    print(f"Connecting to recorded video at {start_time}")
    print(f"URL: {rtsp_url}")
    return rtsp_url

def datetime_to_unix_timestamp(dt):
    """
    Convert a datetime object to a Unix timestamp (seconds since Jan 1, 1970 UTC).
    
    Parameters:
    dt (datetime): The datetime object to convert
    
    Returns:
    int: Unix timestamp (seconds since epoch)
    """
    # Convert datetime to Unix timestamp (seconds since Jan 1, 1970)
    # The timestamp() method returns a float, so we convert to int if needed
    return int(dt.timestamp())

# Example usage
if __name__ == "__main__":
    username = "admin"
    password = "rmc@12345"  # Password with @ symbol
    ip = "103.168.199.92"
    port = "554"
    channel = 1       # Use your specific channel number
    stream_type = 0  # 0 for main stream
    
    # Specify the date and time you want to view
    start_time = datetime.datetime(2025, 3, 1, 6, 15, 0)  # March 10, 2025, 2:00 PM
    end_time = datetime.datetime(2025, 3, 1, 7, 0, 0)  # March 10, 2025, 2:00 PM
    start_time_stamp = datetime_to_unix_timestamp(start_time)
    end_time_Stamp = datetime_to_unix_timestamp(end_time)
    print(f"s - {start_time_stamp}")
    print(f"e- {end_time_Stamp}")
    url = unv_url(username,password,ip,port,channel,start_time_stamp,end_time_Stamp)
    print(f"URL -{url}")
# Out:
# s - 1740789900
# e- 1740792600
# Connecting to recorded video at 1740789900
# URL: rtsp://admin:rmc%4012345@103.168.199.92:554/c1/b1740789900/e1740792600/replay/
# URL -rtsp://admin:rmc%4012345@103.168.199.92:554/c1/b1740789900/e1740792600/replay/

# %%
# import cv2
# import os
# from ultralytics import YOLO
# import numpy as np

# def save_first_frame_with_person(video_path, output_folder="final_Frame", conf_threshold=0.5):
#     os.makedirs(output_folder, exist_ok=True)
#     model = YOLO("yolov8n.pt")  # Load YOLOv8 model

#     cap = cv2.VideoCapture(video_path)
#     frame_count = 0
#     saved_frame = False

#     while cap.isOpened():
#         ret, frame = cap.read()
#         if not ret:
#             break  # Exit if no frame is captured

#         frame_count += 1

#         # Run YOLO detection
#         results = model(frame, verbose=False)

#         for result in results:
#             boxes = result.boxes
#             for box in boxes:
#                 cls = int(box.cls.item())
#                 conf = box.conf.item()

#                 if cls == 0 and conf > conf_threshold:  # Class 0 = Person
#                     full_frame = frame.copy()
#                     full_frame_path = os.path.join(output_folder, "first_detection_full_frame.jpg")
#                     cv2.imwrite(full_frame_path, full_frame)

#                     saved_frame = True
#                     break  # Exit after finding the first person

#             if saved_frame:
#                 break

#         # Display the video frame
#         cv2.imshow("Live Video", frame)

#         # Exit when 'q' is pressed
#         if cv2.waitKey(1) & 0xFF == ord('q'):
#             break

#         if saved_frame:
#             break  # Stop after first detection

#     cap.release()
#     cv2.destroyAllWindows()  # Close video window

#     if not saved_frame:
#         print("No person detected in the video.")
#     else:
#         print(f"Processed {frame_count} frames before detection.")

# # Use RTSP or video file path
# video_path = url # Replace with your RTSP URL or video file path
# save_first_frame_with_person(video_path)

# %%
# final
import cv2
import os
from ultralytics import YOLO
import numpy as np

def save_first_frame_with_person(video_path, output_folder="final_Frame", conf_threshold=0.5):
    os.makedirs(output_folder, exist_ok=True)
    model = YOLO("yolov8n.pt")


    cap = cv2.VideoCapture(video_path)
    frame_count = 0
    saved_frame = False

    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            break

        frame_count += 1

        results = model(frame, verbose=False)


        for result in results:
            boxes = result.boxes
            for box in boxes:
                cls = int(box.cls.item())
                conf = box.conf.item()

                if cls == 0 and conf > conf_threshold:
                    full_frame = frame.copy()
                    full_frame_path = os.path.join(output_folder, "first_detection_full_frame.jpg")
                    cv2.imwrite(full_frame_path, full_frame)

                    saved_frame = True
                    break  

            if saved_frame:
                break

        if saved_frame:
            break

    cap.release()

    if not saved_frame:
        print("No person detected in the video.")
    else:
        print(f"Processed {frame_count} frames before detection.")


video_path = url
save_first_frame_with_person(video_path)
# Out:
# [rtsp @ 0x568a3f9882c0] getaddrinfo(): Name or service not known
# [rtsp @ 0x568a3f9882c0] getaddrinfo(): Name or service not known
# [rtsp @ 0x568a3f9882c0] Illegal combination of S and E bit in RTP/HEVC packet
# [rtsp @ 0x568a3f9882c0] Illegal combination of S and E bit in RTP/HEVC packet
# [rtsp @ 0x568a3f9882c0] Illegal combination of S and E bit in RTP/HEVC packet
# [rtsp @ 0x568a3f9882c0] Illegal combination of S and E bit in RTP/HEVC packet
# [rtsp @ 0x568a3f9882c0] Illegal combination of S and E bit in RTP/HEVC packet
# [rtsp @ 0x568a3f9882c0] Illegal combination of S and E bit in RTP/HEVC packet
# [rtsp @ 0x568a3f9882c0] Illegal combination of S and E bit in RTP/HEVC packet
# [rtsp @ 0x568a3f9882c0] Illegal combination of S and E bit in RTP/HEVC packet
# [rtsp @ 0x568a3f9882c0] Illegal combination of S and E bit in RTP/HEVC packet
# [rtsp @ 0x568a3f9882c0] Illegal combination of S and E bit in RTP/HEVC packet
# ...

# %%
import easyocr
import cv2
import re
from datetime import datetime, timedelta
import json


class object:

  def timining(self,start_time_str,m1=None,m2=None):
    # start_time_str = "07:00:00"
    start_time = datetime.strptime(start_time_str, "%H:%M:%S")


    before_30mins = start_time - timedelta(minutes=30)
    print(before_30mins)


    time_before_30mins_str = before_30mins.strftime("%H:%M:%S")
    print("",time_before_30mins_str)

    time_before_30mins_variable = time_before_30mins_str

    # print(f"30 minutes before start time: {time_before_30mins_variable}")
    return time_before_30mins_variable



  # def person_enter(self,image_path):
  #     # image_path = '/content/final_Frame/first_detection_full_frame.jpg'
  #     # self.start_time =  self.timining("07:00:00")
  #     image = cv2.imread(image_path)


  #     gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)


  #     _, thresh = cv2.threshold(gray, 150, 255, cv2.THRESH_BINARY)


  #     cv2.imwrite('preprocessed_image.png', thresh)

  #     reader = easyocr.Reader(['en'])


  #     results = reader.readtext('preprocessed_image.png')


  #     time_pattern = re.compile(r'\b\d{2}:\d{2}:\d{2}\b')




  #     for (bbox, text, prob) in results:
  #         # print(text)
  #         time_match = time_pattern.search(text)
  #         if time_match:
  #           print('--',time_match)
  #           print(f"Extracted Time: {time_match.group()}")
  #           self.entry_time = time_match.group()
  #           return self.entry_time

  def timining(self,start_time_str):
    # start_time_str = "07:00:00"
    start_time = datetime.strptime(start_time_str, "%H:%M:%S")


    before_30mins = start_time - timedelta(minutes=30)
    print(before_30mins)


    time_before_30mins_str = before_30mins.strftime("%H:%M:%S")
    print("",time_before_30mins_str)

    time_before_30mins_variable = time_before_30mins_str

    # print(f"30 minutes before start time: {time_before_30mins_variable}")
    return time_before_30mins_variable

# %%
def timining(start_time_str= "07:00:00"):
# start_time_str = "07:00:00"
    start_time = datetime.strptime(start_time_str, "%H:%M:%S")


    before_30mins = start_time - timedelta(minutes=30)



    time_before_30mins_str = before_30mins.strftime("%H:%M:%S")


    return type(time_before_30mins_str)

# %%
timining()
# Out:
# str

# %%
o = object()
o.timining("07:00:00")
# Out:
# 1900-01-01 06:30:00
#  06:30:00
# '06:30:00'

# %%
with open('extract_date.josn','a+') as f:
    json.dumps(f)

# %%
o = object()

# %%
o.person_enter('/home/hepl/Desktop/New Folder/Keerthanaa/Keerthii/MAR/VA_research_task/NCS/NC_00/final_Frame/first_detection_full_frame.jpg')
# Out:
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.

# %%
n = "12-02-2025"
m = "09:02:00"

mn = n+" "+n

# %%
from datetime import datetime


date_obj = datetime.strptime(mn, '%d-%m-%Y %H:%M:%S')

print(date_obj)

# %%
(mn)
# Out:
# '12-02-2025 12-02-2025'

# %%
datetime(mn)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 datetime(mn)
#
# TypeError: 'str' object cannot be interpreted as an integer

# %%
def save_first_frame_with_person(self, username, password, ip, port, channel,
                                 start_time, end_time, formatted_date, output_folder, conf_threshold=0.9):
    print("#####################")
    os.makedirs(output_folder, exist_ok=True)
    model = YOLO("yolov8n.pt")

    # Adjust stream time until available
    while True:
        start_time_stamp = self.datetime_to_unix_timestamp(start_time)
        end_time_stamp = self.datetime_to_unix_timestamp(end_time)

        video_path = self.unv_url(username, password, ip, port, channel, start_time_stamp, end_time_stamp)
        cap = cv2.VideoCapture(video_path)

        if not cap.isOpened():
            print(f"Stream not available for {start_time.strftime('%H:%M:%S')}, trying next second...")
            start_time += timedelta(seconds=1)
            cap.release()
        else:
            print(f"Stream available at {start_time.strftime('%H:%M:%S')}")
            break

    frame_count = 0
    saved_frame = False

    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            break

        frame_count += 1
        results = model(frame, verbose=False)
        for result in results:
            boxes = result.boxes
            for box in boxes:
                cls = int(box.cls.item())
                conf = box.conf.item()
                xyxy = box.xyxy[0].cpu().numpy().astype(int)

                if cls == 0 and conf > conf_threshold:
                    full_frame = frame.copy()
                    cv2.rectangle(full_frame, (xyxy[0], xyxy[1]), (xyxy[2], xyxy[3]), (0, 255, 0), 2)
                    cv2.putText(full_frame, f"Person {conf:.2f}", (xyxy[0], xyxy[1] - 10),
                                cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)

                    full_frame_path = os.path.join(output_folder, f"{formatted_date}.jpg")
                    cv2.imwrite(full_frame_path, full_frame)

                    saved_frame = True
                    break

            if saved_frame:
                break

        if saved_frame:
            break

    cap.release()

    if not saved_frame:
        print("No person detected in the video.")
        return "No person detected in the video."
    else:
        return f"Processed {frame_count} frames before detection."

# %%
if o.person_enter == o.start_time:
  print('yes')
else:print('NO')

# %%
import cv2
import os
import numpy as np
import easyocr
import re
from datetime import datetime, timedelta
import json

def person_enter(image_path):
    image = cv2.imread(image_path)

    # if image is None:
    #     print("Error: Image not found.")
    #     return None
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    _, thresh = cv2.threshold(gray, 150, 255, cv2.THRESH_BINARY)
    cv2.imwrite('preprocessed_image.png', thresh)

    reader = easyocr.Reader(['en'])
    results = reader.readtext('preprocessed_image.png')
    time_pattern = re.compile(r'\b\d{2}:\d{2}:\d{2}\b')

    for (bbox, text, prob) in results:
        # print(text)
        time_match = time_pattern.search(text)
        if time_match:
            print('--',time_match)
            print(f"Extracted Time: {time_match.group()}")
            entry_time = time_match.group()
            print(entry_time)
            return entry_time

# %%
import easyocr
import re
import os
import cv2

def person_enter(image_path):
        if not os.path.isfile(image_path):
            raise FileNotFoundError(f"Image file not found: {image_path}")
        reader = easyocr.Reader(['en'])
        
        img = cv2.imread(image_path)
        if img is None:
            raise ValueError(f"Unable to read image: {image_path}")
        results = reader.readtext(img, detail=0, 
                                allowlist='0123456789:/-APMapm')
        text = " ".join(results)
        print(results)
        time_patterns = r'\b\d{2}\s*[:.]\d{2}\s*[:.]\d{2}\b' # ISO format date + time


        matches = re.search(time_patterns, text)
        if matches:
            print(f"Found Time stamp on image -{matches.group()}")
            return matches.group()
        
        raise ValueError("No timestamp pattern detected in the image")

# %%
person_enter("/home/hepl/Downloads/test26-04-2025.jpg")
# Out:
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# ['26/04/202506:38:46', 'pPPA', '13434m1A6:17A', 'M:a:aa:aa:9maa130Paa10311a:a1Pa:', 'pmaam-aa6083']
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 person_enter("/home/hepl/Downloads/test26-04-2025.jpg")
#
# Cell In[8], line 26, in person_enter(image_path)
#      23     print(f"Found Time stamp on image -{matches.group()}")
#      24     return matches.group()
# ---> 26 raise ValueError("No timestamp pattern detected in the image")
#
# ValueError: No timestamp pattern detected in the image

# %%
# !pip install easyocr==1.7.2
# Out:
# ...
#   Using cached easyocr-1.7.2-py3-none-any.whl.metadata (10 kB)
# ...
# Using cached easyocr-1.7.2-py3-none-any.whl (2.9 MB)
# ...
#
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: pip install --upgrade pip

# %%
import os
import glob

# %%
import cv2
import easyocr
import re
def extract_timestamp_from_image(image_path):
        reader = easyocr.Reader(['en'])
        
        img = cv2.imread(image_path)

        results = reader.readtext(img, detail=0, 
                                allowlist='0123456789:/-APMapm')
        text = " ".join(results)
        # print(results)
        time_patterns = [
            r'(\d{1,2}:\d{2}:\d{2})', # HH:MM:SS
            r'(\d{1,2}:\d{2}(:\d{2})?\s*[APap][Mm])', # HH:MM:SS AM/PM or HH:MM AM/PM
            r'(\d{1,2}[/-]\d{1,2}[/-]\d{2,4}\s+\d{1,2}:\d{2}(:\d{2})?)', # Date + time
            r'(\d{4}-\d{2}-\d{2}\s+\d{2}:\d{2}:\d{2})' # ISO format date + time
        ]
        for pattern in time_patterns:
            matches = re.search(pattern, text)
            if matches:
                print(f"Found Time stamp on image -{matches.group(1)}")
                return matches.group(1)
        
        raise ValueError("No timestamp pattern detected in the image")

# %%
extract_timestamp_from_image("/home/hepl/Downloads/test26-04-2025.jpg")
# Out:
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# Found Time stamp on image -06:38:46
# '06:38:46'

# %%
# import glob

# image_paths = glob.glob()
image_path = "/home/hepl/Desktop/New_Folder/Keerthanaa/Keerthii/MAR_2025/VA_research_task/NCS/NC_00/shift_02/PM/22-04-2025.jpg"
person_enter(image_path)
# Out:
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# ['22/04/2025', '17:30:017', '0AP', 'A:', '12487:30471MAA-71A271PAA', 'Ma:a:', '9a:aa:apma', '13', '0m', 'Paa32108', '1m', '0', ':a', '1PA', 'a', '1', 'a', '685', 'Pamaap-0590', 'Apaapa']
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[41], line 5
#       1 # import glob
#       2
#       3 # image_paths = glob.glob()
#       4 image_path = "/home/hepl/Desktop/New_Folder/Keerthanaa/Keerthii/MAR_2025/VA_research_task/NCS/NC_00/shift_02/PM/22-04-2025.jpg"
# ----> 5 person_enter(image_path)
#
# Cell In[38], line 25, in person_enter(image_path)
#      22     print(f"Found Time stamp on image -{matches.group()}")
#      23     return matches.group()
# ---> 25 raise ValueError("No timestamp pattern detected in the image")
#
# ...

# %%
easyocr.__version__
# Out:
# '1.7.2'

# %%
s = "abcdefgh"
z = len(s)//2

# %%
z
# Out:
# 4

# %%
if not True:
    print(1)

# %%
import cv2

import time

import os

import easyocr
import re

# %%
def person_enter(image_path):
    image = cv2.imread(image_path)

    # if image is None:
    #     print("Error: Image not found.")
    #     return None
    # gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    # _, thresh = cv2.threshold(gray, 150, 255, cv2.THRESH_BINARY)
    # cv2.imwrite('preprocessed_image.png', thresh)

    reader = easyocr.Reader(['en'])
    results = reader.readtext(image,detail=0,allowlist='0123456789:/-APMapm')
    # time_pattern = re.compile(r'\b\d{2}[:.]\d{2}[:.]\d{2}\b')
    time_pattern = r'(\b\d{2}\s*[:.]\d{2}\s*[:.]\d{2}\b)'


    for text in results:
        print(text)
        time_match = re.search(time_pattern,text)
        if time_match:
            print('--',time_match)
            print(f"Extracted Time: {time_match.group()}")
            entry_time = time_match.group()
            print(entry_time)
            return entry_time

# %%
a = person_enter('/home/hepl/Desktop/New_Folder/Keerthanaa/Keerthii/MAR_2025/VA_research_task/NCS/NC_00/shift_2/PM/29-03-2025.jpg')
# Out:
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# 29/03/202516:07:45
# 0AP
# A:
# 182487:4AP:MAA-71A271PA1
# Mp:a:
# 9a:a-:pmm2
# 13
# 01
# Paa32108
# 1m
# 0
# :a
# 1PA
# a
# 1
# Pamaam-089
# M01

# %%
person_enter("/home/hepl/Downloads/test26-04-2025.jpg")
# Out:
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# 26/04/202506:38:46
# pPPA
# 13434m1A6:17A
# M:a:aa:aa:9maa130Paa10311a:a1Pa:
# pmaam-aa6083

# %%
print(a)
# Out:
# None

# %%
def extract_timestamp_from_image():
#         image_dir = 'person_entry_Frame'
#         image_path = os.path.join(image_dir,"29-03-2025.jpg")
#         if not os.path.isfile(image_path):
#             raise FileNotFoundError(f"Image file not found: {image_path}")
        reader = easyocr.Reader(['en'])
        
        img = cv2.imread('/home/hepl/Desktop/New_Folder/Keerthanaa/Keerthii/MAR_2025/VA_research_task/NCS/NC_00/shift_2/PM/29-03-2025.jpg')
        if img is None:
            raise ValueError(f"Unable to read image: {'/home/hepl/Desktop/New_Folder/Keerthanaa/Keerthii/MAR_2025/VA_research_task/NCS/NC_00/shift_2/PM/29-03-2025.jpg'}")
        results = reader.readtext(img, detail=0, 
                                allowlist='0123456789:/-APMapm')
        text = " ".join(results)
        # print(results)
        time_patterns = [
            # r'(\d{1,2}:\d{2}:\d{2})', # HH:MM:SS
            # r'(\d{1,2}:\d{2}(:\d{2})?\s*[APap][Mm])', # HH:MM:SS AM/PM or HH:MM AM/PM
            # r'(\d{1,2}[/-]\d{1,2}[/-]\d{2,4}\s+\d{1,2}:\d{2}(:\d{2})?)', # Date + time
            # r'(\d{4}-\d{2}-\d{2}\s+\d{2}:\d{2}:\d{2})' # ISO format date + time

            r'(\b\d{2}\s*[:.]\d{2}\s*[:.]\d{2}\b)'
        ]
        for pattern in time_patterns:
            matches = re.search(pattern, text)
            if matches:
                print(f"Found Time stamp on image -{matches.group(1)}")
                return matches.group(1)
        
        raise ValueError("No timestamp pattern detected in the image")

extract_timestamp_from_image()
# Out:
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[54], line 31
#      27                 return matches.group(1)
#      29         raise ValueError("No timestamp pattern detected in the image")
# ---> 31 extract_timestamp_from_image()
#
# Cell In[54], line 29, in extract_timestamp_from_image()
#      26         print(f"Found Time stamp on image -{matches.group(1)}")
#      27         return matches.group(1)
# ---> 29 raise ValueError("No timestamp pattern detected in the image")
#
# ValueError: No timestamp pattern detected in the image

# %%
def mm(image_path):
    image = cv2.imread(image_path)

    # if image is None:
    #     print("Error: Image not found.")
    # #     return None
    # gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    # _, thresh = cv2.threshold(gray, 150, 255, cv2.THRESH_BINARY)
    # cv2.imwrite('preprocessed_image.png', thresh)

    reader = easyocr.Reader(['en'])
    results = reader.readtext(image)
    time_pattern = re.compile(r'\b\d{2}:\d{2}.\d{2}\b')

    for (bbox, text, prob) in results:
        print(text)
        time_match = time_pattern.search(text)
        if time_match:
            print('--',time_match)
            print(f"Extracted Time: {time_match.group()}")
            entry_time = time_match.group()
            print(entry_time)
            return entry_time

# %%
mm("/home/hepl/Downloads/test26-04-2025.jpg")
# Out:
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# 26/04/2025 06,38 ,46
# pJVER ALL
# 3#t.4m tiN# T,ZRIt1
# llte' The factory mode is 0  Please log in to the IFC ad t
# broom_stick 0.83

# %%
a = mm('/home/hepl/Desktop/New_Folder/Keerthanaa/Keerthii/MAR_2025/VA_research_task/NCS/NC_00/shift_2/PM/29-03-2025.jpg')
# Out:
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# 29/03/2025 16:07:45
# -- <re.Match object; span=(11, 19), match='16:07:45'>
# Extracted Time: 16:07:45
# 16:07:45

# %%
print(a)
# Out:
# None

# %%
def m(ip):
    return ip

# %%
ip_address = {"Kannakurukai":"103.168.199.92", "kukudupatti":"38.188.181.29"}
m(ip_address["Kannakurukai"])
# Out:
# '103.168.199.92'

# %%
for i in range(len(s)):
    print(i)
    if i==z-1:
        j = s.partition(s[i])
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
# 6
# 7

# %%
j
# Out:
# ('abc', 'd', 'efgh')

# %%
p=["a",1,"b",2,"c",1,3,"d",2,4]

# output="abbcccdddddddd"

# %%
op = ""
l = []
o = ""
for i in p:
    if i == str(i):
        o =i
        continue
    else:
        z = o*i
        l.append(z)
        print(l)
        op = "".join(l)
# Out:
# ['a']
# ['a', 'bb']
# ['a', 'bb', 'c']
# ['a', 'bb', 'c', 'ccc']
# ['a', 'bb', 'c', 'ccc', 'dd']
# ['a', 'bb', 'c', 'ccc', 'dd', 'dddd']

# %%
op
# Out:
# 'abbcccccdddddd'

# %%
op = ""
l = []
o = ""
for i in range(len(p)):
    if p[i] == str(p[i]):
        o = p[i]
        continue
    else:
        if type(p[i]+1) == int:
            z = o*i
            l.append(z)
            print(l)
            op = "".join(l)

# %%
class c :
    def m(self):
        f = op()
        print(f)

def op():
    b = 10

# %%
o = c()
o.m()
# Out:
# None

# %%
class c:
    def m(self):
        b = op()  # Get b from op()
        print(b)

def op():
    b = 10
# Return b

obj = c()
obj.m()  # Output: 10
# Out:
# None

# %%
from datetime import datetime, timedelta

# %%
for i in range(25,26):
    start_time = datetime(2025, 3, i, 6,25, 0)  
    end_time = datetime(2025, 3, i, 7, 0, 0) 
    print(start_time) 
    formatted_date = start_time.strftime("%d-%m-%Y")
    timing = int(start_time.strftime("%S"))+1
    print((timing))
# Out:
# 2025-03-25 06:25:00
# 1

# %%
class object:
    def fun1():
        a = 10 

    def fun2():
        b =11
        print(b)
        return c 
def fun3():
    global c 
    c= 10

# %%
o = object()
v = o. fun2
print(v)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[71], line 3
#       1 o = object()
#       2 v = o. fun2
# ----> 3 print(list(v))
#
# TypeError: 'method' object is not iterable

# %%
start_time = datetime(2025, 3, i, 6,25, 1)  
start_time.second+1
# Out:
# 2

# %%
def main(_ip):
    obj = Process() 
    username = "admin"
    password = "rmc@12345"  
    ip = _ip
    port = "554"
    channel = 1       
    file_path = "extract_date.json"

    if not os.path.exists(file_path):
        with open(file_path, "w") as f:
            json.dump({}, f)

    try:
        with open(file_path, "r") as f:
            data_dict = json.load(f)
    except json.JSONDecodeError:
        data_dict = {}  

    for i in range(23, 32):
        start_time = datetime(2025, 3, i, 6, 25, 0)  
        end_time = datetime(2025, 3, i, 7, 0, 0)  
        formatted_date = start_time.strftime("%d-%m-%Y")
        print(f"***{formatted_date}***")

        while True:
            start_time_stamp = obj.datetime_to_unix_timestamp(start_time)
            end_time_stamp = obj.datetime_to_unix_timestamp(end_time)

            print(f"Trying start time: {start_time.strftime('%H:%M:%S')}")
            url = obj.unv_url(username, password, ip, port, channel, start_time_stamp, end_time_stamp)

            cap = cv2.VideoCapture(url)
            if cap.isOpened():
                print(f"Stream found at {start_time.strftime('%H:%M:%S')}")
                cap.release()
                break
            else:
                print(f"Stream not available for {start_time.strftime('%H:%M:%S')}, trying next second...")
                start_time += timedelta(seconds=1)

        video_path = url
        man_detect = obj.save_first_frame_with_person(video_path, formatted_date, str(start_time.second))
        print(man_detect)  
        print("Saved successfully")  

        try:
            if man_detect == "No person detected in the video.":
                print(f"{man_detect}======")
                data_dict[formatted_date] = "NaN"
            else:    
                try:
                    extract_date = obj.person_enter(f"final_Frame/{formatted_date}.jpg")
                    print(extract_date)
                    if extract_date:
                        data_dict[formatted_date] = extract_date
                        print(f"Data extracted for {formatted_date}: {extract_date}")
                    else:
                        data_dict[formatted_date] = "Failed to extract"
                        print(f"Failed to extract data for {formatted_date}")
                except Exception as e:
                    data_dict[formatted_date] = "person_enter function failed"
                    print(f"Error processing {formatted_date}: {e}")

        except Exception as e:
            print(e)        

        with open(file_path, "w") as f:
            json.dump(data_dict, f, indent=4)
    
    print("====Process done====")

# Example usage
if __name__ == "__main__":
    ip_address = {"Kannakurukai": "10.92", "kukudupatti": "38.29"}
    main(ip_address["Kannakurukai"])

# %%
start_time = datetime(2025, 3, 4, 6, 25, 0)  
start_time
# Out:
# datetime.datetime(2025, 3, 4, 6, 25)

# %%
from datetime import datetime

start_time = datetime(2025, 3, 4, 6, 25, 0)
s = f'{start_time.date()} 16:54:00'  
print(s)
# Out:
# (datetime.date(2025, 3, 4),) 16:54:00

# %%
from datetime import datetime

start_time = datetime(2025, 3, 4, 6, 25, 0)  
new_time = datetime.combine(start_time.date(), datetime.min.time()).replace(hour=16, minute=54, second=0)

print(new_time)  # Output: 2025-03-04 16:54:00
print(repr(new_time))  # Output: datetime.datetime(2025, 3, 4, 16, 54, 0)
# Out:
# 2025-03-04 16:54:00
# datetime.datetime(2025, 3, 4, 16, 54)

# %%
def m():
    return '122324'

import json

# %%
file_path = "t1.json"
if not os.path.exists(file_path):
    with open(file_path, "w") as f:
        json.dump({}, f)

try:
    with open(file_path, "r") as f:
        data_dict = json.load(f)
except json.JSONDecodeError:
    data_dict = {}  

for i in range(24, 32):
    start_time = datetime(2025, 3, i, 6, 25, 0)  
    end_time = datetime(2025, 3, i, 7, 0, 0)  
    n = m()
    q = m()
    formatted_date = start_time.strftime("%d-%m-%Y")
    end_1 = datetime(2025, 3, i, 16, 25, 0)
    end_2 = datetime(2025, 3, i, 17, 25, 0)
    data_dict[formatted_date]= 

    with open(file_path, "w") as f:
        json.dump(data_dict, f, indent=4)
# Out:
# ***24-03-2025***
# ***25-03-2025***
# ***26-03-2025***
# ***27-03-2025***
# ***28-03-2025***
# ***29-03-2025***
# ***30-03-2025***
# ***31-03-2025***

# %%
import pandas as pd
from datetime import datetime

df = pd.DataFrame()

# %%
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
start_time = datetime(2025, 3, 4, 6, 25, 0)  
end_time = datetime(2025, 3, 4, 7, 0, 0)  
formatted_date = start_time.strftime("%d-%m-%Y")
type(formatted_date)
# Out:
# str

# %%
print(str(formatted_date))
# Out:
# 04-03-2025

# %%
df['Date'] =f'{formatted_date}'

# %%
df
# Out:
# Empty DataFrame
# Columns: [Date]
# Index: []

# %%
ip_address = {"Kannakurukai":"103.168.199.92", "kukudupatti":"38.188.181.29"}

ip = ip_address['Kannakurukai']

# %%
ip
# Out:
# '103.168.199.92'

# %%
ip_address = {"Kannakurukai": "103.12", "kukudupatti": "329"}

ip = ip_address["Kannakurukai"]  # Value: "103.12"
key = next(k for k, v in ip_address.items() if v == ip)

print(type(key))  # Output: "Kannakurukai"
# Out:
# <class 'str'>

# %%
d = {}

# %%
d['date'] = f

# %%
d['am']= '0.9'

# %%
d
# Out:
# {}

# %%
from datetime import datetime

# %%
today = datetime.now()

# %%
print(today)
# Out:
# 2025-04-07 11:23:44.227099

# %%
import json
def main():
    file_path = "2.json"

    if not os.path.exists(file_path):
        with open(file_path, "w") as f:
            json.dump({}, f)

    try:
        with open(file_path, "r") as f:
            data_dict = json.load(f)
    except json.JSONDecodeError:
        data_dict = {}  

    for i in range(26, 27):
        start_time = datetime(2025, 3, i, 6, 0, 0)  
        end_time = datetime(2025, 3, i, 7, 0, 0)  

        env_startime = datetime(2025, 3, i, 15, 0, 20)  
        env_end_time = datetime(2025, 3, i, 17, 30, 0)  

        formatted_date = start_time.strftime("%d-%m-%Y")
        print(f"***{formatted_date}***")
        data_dict['Location'] = "K"
        data_dict['Date'] = formatted_date
        man_detect = '06.6'
        man_detect_2 = '18.0'

        print(man_detect) 
        print(man_detect_2) 
        print("Saved successfully")  

        am_value, pm_value = "NaN", "NaN"  

        if man_detect != "No person detected in the video.":
            try:
                extract_date = '09.6'
                am_value = extract_date if extract_date else "Failed to extract_1"
            except Exception as e:
                print(f"Error processing AM frame for {formatted_date}: {e}")
                am_value = "person_enter failed"

        if man_detect_2 != "No person detected in the video.":
            try:
                extract_date_2 = '19.0'
                pm_value = extract_date_2 if extract_date_2 else "Failed to extract_2"
            except Exception as e:
                print(f"Error processing PM frame for {formatted_date}: {e}")
                pm_value = "person_enter failed"
        # if formatted_date not in data_dict or not isinstance(data_dict[formatted_date], list):
        #         data_dict[formatted_date] = []

        data_dict['AM'] =am_value
        data_dict['PM'] =pm_value
        data_dict['createdAt'] = today.strftime("%Y-%m-%d %H:%M:%S")


        with open(file_path, "w") as f:
            json.dump(data_dict, f, indent=4)

# %%
main()
# Out:
# ***26-03-2025***
# 06.6
# 18.0
# Saved successfully

# %%
import json
import os
from datetime import datetime

def main():
    file_path = "2.json"

    # Ensure the file exists
    if not os.path.exists(file_path):
        with open(file_path, "w") as f:
            json.dump([], f)

    # Load existing data
    try:
        with open(file_path, "r") as f:
            data_list = json.load(f)
            if not isinstance(data_list, list):
                data_list = []  
    except json.JSONDecodeError:
        data_list = []

    today = datetime.now()

    for i in range(27, 28):
        formatted_date = datetime(2025, 3, i).strftime("%d-%m-%Y")
        print(f"***{formatted_date}***")

        man_detect = '06.6'
        man_detect_2 = '17:00:12'

        print(man_detect) 
        print(man_detect_2) 
        print("Saved successfully")  

        am_value, pm_value = "NaN", "NaN"  

        if man_detect != "No person detected in the video.":
            am_value = '06.6'

        if man_detect_2 != "No person detected in the video.":
            pm_value = '17:00:12'

        # Append new entry to existing data


        data_new = {
            'Location': "RK",
            'Date': formatted_date,
            'AM': am_value,
            'PM': pm_value,
            'createdAt': today.strftime("%Y-%m-%d %H:%M:%S")
        }
        data_list.append(data_new) 

    # Save updated data back to the file
    with open(file_path, "w") as f:
        json.dump(data_list, f, indent=4)

main()
# Out:
# ***27-03-2025***
# 06.6
# 17:00:12
# Saved successfully

# %%
earch_task/NCS/NC_00$ python3 nc_0_test.py
====Process done====
***24-03-2025***
Trying start time: 06:00:00
Connecting to recorded video at 1742776200
URL: rtsp://admin:rmc%4012345@103.168.199.92:554/c1/b1742776200/e1742779800/replay/
[rtsp @ 0x61ed55c5ccc0] getaddrinfo(): Name or service not known
[rtsp @ 0x61ed55c5ccc0] getaddrinfo(): Name or service not known
Stream found at 06:00:00
Trying start time: 15:00:20
Connecting to recorded video at 1742808620
URL: rtsp://admin:rmc%4012345@103.168.199.92:554/c1/b1742808620/e1742817600/replay/
[rtsp @ 0x61ed5bc63180] getaddrinfo(): Name or service not known
[rtsp @ 0x61ed5bc63180] getaddrinfo(): Name or service not known
Stream found at 15:00:20
#####################
[rtsp @ 0x61ed55d4a280] getaddrinfo(): Name or service not known
[rtsp @ 0x61ed55d4a280] getaddrinfo(): Name or service not known
[h264 @ 0x61ed559147c0] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x61ed559147c0] error while decoding MB 0 58, bytestream 10102
[h264 @ 0x61ed560e5980] error while decoding MB 82 66, bytestream -13
[h264 @ 0x61ed55958080] error while decoding MB 106 61, bytestream -6
[h264 @ 0x61ed559147c0] error while decoding MB 89 65, bytestream -10
[h264 @ 0x61ed579c9c00] error while decoding MB 50 22, bytestream -7
[h264 @ 0x61ed5be41440] left block unavailable for requested intra mode
[h264 @ 0x61ed5be41440] error while decoding MB 0 59, bytestream 15496
[h264 @ 0x61ed5be41440] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x61ed5be41440] error while decoding MB 0 33, bytestream 88422
[h264 @ 0x61ed560e5980] error while decoding MB 52 64, bytestream -23
[h264 @ 0x61ed55f80380] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x61ed55f80380] error while decoding MB 0 43, bytestream 12124
[h264 @ 0x61ed55f80380] left block unavailable for requested intra mode
[h264 @ 0x61ed55f80380] error while decoding MB 0 44, bytestream 8166
[h264 @ 0x61ed55ff7ec0] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x61ed55ff7ec0] error while decoding MB 0 44, bytestream 60014
[h264 @ 0x61ed5977acc0] left block unavailable for requested intra mode
[h264 @ 0x61ed5977acc0] error while decoding MB 0 36, bytestream 101395
[h264 @ 0x61ed55ff7ec0] error while decoding MB 99 63, bytestream -14
[h264 @ 0x61ed55f80380] left block unavailable for requested intra mode
[h264 @ 0x61ed55f80380] error while decoding MB 0 44, bytestream 75628
[h264 @ 0x61ed55f80380] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x61ed55f80380] error while decoding MB 0 19, bytestream 173612
[h264 @ 0x61ed5977acc0] error while decoding MB 112 40, bytestream -30
[h264 @ 0x61ed55ff7ec0] left block unavailable for requested intra mode
[h264 @ 0x61ed55ff7ec0] error while decoding MB 0 21, bytestream 158683
[h264 @ 0x61ed5977acc0] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x61ed5977acc0] error while decoding MB 0 53, bytestream 44579
[h264 @ 0x61ed55f80380] left block unavailable for requested intra mode
[h264 @ 0x61ed55f80380] error while decoding MB 0 22, bytestream 147081
[h264 @ 0x61ed5977acc0] error while decoding MB 22 61, bytestream -19
[h264 @ 0x61ed55977dc0] error while decoding MB 106 63, bytestream -23
[h264 @ 0x61ed579c9c00] error while decoding MB 83 66, bytestream -25
[h264 @ 0x61ed5952d280] left block unavailable for requested intra mode
[h264 @ 0x61ed5952d280] error while decoding MB 0 17, bytestream 179405
[h264 @ 0x61ed558e1380] left block unavailable for requested intra mode
[h264 @ 0x61ed558e1380] error while decoding MB 0 44, bytestream 2621
[h264 @ 0x61ed5952d280] left block unavailable for requested intra mode
[h264 @ 0x61ed5952d280] error while decoding MB 0 59, bytestream 23437
[h264 @ 0x61ed5952d280] error while decoding MB 50 63, bytestream -16
[h264 @ 0x61ed584c6bc0] error while decoding MB 92 62, bytestream -5
[h264 @ 0x61ed584c6bc0] cabac decode of qscale diff failed at 63 41
[h264 @ 0x61ed584c6bc0] error while decoding MB 63 41, bytestream 3575
[h264 @ 0x61ed55958080] error while decoding MB 107 59, bytestream -26
[h264 @ 0x61ed55977dc0] error while decoding MB 63 32, bytestream -5
[h264 @ 0x61ed55958080] error while decoding MB 43 37, bytestream -17
[h264 @ 0x61ed5952d280] error while decoding MB 67 61, bytestream -8
[h264 @ 0x61ed579c9c00] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x61ed579c9c00] error while decoding MB 0 55, bytestream 10333
[h264 @ 0x61ed579c9c00] error while decoding MB 75 56, bytestream -15
[h264 @ 0x61ed5952d280] left block unavailable for requested intra mode
[h264 @ 0x61ed5952d280] error while decoding MB 0 37, bytestream 9917
[h264 @ 0x61ed55958080] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x61ed55958080] error while decoding MB 0 57, bytestream 33898
[h264 @ 0x61ed579c9c00] error while decoding MB 117 65, bytestream -16
[h264 @ 0x61ed579c9c00] left block unavailable for requested intra mode
[h264 @ 0x61ed579c9c00] error while decoding MB 0 42, bytestream 79755
[h264 @ 0x61ed579c9c00] left block unavailable for requested intra mode
[h264 @ 0x61ed579c9c00] error while decoding MB 0 50, bytestream 9898
[h264 @ 0x61ed579c9c00] error while decoding MB 23 66, bytestream -7
[h264 @ 0x61ed559147c0] error while decoding MB 92 52, bytestream -6
[h264 @ 0x61ed5be41440] error while decoding MB 64 66, bytestream -16
[h264 @ 0x61ed559147c0] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x61ed559147c0] error while decoding MB 0 49, bytestream 64200
[h264 @ 0x61ed5be41440] error while decoding MB 44 58, bytestream -17
[h264 @ 0x61ed559147c0] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x61ed559147c0] error while decoding MB 0 44, bytestream 5940
[h264 @ 0x61ed559147c0] left block unavailable for requested intra mode
[h264 @ 0x61ed559147c0] error while decoding MB 0 47, bytestream 53648
[h264 @ 0x61ed559147c0] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x61ed559147c0] error while decoding MB 0 51, bytestream 8928
[h264 @ 0x61ed560e5980] left block unavailable for requested intra mode
[h264 @ 0x61ed560e5980] error while decoding MB 0 59, bytestream 9726
[h264 @ 0x61ed560e5980] error while decoding MB 43 43, bytestream -37
[h264 @ 0x61ed5be41440] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x61ed5be41440] error while decoding MB 0 50, bytestream 10319
[h264 @ 0x61ed5be41440] left block unavailable for requested intra mode
[h264 @ 0x61ed5be41440] error while decoding MB 0 53, bytestream 7645
[h264 @ 0x61ed5be41440] left block unavailable for requested intra mode
[h264 @ 0x61ed5be41440] error while decoding MB 0 55, bytestream 9899
[h264 @ 0x61ed559147c0] left block unavailable for requested intra mode
[h264 @ 0x61ed559147c0] error while decoding MB 0 53, bytestream 7927
[h264 @ 0x61ed5be41440] error while decoding MB 23 58, bytestream -25
[h264 @ 0x61ed559147c0] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x61ed559147c0] error while decoding MB 0 17, bytestream 176395
[h264 @ 0x61ed559147c0] error while decoding MB 20 66, bytestream -27
[h264 @ 0x61ed5be41440] left block unavailable for requested intra mode
[h264 @ 0x61ed5be41440] error while decoding MB 0 63, bytestream 1719
[h264 @ 0x61ed559147c0] error while decoding MB 20 66, bytestream -40
[h264 @ 0x61ed559147c0] left block unavailable for requested intra mode
[h264 @ 0x61ed559147c0] error while decoding MB 0 59, bytestream 15146
[h264 @ 0x61ed5977acc0] error while decoding MB 107 64, bytestream -20
[h264 @ 0x61ed55977dc0] error while decoding MB 39 64, bytestream -37
[h264 @ 0x61ed55977dc0] error while decoding MB 110 61, bytestream -31
#####################
[rtsp @ 0x61ed576fda80] getaddrinfo(): Name or service not known
[rtsp @ 0x61ed576fda80] getaddrinfo(): Name or service not known
[h264 @ 0x61ed55960c80] error while decoding MB 95 55, bytestream -10
[h264 @ 0x61ed58b556c0] left block unavailable for requested intra mode
[h264 @ 0x61ed58b556c0] error while decoding MB 0 18, bytestream 117506
[h264 @ 0x61ed59f13f80] error while decoding MB 20 63, bytestream -6
[h264 @ 0x61ed55bccac0] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x61ed55bccac0] error while decoding MB 0 17, bytestream 101211
[h264 @ 0x61ed55956a80] left block unavailable for requested intra mode
[h264 @ 0x61ed55956a80] error while decoding MB 0 37, bytestream 74631
[h264 @ 0x61ed55bccac0] left block unavailable for requested intra mode
[h264 @ 0x61ed55bccac0] error while decoding MB 0 55, bytestream 2154
[h264 @ 0x61ed598106c0] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x61ed598106c0] error while decoding MB 0 18, bytestream 11583
[h264 @ 0x61ed55bccac0] error while decoding MB 79 63, bytestream -12
[h264 @ 0x61ed55956a80] error while decoding MB 116 57, bytestream -17
[h264 @ 0x61ed598106c0] left block unavailable for requested intra mode
[h264 @ 0x61ed598106c0] error while decoding MB 0 34, bytestream 6875
[h264 @ 0x61ed55956a80] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x61ed55956a80] error while decoding MB 0 24, bytestream 86942
[h264 @ 0x61ed55bccac0] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x61ed55bccac0] error while decoding MB 0 42, bytestream 51204
[h264 @ 0x61ed55bccac0] error while decoding MB 106 63, bytestream -6
[h264 @ 0x61ed55bccac0] left block unavailable for requested intra mode
[h264 @ 0x61ed55bccac0] error while decoding MB 0 28, bytestream 78735
[h264 @ 0x61ed55bccac0] error while decoding MB 110 63, bytestream -36
[h264 @ 0x61ed58b556c0] error while decoding MB 39 14, bytestream -11
[h264 @ 0x61ed55960c80] left block unavailable for requested intra mode
[h264 @ 0x61ed55960c80] error while decoding MB 0 47, bytestream 1109
[h264 @ 0x61ed55bccac0] error while decoding MB 80 58, bytestream -23
[h264 @ 0x61ed55aa0cc0] left block unavailable for requested intra mode
[h264 @ 0x61ed55aa0cc0] error while decoding MB 0 49, bytestream 3148
[h264 @ 0x61ed55bccac0] error while decoding MB 13 65, bytestream -34
[h264 @ 0x61ed59f13f80] left block unavailable for requested intra mode
[h264 @ 0x61ed59f13f80] error while decoding MB 0 26, bytestream 7268
[h264 @ 0x61ed5ad4afc0] left block unavailable for requested intra mode
[h264 @ 0x61ed5ad4afc0] error while decoding MB 0 2, bytestream 147584
[h264 @ 0x61ed587f8d80] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x61ed587f8d80] error while decoding MB 0 41, bytestream 63673
[h264 @ 0x61ed5ad4afc0] left block unavailable for requested intra mode
[h264 @ 0x61ed5ad4afc0] error while decoding MB 0 33, bytestream 83680
[h264 @ 0x61ed58f3f940] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x61ed58f3f940] error while decoding MB 0 42, bytestream 50175
[h264 @ 0x61ed55960c80] error while decoding MB 17 28, bytestream -6
[h264 @ 0x61ed587f8d80] error while decoding MB 64 62, bytestream -16
[h264 @ 0x61ed55bfb8c0] left block unavailable for requested intra mode
[h264 @ 0x61ed55bfb8c0] error while decoding MB 0 36, bytestream 5206
[h264 @ 0x61ed58f3f940] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x61ed58f3f940] error while decoding MB 0 34, bytestream 79363
[h264 @ 0x61ed587f8d80] error while decoding MB 96 61, bytestream -16
[h264 @ 0x61ed58f3f940] error while decoding MB 34 63, bytestream -5
[h264 @ 0x61ed58b556c0] left block unavailable for requested intra mode
[h264 @ 0x61ed58b556c0] error while decoding MB 0 29, bytestream 74123
[h264 @ 0x61ed55aa0cc0] error while decoding MB 4 63, bytestream -6
[h264 @ 0x61ed598106c0] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x61ed598106c0] error while decoding MB 0 22, bytestream 109991
[h264 @ 0x61ed58b556c0] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x61ed58b556c0] error while decoding MB 0 18, bytestream 122625
[h264 @ 0x61ed58b556c0] error while decoding MB 49 31, bytestream -6
[h264 @ 0x61ed55c5b500] left block unavailable for requested intra mode
[h264 @ 0x61ed55c5b500] error while decoding MB 0 27, bytestream 8849
[h264 @ 0x61ed58f3f940] left block unavailable for requested intra mode
[h264 @ 0x61ed58f3f940] error while decoding MB 0 65, bytestream 4844
[h264 @ 0x61ed587f8d80] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x61ed587f8d80] error while decoding MB 0 45, bytestream 53338
[h264 @ 0x61ed587f8d80] left block unavailable for requested intra mode
[h264 @ 0x61ed587f8d80] error while decoding MB 0 50, bytestream 33100
[h264 @ 0x61ed5ad4afc0] left block unavailable for requested intra mode
[h264 @ 0x61ed5ad4afc0] error while decoding MB 0 63, bytestream 9609
[h264 @ 0x61ed587f8d80] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x61ed587f8d80] error while decoding MB 0 19, bytestream 118599
[h264 @ 0x61ed5ad4afc0] error while decoding MB 17 60, bytestream -10
[h264 @ 0x61ed55956a80] error while decoding MB 57 58, bytestream -6
[h264 @ 0x61ed55bfb8c0] error while decoding MB 77 51, bytestream -6
[h264 @ 0x61ed55956a80] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x61ed55956a80] error while decoding MB 0 40, bytestream 65189
[h264 @ 0x61ed55956a80] left block unavailable for requested intra mode
[h264 @ 0x61ed55956a80] error while decoding MB 0 53, bytestream 35311
[h264 @ 0x61ed55960c80] left block unavailable for requested intra mode
[h264 @ 0x61ed55960c80] error while decoding MB 0 10, bytestream 115155
[h264 @ 0x61ed55960c80] left block unavailable for requested intra mode
[h264 @ 0x61ed55960c80] error while decoding MB 0 29, bytestream 75061
[h264 @ 0x61ed58f3f940] error while decoding MB 86 63, bytestream -5
[h264 @ 0x61ed59f13f80] left block unavailable for requested intra mode
[h264 @ 0x61ed59f13f80] error while decoding MB 0 28, bytestream 7348
[h264 @ 0x61ed55bccac0] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x61ed55bccac0] error while decoding MB 0 38, bytestream 69355
[h264 @ 0x61ed55c5b500] error while decoding MB 38 23, bytestream -5
[h264 @ 0x61ed5ad4afc0] cabac decode of qscale diff failed at 72 63
[h264 @ 0x61ed5ad4afc0] error while decoding MB 72 63, bytestream -4
[h264 @ 0x61ed587f8d80] error while decoding MB 27 30, bytestream -5
[h264 @ 0x61ed58f3f940] error while decoding MB 110 52, bytestream -7
[h264 @ 0x61ed55bccac0] error while decoding MB 31 37, bytestream -5
[h264 @ 0x61ed587f8d80] error while decoding MB 0 66, bytestream -6
[h264 @ 0x61ed587f8d80] left block unavailable for requested intra mode
[h264 @ 0x61ed587f8d80] error while decoding MB 0 46, bytestream 381
[h264 @ 0x61ed55956a80] error while decoding MB 24 46, bytestream -6
[h264 @ 0x61ed55c5b500] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x61ed55c5b500] error while decoding MB 0 18, bytestream 117960
[h264 @ 0x61ed5ad4afc0] error while decoding MB 27 63, bytestream -5
[h264 @ 0x61ed59f13f80] left block unavailable for requested intra mode
[h264 @ 0x61ed59f13f80] error while decoding MB 0 53, bytestream 27106
[h264 @ 0x61ed59f13f80] left block unavailable for requested intra mode
[h264 @ 0x61ed59f13f80] error while decoding MB 0 8, bytestream 108345
[h264 @ 0x61ed55aa0cc0] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x61ed55aa0cc0] error while decoding MB 0 25, bytestream 80101
[h264 @ 0x61ed55bfb8c0] left block unavailable for requested intra mode
[h264 @ 0x61ed55bfb8c0] error while decoding MB 0 63, bytestream 8528
[h264 @ 0x61ed55960c80] error while decoding MB 24 66, bytestream -26
[h264 @ 0x61ed58f3f940] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x61ed58f3f940] error while decoding MB 0 45, bytestream 70266
[h264 @ 0x61ed5ad4afc0] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x61ed5ad4afc0] error while decoding MB 0 17, bytestream 164322
[h264 @ 0x61ed55c5b500] error while decoding MB 40 61, bytestream -5
[h264 @ 0x61ed587f8d80] left block unavailable for requested intra mode
[h264 @ 0x61ed587f8d80] error while decoding MB 0 56, bytestream 20717
[h264 @ 0x61ed55c5b500] error while decoding MB 55 61, bytestream -5
[h264 @ 0x61ed5ad4afc0] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x61ed5ad4afc0] error while decoding MB 0 59, bytestream 10959
[h264 @ 0x61ed58f3f940] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x61ed58f3f940] error while decoding MB 0 4, bytestream 177318
[h264 @ 0x61ed55c5b500] left block unavailable for requested intra mode
[h264 @ 0x61ed55c5b500] error while decoding MB 0 29, bytestream 114899
[h264 @ 0x61ed55aa0cc0] error while decoding MB 57 65, bytestream -13
[h264 @ 0x61ed59f13f80] left block unavailable for requested intra mode
[h264 @ 0x61ed59f13f80] error while decoding MB 0 64, bytestream 9461
[h264 @ 0x61ed55aa0cc0] left block unavailable for requested intra mode
[h264 @ 0x61ed55aa0cc0] error while decoding MB 0 41, bytestream 80007
[h264 @ 0x61ed55aa0cc0] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x61ed55aa0cc0] error while decoding MB 0 10, bytestream 170391
[h264 @ 0x61ed59f13f80] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x61ed59f13f80] error while decoding MB 0 48, bytestream 59351
[h264 @ 0x61ed55aa0cc0] error while decoding MB 61 61, bytestream -7
[h264 @ 0x61ed55c5b500] left block unavailable for requested intra mode
[h264 @ 0x61ed55c5b500] error while decoding MB 0 45, bytestream 62222
[h264 @ 0x61ed55956a80] left block unavailable for requested intra mode
[h264 @ 0x61ed55956a80] error while decoding MB 0 59, bytestream 17730
[h264 @ 0x61ed55960c80] left block unavailable for requested intra mode
[h264 @ 0x61ed55960c80] error while decoding MB 0 53, bytestream 34425
[h264 @ 0x61ed55960c80] left block unavailable for requested intra mode
[h264 @ 0x61ed55960c80] error while decoding MB 0 40, bytestream 87998
[h264 @ 0x61ed55960c80] error while decoding MB 36 58, bytestream -17
[h264 @ 0x61ed55bccac0] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x61ed55bccac0] error while decoding MB 0 45, bytestream 70913
[h264 @ 0x61ed598106c0] error while decoding MB 114 55, bytestream -5
[h264 @ 0x61ed55aa0cc0] error while decoding MB 6 61, bytestream -7
Processed 58918 frames before detection.
Processed 139231 frames before detection.
Saved successfully
Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
-- <re.Match object; span=(0, 8), match='06:49:13'>
Extracted Time: 06:49:13
06:49:13
Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
-- <re.Match object; span=(0, 8), match='16.56.26'>
Extracted Time: 16.56.26
16.56.26
***25-03-2025***
Trying start time: 06:00:00
Connecting to recorded video at 1742862600
URL: rtsp://admin:rmc%4012345@103.168.199.92:554/c1/b1742862600/e1742866200/replay/
[rtsp @ 0x61ed55949ac0] getaddrinfo(): Name or service not known
[rtsp @ 0x61ed55949ac0] getaddrinfo(): Name or service not known
Stream found at 06:00:00
Trying start time: 15:00:20
Connecting to recorded video at 1742895020
URL: rtsp://admin:rmc%4012345@103.168.199.92:554/c1/b1742895020/e1742904000/replay/
[rtsp @ 0x61ed55e03b40] getaddrinfo(): Name or service not known
[rtsp @ 0x61ed55e03b40] getaddrinfo(): Name or service not known
Stream found at 15:00:20
#####################
[rtsp @ 0x61ed5bc59f40] getaddrinfo(): Name or service not known
[rtsp @ 0x61ed5bc59f40] getaddrinfo(): Name or service not known
[h264 @ 0x61ed596b4040] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x61ed596b4040] error while decoding MB 0 17, bytestream 4926
[h264 @ 0x61ed56377580] left block unavailable for requested intra mode
[h264 @ 0x61ed56377580] error while decoding MB 0 17, bytestream 144605
[h264 @ 0x61ed55c2dac0] error while decoding MB 105 63, bytestream -7
[h264 @ 0x61ed5b0dfb80] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x61ed5b0dfb80] error while decoding MB 0 46, bytestream 68221
[h264 @ 0x61ed596b4040] left block unavailable for requested intra mode
[h264 @ 0x61ed596b4040] error while decoding MB 0 48, bytestream 10363
[h264 @ 0x61ed596b4040] error while decoding MB 59 59, bytestream -14
[h264 @ 0x61ed5b0dfb80] left block unavailable for requested intra mode
[h264 @ 0x61ed5b0dfb80] error while decoding MB 0 21, bytestream 155159
[h264 @ 0x61ed596b4040] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x61ed596b4040] error while decoding MB 0 26, bytestream 134085
[h264 @ 0x61ed596b4040] left block unavailable for requested intra mode
[h264 @ 0x61ed596b4040] error while decoding MB 0 16, bytestream 183942
[h264 @ 0x61ed596b4040] error while decoding MB 88 65, bytestream -13
[h264 @ 0x61ed55bbff00] left block unavailable for requested intra mode
[h264 @ 0x61ed55bbff00] error while decoding MB 0 42, bytestream 59883
[h264 @ 0x61ed5b0dfb80] left block unavailable for requested intra mode
[h264 @ 0x61ed5b0dfb80] error while decoding MB 0 36, bytestream 99067
[h264 @ 0x61ed5b0dfb80] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x61ed5b0dfb80] error while decoding MB 0 65, bytestream 6757
[h264 @ 0x61ed55bbff00] top block unavailable for requested intra mode -1
[h264 @ 0x61ed55bbff00] error while decoding MB 119 0, bytestream 174570
[h264 @ 0x61ed55bbff00] left block unavailable for requested intra mode
[h264 @ 0x61ed55bbff00] error while decoding MB 0 17, bytestream 187469
[h264 @ 0x61ed5b0dfb80] left block unavailable for requested intra mode
[h264 @ 0x61ed5b0dfb80] error while decoding MB 0 52, bytestream 52664
[h264 @ 0x61ed55bbff00] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x61ed55bbff00] error while decoding MB 0 19, bytestream 5931
[h264 @ 0x61ed55bbff00] left block unavailable for requested intra mode
[h264 @ 0x61ed55bbff00] error while decoding MB 0 58, bytestream 10922
[h264 @ 0x61ed56377580] error while decoding MB 0 54, bytestream -14
[h264 @ 0x61ed55b70700] left block unavailable for requested intra mode
[h264 @ 0x61ed55b70700] error while decoding MB 0 16, bytestream 194746
[h264 @ 0x61ed559470c0] error while decoding MB 64 58, bytestream -6
[h264 @ 0x61ed5829b280] left block unavailable for requested intra mode
[h264 @ 0x61ed5829b280] error while decoding MB 0 53, bytestream 48343
[h264 @ 0x61ed5829b280] left block unavailable for requested intra mode
[h264 @ 0x61ed5829b280] error while decoding MB 0 30, bytestream 125036
[h264 @ 0x61ed559470c0] error while decoding MB 78 60, bytestream 61
[h264 @ 0x61ed584c5f40] left block unavailable for requested intra mode
[h264 @ 0x61ed584c5f40] error while decoding MB 0 65, bytestream 2285
[h264 @ 0x61ed584c5f40] left block unavailable for requested intra mode
[h264 @ 0x61ed584c5f40] error while decoding MB 0 67, bytestream 165
[h264 @ 0x61ed584c5f40] error while decoding MB 65 65, bytestream -10
[h264 @ 0x61ed584c5f40] error while decoding MB 27 65, bytestream -5
[h264 @ 0x61ed55c2dac0] error while decoding MB 30 66, bytestream -11
[h264 @ 0x61ed584c5f40] left block unavailable for requested intra mode
[h264 @ 0x61ed584c5f40] error while decoding MB 0 25, bytestream 157261
[h264 @ 0x61ed584c5f40] left block unavailable for requested intra mode
[h264 @ 0x61ed584c5f40] error while decoding MB 0 21, bytestream 175980
[h264 @ 0x61ed5829b280] error while decoding MB 29 64, bytestream -7
[h264 @ 0x61ed56f46140] error while decoding MB 30 62, bytestream -8
[h264 @ 0x61ed559470c0] left block unavailable for requested intra mode
[h264 @ 0x61ed559470c0] error while decoding MB 0 56, bytestream 12282
[h264 @ 0x61ed55bbff00] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x61ed55bbff00] error while decoding MB 0 39, bytestream 103060
#####################
[rtsp @ 0x61ed55e03b40] getaddrinfo(): Name or service not known
[rtsp @ 0x61ed55e03b40] getaddrinfo(): Name or service not known
[h264 @ 0x61ed597f9900] left block unavailable for requested intra mode
[h264 @ 0x61ed597f9900] error while decoding MB 0 28, bytestream 83774
[h264 @ 0x61ed558bcdc0] left block unavailable for requested intra mode
[h264 @ 0x61ed558bcdc0] error while decoding MB 0 28, bytestream 83810
[h264 @ 0x61ed558bcdc0] left block unavailable for requested intra mode
[h264 @ 0x61ed558bcdc0] error while decoding MB 0 61, bytestream 15360
[h264 @ 0x61ed58d7aa40] error while decoding MB 77 59, bytestream -15
[h264 @ 0x61ed597f9900] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x61ed597f9900] error while decoding MB 0 64, bytestream 9305
[h264 @ 0x61ed589ee440] cabac decode of qscale diff failed at 16 63
[h264 @ 0x61ed589ee440] error while decoding MB 16 63, bytestream -5
[h264 @ 0x61ed570e6400] left block unavailable for requested intra mode
[h264 @ 0x61ed570e6400] error while decoding MB 0 29, bytestream 6997
[h264 @ 0x61ed598106c0] error while decoding MB 40 63, bytestream -5
[h264 @ 0x61ed597f9900] left block unavailable for requested intra mode
[h264 @ 0x61ed597f9900] error while decoding MB 0 32, bytestream 83353
[h264 @ 0x61ed558bcdc0] left block unavailable for requested intra mode
[h264 @ 0x61ed558bcdc0] error while decoding MB 0 22, bytestream 109613
[h264 @ 0x61ed58d7aa40] left block unavailable for requested intra mode
[h264 @ 0x61ed58d7aa40] error while decoding MB 0 54, bytestream 32744
[h264 @ 0x61ed598106c0] left block unavailable for requested intra mode
[h264 @ 0x61ed598106c0] error while decoding MB 0 24, bytestream 9257
[h264 @ 0x61ed58d7aa40] left block unavailable for requested intra mode
[h264 @ 0x61ed58d7aa40] error while decoding MB 0 37, bytestream 63989
[h264 @ 0x61ed597f9900] cabac decode of qscale diff failed at 9 17
[h264 @ 0x61ed597f9900] error while decoding MB 9 17, bytestream 11605
[h264 @ 0x61ed597f9900] cabac decode of qscale diff failed at 20 20
[h264 @ 0x61ed597f9900] error while decoding MB 20 20, bytestream 10627
[h264 @ 0x61ed55e28a40] left block unavailable for requested intra mode
[h264 @ 0x61ed55e28a40] error while decoding MB 0 20, bytestream 11101
[h264 @ 0x61ed58d7aa40] left block unavailable for requested intra mode
[h264 @ 0x61ed58d7aa40] error while decoding MB 0 30, bytestream 7696
[h264 @ 0x61ed5b8d2200] left block unavailable for requested intra mode
[h264 @ 0x61ed5b8d2200] error while decoding MB 0 6, bytestream 121538
[h264 @ 0x61ed558bcdc0] error while decoding MB 73 64, bytestream -5
[h264 @ 0x61ed58d7aa40] left block unavailable for requested intra mode
[h264 @ 0x61ed58d7aa40] error while decoding MB 0 39, bytestream 57803
[h264 @ 0x61ed58d7aa40] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x61ed58d7aa40] error while decoding MB 0 45, bytestream 3728
[h264 @ 0x61ed58d7aa40] left block unavailable for requested intra mode
[h264 @ 0x61ed58d7aa40] error while decoding MB 0 61, bytestream 11266
[h264 @ 0x61ed596b2680] left block unavailable for requested intra mode
[h264 @ 0x61ed596b2680] error while decoding MB 0 63, bytestream 9349
[h264 @ 0x61ed5a751980] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x61ed5a751980] error while decoding MB 0 16, bytestream 103044
[h264 @ 0x61ed598106c0] left block unavailable for requested intra mode
[h264 @ 0x61ed598106c0] error while decoding MB 0 30, bytestream 7577
[h264 @ 0x61ed596b2680] left block unavailable for requested intra mode
[h264 @ 0x61ed596b2680] error while decoding MB 0 60, bytestream 12622
[h264 @ 0x61ed598106c0] left block unavailable for requested intra mode
[h264 @ 0x61ed598106c0] error while decoding MB 0 30, bytestream 7883
[h264 @ 0x61ed5a751980] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x61ed5a751980] error while decoding MB 0 48, bytestream 38828
[h264 @ 0x61ed55e28a40] left block unavailable for requested intra mode
[h264 @ 0x61ed55e28a40] error while decoding MB 0 40, bytestream 53286
[h264 @ 0x61ed57a7ed00] cabac decode of qscale diff failed at 19 61
[h264 @ 0x61ed57a7ed00] error while decoding MB 19 61, bytestream 358
[h264 @ 0x61ed55e28a40] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x61ed55e28a40] error while decoding MB 0 65, bytestream 4858
[h264 @ 0x61ed589ee440] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x61ed589ee440] error while decoding MB 0 20, bytestream 16511
[h264 @ 0x61ed596b2680] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x61ed596b2680] error while decoding MB 0 19, bytestream 149202
[h264 @ 0x61ed55e28a40] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x61ed55e28a40] error while decoding MB 0 46, bytestream 65911
[h264 @ 0x61ed55e28a40] left block unavailable for requested intra mode
[h264 @ 0x61ed55e28a40] error while decoding MB 0 54, bytestream 42226
[h264 @ 0x61ed596b2680] error while decoding MB 105 50, bytestream -22
[h264 @ 0x61ed596b2680] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x61ed596b2680] error while decoding MB 0 22, bytestream 136061
[h264 @ 0x61ed596b2680] cabac decode of qscale diff failed at 70 49
[h264 @ 0x61ed596b2680] error while decoding MB 70 49, bytestream 55335
[h264 @ 0x61ed558bcdc0] left block unavailable for requested intra mode
[h264 @ 0x61ed558bcdc0] error while decoding MB 0 37, bytestream 89890
[h264 @ 0x61ed570e6400] left block unavailable for requested intra mode
[h264 @ 0x61ed570e6400] error while decoding MB 0 19, bytestream 145653
[h264 @ 0x61ed570e6400] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x61ed570e6400] error while decoding MB 0 23, bytestream 131467
[h264 @ 0x61ed5b8d2200] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x61ed5b8d2200] error while decoding MB 0 41, bytestream 34182
[h264 @ 0x61ed5b8d2200] error while decoding MB 99 14, bytestream -5
[h264 @ 0x61ed56f3a180] left block unavailable for requested intra mode
[h264 @ 0x61ed56f3a180] error while decoding MB 0 61, bytestream 18522
[h264 @ 0x61ed570e6400] left block unavailable for requested intra mode
[h264 @ 0x61ed570e6400] error while decoding MB 0 59, bytestream 24900
[h264 @ 0x61ed56f3a180] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x61ed56f3a180] error while decoding MB 0 29, bytestream 111486
[h264 @ 0x61ed57a7ed00] left block unavailable for requested intra mode
[h264 @ 0x61ed57a7ed00] error while decoding MB 0 67, bytestream 6029
[h264 @ 0x61ed55e28a40] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x61ed55e28a40] error while decoding MB 0 57, bytestream 31949
[h264 @ 0x61ed56f3a180] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x61ed56f3a180] error while decoding MB 0 57, bytestream 32562
[h264 @ 0x61ed56f3a180] left block unavailable for requested intra mode
[h264 @ 0x61ed56f3a180] error while decoding MB 0 56, bytestream 8359
[h264 @ 0x61ed596b2680] error while decoding MB 109 59, bytestream -5
[h264 @ 0x61ed570e6400] error while decoding MB 86 55, bytestream -22
[h264 @ 0x61ed5b8d2200] left block unavailable for requested intra mode
[h264 @ 0x61ed5b8d2200] error while decoding MB 0 61, bytestream 17933
[h264 @ 0x61ed58d7aa40] left block unavailable for requested intra mode
[h264 @ 0x61ed58d7aa40] error while decoding MB 0 19, bytestream 153101
[h264 @ 0x61ed5b8d2200] left block unavailable for requested intra mode
[h264 @ 0x61ed5b8d2200] error while decoding MB 0 57, bytestream 33454
[h264 @ 0x61ed56f3a180] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x61ed56f3a180] error while decoding MB 0 62, bytestream 15559
[h264 @ 0x61ed558bcdc0] error while decoding MB 58 60, bytestream -5
[h264 @ 0x61ed589ee440] error while decoding MB 112 60, bytestream -7
[h264 @ 0x61ed570e6400] left block unavailable for requested intra mode
[h264 @ 0x61ed570e6400] error while decoding MB 0 61, bytestream 18000
[h264 @ 0x61ed598106c0] left block unavailable for requested intra mode
[h264 @ 0x61ed598106c0] error while decoding MB 0 32, bytestream 111366
Processed 49493 frames before detection.
Processed 143759 frames before detection.
Saved successfully
Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
-- <re.Match object; span=(0, 8), match='06:41:17'>
Extracted Time: 06:41:17
06:41:17
Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
***26-03-2025***
Trying start time: 06:00:00
Connecting to recorded video at 1742949000
URL: rtsp://admin:rmc%4012345@103.168.199.92:554/c1/b1742949000/e1742952600/replay/
[rtsp @ 0x61ed5a1c1d40] getaddrinfo(): Name or service not known
[ WARN:0@19660.481] global cap.cpp:175 open VIDEOIO(CV_IMAGES): raised OpenCV exception:

OpenCV(4.11.0) /io/opencv/modules/videoio/src/cap_images.cpp:237: error: (-5:Bad argument) CAP_IMAGES: error, expected '0?[1-9][du]' pattern, got: rtsp://admin:rmc%4012345@103.168.199.92:554/c1/b1742949000/e1742952600/replay/ in function 'icvExtractPattern'


Trying start time: 06:00:00
Connecting to recorded video at 1742949000
URL: rtsp://admin:rmc%4012345@103.168.199.92:554/c1/b1742949000/e1742952600/replay/
[rtsp @ 0x61ed55e03b40] getaddrinfo(): Name or service not known
[rtsp @ 0x61ed55e03b40] getaddrinfo(): Name or service not known
Stream found at 06:00:00
Trying start time: 15:00:20
Connecting to recorded video at 1742981420
URL: rtsp://admin:rmc%4012345@103.168.199.92:554/c1/b1742981420/e1742990400/replay/
[rtsp @ 0x61ed55e03b40] getaddrinfo(): Name or service not known
[rtsp @ 0x61ed55e03b40] getaddrinfo(): Name or service not known
Stream found at 15:00:20
#####################
[rtsp @ 0x61ed55e03b40] getaddrinfo(): Name or service not known
[ WARN:0@19672.608] global cap.cpp:175 open VIDEOIO(CV_IMAGES): raised OpenCV exception:

OpenCV(4.11.0) /io/opencv/modules/videoio/src/cap_images.cpp:237: error: (-5:Bad argument) CAP_IMAGES: error, expected '0?[1-9][du]' pattern, got: rtsp://admin:rmc%4012345@103.168.199.92:554/c1/b1742949000/e1742952600/replay/ in function 'icvExtractPattern'


No person detected in the video.
#####################
[rtsp @ 0x61ed593f20c0] getaddrinfo(): Name or service not known
[rtsp @ 0x61ed593f20c0] getaddrinfo(): Name or service not known
[h264 @ 0x61ed579c4500] left block unavailable for requested intra mode
[h264 @ 0x61ed579c4500] error while decoding MB 0 16, bytestream 141088
[h264 @ 0x61ed58ed7940] left block unavailable for requested intra mode
[h264 @ 0x61ed58ed7940] error while decoding MB 0 21, bytestream 7583
[h264 @ 0x61ed5bc0cfc0] error while decoding MB 83 64, bytestream -7
[h264 @ 0x61ed560df440] left block unavailable for requested intra mode
[h264 @ 0x61ed560df440] error while decoding MB 0 14, bytestream 145027
[h264 @ 0x61ed58ed7940] left block unavailable for requested intra mode
[h264 @ 0x61ed58ed7940] error while decoding MB 0 38, bytestream 63711
[h264 @ 0x61ed579c4500] left block unavailable for requested intra mode
[h264 @ 0x61ed579c4500] error while decoding MB 0 24, bytestream 113171
[h264 @ 0x61ed579c4500] error while decoding MB 87 61, bytestream -5
[h264 @ 0x61ed56a6ff40] cabac decode of qscale diff failed at 51 20
[h264 @ 0x61ed56a6ff40] error while decoding MB 51 20, bytestream 8678
[h264 @ 0x61ed58466140] left block unavailable for requested intra mode
[h264 @ 0x61ed58466140] error while decoding MB 0 18, bytestream 11522
[h264 @ 0x61ed560df440] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x61ed560df440] error while decoding MB 0 28, bytestream 83721
[h264 @ 0x61ed579c4500] error while decoding MB 110 62, bytestream -7
[h264 @ 0x61ed59e80d00] error while decoding MB 69 63, bytestream -6
[h264 @ 0x61ed579c4500] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x61ed579c4500] error while decoding MB 0 64, bytestream 8139
[h264 @ 0x61ed558540c0] left block unavailable for requested intra mode
[h264 @ 0x61ed558540c0] error while decoding MB 0 54, bytestream 34008
[h264 @ 0x61ed5a800740] error while decoding MB 12 64, bytestream -5
[h264 @ 0x61ed5bc0cfc0] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x61ed5bc0cfc0] error while decoding MB 0 62, bytestream 10828
[h264 @ 0x61ed56f39080] left block unavailable for requested intra mode
[h264 @ 0x61ed56f39080] error while decoding MB 0 47, bytestream 4145
[h264 @ 0x61ed558540c0] error while decoding MB 55 54, bytestream -8
[h264 @ 0x61ed59ed8a00] left block unavailable for requested intra mode
[h264 @ 0x61ed59ed8a00] error while decoding MB 0 58, bytestream 18612
[h264 @ 0x61ed58466140] error while decoding MB 53 63, bytestream -5
[h264 @ 0x61ed59ed8a00] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x61ed59ed8a00] error while decoding MB 0 39, bytestream 61336
[h264 @ 0x61ed59ed8a00] left block unavailable for requested intra mode
[h264 @ 0x61ed59ed8a00] error while decoding MB 0 51, bytestream 41819
[h264 @ 0x61ed5a800740] error while decoding MB 92 62, bytestream -5
No person detected in the video.
Processed 60241 frames before detection.
Saved successfully
Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
-- <re.Match object; span=(0, 8), match='15.50.36'>
Extracted Time: 15.50.36
15.50.36
***27-03-2025***
Trying start time: 06:00:00
Connecting to recorded video at 1743035400
URL: rtsp://admin:rmc%4012345@103.168.199.92:554/c1/b1743035400/e1743039000/replay/
[rtsp @ 0x61ed5a75ff00] getaddrinfo(): Name or service not known
[rtsp @ 0x61ed5a75ff00] getaddrinfo(): Name or service not known
Stream found at 06:00:00
Trying start time: 15:00:20
Connecting to recorded video at 1743067820
URL: rtsp://admin:rmc%4012345@103.168.199.92:554/c1/b1743067820/e1743076800/replay/
[rtsp @ 0x61ed55e03b40] getaddrinfo(): Name or service not known
[rtsp @ 0x61ed55e03b40] getaddrinfo(): Name or service not known
Stream found at 15:00:20
#####################
[rtsp @ 0x61ed5a42aa00] getaddrinfo(): Name or service not known
[rtsp @ 0x61ed5a42aa00] getaddrinfo(): Name or service not known
[h264 @ 0x61ed5bc6f080] error while decoding MB 95 52, bytestream -8
[h264 @ 0x61ed5a637200] left block unavailable for requested intra mode
[h264 @ 0x61ed5a637200] error while decoding MB 0 6, bytestream 202025
[h264 @ 0x61ed568c6940] error while decoding MB 16 26, bytestream -5
[h264 @ 0x61ed59694a40] left block unavailable for requested intra mode
[h264 @ 0x61ed59694a40] error while decoding MB 0 30, bytestream 118170
[h264 @ 0x61ed58296140] error while decoding MB 26 60, bytestream -19
[h264 @ 0x61ed59694a40] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x61ed59694a40] error while decoding MB 0 62, bytestream 14121
[h264 @ 0x61ed59ed7080] error while decoding MB 80 23, bytestream -9
[h264 @ 0x61ed704e2380] left block unavailable for requested intra mode
[h264 @ 0x61ed704e2380] error while decoding MB 0 18, bytestream 146638
[h264 @ 0x61ed5a75d380] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x61ed5a75d380] error while decoding MB 0 39, bytestream 68371
[h264 @ 0x61ed59ed7080] error while decoding MB 55 65, bytestream -6
[h264 @ 0x61ed5a75d380] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x61ed5a75d380] error while decoding MB 0 47, bytestream 49945
[h264 @ 0x61ed59491500] error while decoding MB 72 50, bytestream -5
[h264 @ 0x61ed5bc6f080] error while decoding MB 19 66, bytestream -18
[h264 @ 0x61ed5bc6f080] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x61ed5bc6f080] error while decoding MB 0 51, bytestream 59875
[h264 @ 0x61ed5a637200] error while decoding MB 7 64, bytestream -20
[h264 @ 0x61ed5a637200] error while decoding MB 106 60, bytestream -44
[h264 @ 0x61ed5a75d380] error while decoding MB 35 61, bytestream -14
[h264 @ 0x61ed5a75d380] error while decoding MB 44 67, bytestream -10
[h264 @ 0x61ed5a75d380] error while decoding MB 100 56, bytestream -10
#####################
[rtsp @ 0x61ed59edb1c0] getaddrinfo(): Name or service not known
[rtsp @ 0x61ed59edb1c0] getaddrinfo(): Name or service not known
[h264 @ 0x61ed6970ad00] error while decoding MB 92 65, bytestream -6
[h264 @ 0x61ed55c36300] error while decoding MB 48 62, bytestream -14
[h264 @ 0x61ed584c5800] left block unavailable for requested intra mode
[h264 @ 0x61ed584c5800] error while decoding MB 0 34, bytestream 6858
[h264 @ 0x61ed5729d4c0] error while decoding MB 40 63, bytestream -19
[h264 @ 0x61ed55c36300] error while decoding MB 87 58, bytestream -5
[h264 @ 0x61ed55c36300] error while decoding MB 114 63, bytestream -17
[h264 @ 0x61ed5a28ef80] error while decoding MB 97 51, bytestream -5
[h264 @ 0x61ed5729d4c0] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x61ed5729d4c0] error while decoding MB 0 55, bytestream 31190
[h264 @ 0x61ed5a28ef80] error while decoding MB 75 49, bytestream -7
[h264 @ 0x61ed5829b0c0] left block unavailable for requested intra mode
[h264 @ 0x61ed5829b0c0] error while decoding MB 0 43, bytestream 5034
[h264 @ 0x61ed55c36300] error while decoding MB 47 62, bytestream -6
[h264 @ 0x61ed5a28ef80] error while decoding MB 72 62, bytestream -9
[h264 @ 0x61ed55d49d00] left block unavailable for requested intra mode
[h264 @ 0x61ed55d49d00] error while decoding MB 0 52, bytestream 2603
[h264 @ 0x61ed5a28ef80] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x61ed5a28ef80] error while decoding MB 0 4, bytestream 129884
[h264 @ 0x61ed592b2e40] error while decoding MB 62 64, bytestream -6
[h264 @ 0x61ed584c5800] left block unavailable for requested intra mode
[h264 @ 0x61ed584c5800] error while decoding MB 0 29, bytestream 7770
[h264 @ 0x61ed5a28ef80] left block unavailable for requested intra mode
[h264 @ 0x61ed5a28ef80] error while decoding MB 0 35, bytestream 81385
[h264 @ 0x61ed5829b0c0] error while decoding MB 101 65, bytestream -5
[h264 @ 0x61ed592b2e40] left block unavailable for requested intra mode
[h264 @ 0x61ed592b2e40] error while decoding MB 0 64, bytestream 5917
[h264 @ 0x61ed5729d4c0] error while decoding MB 112 66, bytestream -24
[h264 @ 0x61ed5729d4c0] error while decoding MB 58 62, bytestream -5
[h264 @ 0x61ed592b2e40] left block unavailable for requested intra mode
[h264 @ 0x61ed592b2e40] error while decoding MB 0 2, bytestream 863
[h264 @ 0x61ed55c36300] left block unavailable for requested intra mode
[h264 @ 0x61ed55c36300] error while decoding MB 0 55, bytestream 14032
[h264 @ 0x61ed55d49d00] left block unavailable for requested intra mode
[h264 @ 0x61ed55d49d00] error while decoding MB 0 20, bytestream 9766
[h264 @ 0x61ed592b2e40] error while decoding MB 72 60, bytestream -12
[h264 @ 0x61ed5829b0c0] error while decoding MB 6 66, bytestream -28
[h264 @ 0x61ed56a7c680] left block unavailable for requested intra mode
[h264 @ 0x61ed56a7c680] error while decoding MB 0 60, bytestream 8412
[h264 @ 0x61ed55d49d00] error while decoding MB 109 39, bytestream -11
[h264 @ 0x61ed5829b0c0] error while decoding MB 81 64, bytestream -20
[h264 @ 0x61ed584c5800] left block unavailable for requested intra mode
[h264 @ 0x61ed584c5800] error while decoding MB 0 60, bytestream 394
[h264 @ 0x61ed5829b0c0] error while decoding MB 4 59, bytestream -6
[h264 @ 0x61ed584c5800] error while decoding MB 30 54, bytestream -6
[h264 @ 0x61ed5829b0c0] left block unavailable for requested intra mode
[h264 @ 0x61ed5829b0c0] error while decoding MB 0 58, bytestream 8347
[h264 @ 0x61ed6970ad00] error while decoding MB 33 34, bytestream -7
[h264 @ 0x61ed584c5800] error while decoding MB 41 59, bytestream -6
[h264 @ 0x61ed5829b0c0] error while decoding MB 104 55, bytestream -17
[h264 @ 0x61ed56a7c680] error while decoding MB 83 60, bytestream -7
[h264 @ 0x61ed584c5800] error while decoding MB 68 66, bytestream -6
[h264 @ 0x61ed55c36300] left block unavailable for requested intra mode
[h264 @ 0x61ed55c36300] error while decoding MB 0 19, bytestream 10477
[h264 @ 0x61ed56f3a240] left block unavailable for requested intra mode
[h264 @ 0x61ed56f3a240] error while decoding MB 0 48, bytestream 3406
[h264 @ 0x61ed56a7c680] left block unavailable for requested intra mode
[h264 @ 0x61ed56a7c680] error while decoding MB 0 53, bytestream 4380
[h264 @ 0x61ed584c5800] error while decoding MB 117 52, bytestream -14
[h264 @ 0x61ed5aefd900] error while decoding MB 73 60, bytestream -12
[h264 @ 0x61ed56a7c680] error while decoding MB 110 15, bytestream -9
[h264 @ 0x61ed6970ad00] error while decoding MB 77 40, bytestream -16
[h264 @ 0x61ed57d40dc0] error while decoding MB 63 42, bytestream -12
[h264 @ 0x61ed56f3a240] error while decoding MB 112 60, bytestream -46
[rtsp @ 0x61ed59edb1c0] RTP: PT=60: bad cseq edd7 expected=e0d1
[h264 @ 0x61ed55c36300] error while decoding MB 112 66, bytestream -22
[h264 @ 0x61ed5729d4c0] error while decoding MB 24 63, bytestream -12
[h264 @ 0x61ed5aefd900] error while decoding MB 100 55, bytestream -12
[h264 @ 0x61ed5729d4c0] error while decoding MB 37 55, bytestream -6
[h264 @ 0x61ed5729d4c0] error while decoding MB 15 62, bytestream -8
[h264 @ 0x61ed5aefd900] error while decoding MB 67 65, bytestream -12
[h264 @ 0x61ed5aefd900] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x61ed5aefd900] error while decoding MB 0 48, bytestream 43694
[h264 @ 0x61ed5829b0c0] error while decoding MB 39 63, bytestream -5
[h264 @ 0x61ed55c36300] left block unavailable for requested intra mode
[h264 @ 0x61ed55c36300] error while decoding MB 0 60, bytestream -1
Processed 31598 frames before detection.
Processed 60520 frames before detection.
Saved successfully
Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
-- <re.Match object; span=(0, 8), match='06:26:49'>
Extracted Time: 06:26:49
06:26:49
Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
-- <re.Match object; span=(0, 8), match='15.51.18'>
Extracted Time: 15.51.18
15.51.18
***28-03-2025***
Trying start time: 06:00:00
Connecting to recorded video at 1743121800
URL: rtsp://admin:rmc%4012345@103.168.199.92:554/c1/b1743121800/e1743125400/replay/
[rtsp @ 0x61ed5a75ff00] getaddrinfo(): Name or service not known
[rtsp @ 0x61ed5a75ff00] getaddrinfo(): Name or service not known
Stream found at 06:00:00
Trying start time: 15:00:20
Connecting to recorded video at 1743154220
URL: rtsp://admin:rmc%4012345@103.168.199.92:554/c1/b1743154220/e1743163200/replay/
[rtsp @ 0x61ed5a75ff00] getaddrinfo(): Name or service not known
[ WARN:0@27399.056] global cap.cpp:175 open VIDEOIO(CV_IMAGES): raised OpenCV exception:

OpenCV(4.11.0) /io/opencv/modules/videoio/src/cap_images.cpp:237: error: (-5:Bad argument) CAP_IMAGES: error, expected '0?[1-9][du]' pattern, got: rtsp://admin:rmc%4012345@103.168.199.92:554/c1/b1743154220/e1743163200/replay/ in function 'icvExtractPattern'


Trying start time: 15:00:20
Connecting to recorded video at 1743154220
URL: rtsp://admin:rmc%4012345@103.168.199.92:554/c1/b1743154220/e1743163200/replay/
[rtsp @ 0x61ed5a75ff00] getaddrinfo(): Name or service not known
[ WARN:0@27399.676] global cap.cpp:175 open VIDEOIO(CV_IMAGES): raised OpenCV exception:

OpenCV(4.11.0) /io/opencv/modules/videoio/src/cap_images.cpp:237: error: (-5:Bad argument) CAP_IMAGES: error, expected '0?[1-9][du]' pattern, got: rtsp://admin:rmc%4012345@103.168.199.92:554/c1/b1743154220/e1743163200/replay/ in function 'icvExtractPattern'


Trying start time: 15:00:20
Connecting to recorded video at 1743154220
URL: rtsp://admin:rmc%4012345@103.168.199.92:554/c1/b1743154220/e1743163200/replay/
[rtsp @ 0x61ed5a75ff00] getaddrinfo(): Name or service not known
[ WARN:0@27400.326] global cap.cpp:175 open VIDEOIO(CV_IMAGES): raised OpenCV exception:

OpenCV(4.11.0) /io/opencv/modules/videoio/src/cap_images.cpp:237: error: (-5:Bad argument) CAP_IMAGES: error, expected '0?[1-9][du]' pattern, got: rtsp://admin:rmc%4012345@103.168.199.92:554/c1/b1743154220/e1743163200/replay/ in function 'icvExtractPattern'


Trying start time: 15:00:20
Connecting to recorded video at 1743154220
URL: rtsp://admin:rmc%4012345@103.168.199.92:554/c1/b1743154220/e1743163200/replay/
[rtsp @ 0x61ed5a75ff00] getaddrinfo(): Name or service not known
[rtsp @ 0x61ed5a75ff00] getaddrinfo(): Name or service not known
Stream found at 15:00:20
#####################
[rtsp @ 0x61ed5a427b80] getaddrinfo(): Name or service not known
[rtsp @ 0x61ed5a427b80] getaddrinfo(): Name or service not known
[h264 @ 0x61ed596b4980] error while decoding MB 51 19, bytestream -35
[h264 @ 0x61ed584b9b80] left block unavailable for requested intra mode
[h264 @ 0x61ed584b9b80] error while decoding MB 0 65, bytestream 7863
[h264 @ 0x61ed5c007b00] error while decoding MB 105 66, bytestream -36
[h264 @ 0x61ed570e6680] error while decoding MB 33 57, bytestream -13
[h264 @ 0x61ed570bfb40] error while decoding MB 118 67, bytestream -10
[h264 @ 0x61ed5c007b00] error while decoding MB 21 60, bytestream -39
[h264 @ 0x61ed570e6680] error while decoding MB 62 59, bytestream -5
[h264 @ 0x61ed570bfb40] error while decoding MB 52 66, bytestream -5
[h264 @ 0x61ed5c007b00] error while decoding MB 50 64, bytestream -11
[h264 @ 0x61ed570e6680] error while decoding MB 104 59, bytestream -17
[h264 @ 0x61ed570bfb40] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x61ed570bfb40] error while decoding MB 0 57, bytestream 4717
[h264 @ 0x61ed5c007b00] error while decoding MB 43 63, bytestream -15
[h264 @ 0x61ed570e6680] error while decoding MB 106 59, bytestream -41
[h264 @ 0x61ed570e6680] error while decoding MB 96 61, bytestream -22
[h264 @ 0x61ed570e6680] error while decoding MB 118 59, bytestream -13
[h264 @ 0x61ed570bfb40] left block unavailable for requested intra mode
[h264 @ 0x61ed570bfb40] error while decoding MB 0 60, bytestream 3665
[h264 @ 0x61ed5c007b00] error while decoding MB 66 55, bytestream -13
[h264 @ 0x61ed5745b300] error while decoding MB 53 55, bytestream -5
[h264 @ 0x61ed570bfb40] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x61ed570bfb40] error while decoding MB 0 45, bytestream 5806
[h264 @ 0x61ed5c007b00] error while decoding MB 4 58, bytestream -29
[h264 @ 0x61ed5745b300] error while decoding MB 47 18, bytestream -9
[h264 @ 0x61ed570e6680] error while decoding MB 99 64, bytestream -9
[h264 @ 0x61ed56a6ff40] error while decoding MB 102 6, bytestream -5
[h264 @ 0x61ed5c007b00] error while decoding MB 32 65, bytestream -13
[h264 @ 0x61ed5745b300] cabac decode of qscale diff failed at 102 60
[h264 @ 0x61ed5745b300] error while decoding MB 102 60, bytestream -6
[h264 @ 0x61ed5c007b00] error while decoding MB 90 60, bytestream -26
[h264 @ 0x61ed570e6680] error while decoding MB 22 58, bytestream -21
[h264 @ 0x61ed570bfb40] error while decoding MB 83 46, bytestream -5
[h264 @ 0x61ed5c007b00] error while decoding MB 6 55, bytestream -30
[h264 @ 0x61ed570e6680] left block unavailable for requested intra mode
[h264 @ 0x61ed570e6680] error while decoding MB 0 55, bytestream 1108
[h264 @ 0x61ed5c007b00] error while decoding MB 82 67, bytestream -8
[h264 @ 0x61ed5745b300] error while decoding MB 18 26, bytestream -10
[h264 @ 0x61ed570e6680] left block unavailable for requested intra mode
[h264 @ 0x61ed570e6680] error while decoding MB 0 53, bytestream 9695
[h264 @ 0x61ed570bfb40] left block unavailable for requested intra mode
[h264 @ 0x61ed570bfb40] error while decoding MB 0 49, bytestream 5407
[h264 @ 0x61ed570e6680] error while decoding MB 58 55, bytestream -27
[h264 @ 0x61ed5c007b00] left block unavailable for requested intra mode
[h264 @ 0x61ed5c007b00] error while decoding MB 0 8, bytestream 176115
[h264 @ 0x61ed570bfb40] error while decoding MB 70 49, bytestream -20
[h264 @ 0x61ed5c007b00] left block unavailable for requested intra mode
[h264 @ 0x61ed5c007b00] error while decoding MB 0 59, bytestream 8383
[h264 @ 0x61ed5745b300] error while decoding MB 114 6, bytestream -7
[h264 @ 0x61ed570e6680] error while decoding MB 40 65, bytestream -7
[h264 @ 0x61ed570bfb40] error while decoding MB 75 59, bytestream -19
[h264 @ 0x61ed5c007b00] left block unavailable for requested intra mode
[h264 @ 0x61ed5c007b00] error while decoding MB 0 60, bytestream 6616
[h264 @ 0x61ed570e6680] error while decoding MB 43 63, bytestream -13
[h264 @ 0x61ed5c007b00] error while decoding MB 63 67, bytestream -7
[h264 @ 0x61ed570e6680] error while decoding MB 117 59, bytestream -20
[h264 @ 0x61ed570e6680] error while decoding MB 86 64, bytestream -21
[h264 @ 0x61ed570e6680] error while decoding MB 45 67, bytestream -5
[h264 @ 0x61ed56a6ff40] error while decoding MB 27 51, bytestream -5
[h264 @ 0x61ed5c007b00] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x61ed5c007b00] error while decoding MB 0 54, bytestream 42331
[h264 @ 0x61ed570bfb40] left block unavailable for requested intra mode
[h264 @ 0x61ed570bfb40] error while decoding MB 0 34, bytestream 3913
[h264 @ 0x61ed5c007b00] error while decoding MB 18 66, bytestream -6
[h264 @ 0x61ed570bfb40] error while decoding MB 114 64, bytestream -12
[h264 @ 0x61ed69eb9ac0] error while decoding MB 53 63, bytestream -19
[h264 @ 0x61ed69eb9ac0] error while decoding MB 73 64, bytestream -14
[h264 @ 0x61ed5a28dac0] error while decoding MB 74 51, bytestream -23
[h264 @ 0x61ed570e6680] error while decoding MB 0 50, bytestream -6
[h264 @ 0x61ed596b4980] error while decoding MB 118 58, bytestream -35
[h264 @ 0x61ed5a28dac0] error while decoding MB 59 64, bytestream -5
[h264 @ 0x61ed596b4980] error while decoding MB 59 66, bytestream -18
[h264 @ 0x61ed69eb9ac0] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x61ed69eb9ac0] error while decoding MB 0 51, bytestream 6773
[h264 @ 0x61ed5a28dac0] left block unavailable for requested intra mode
[h264 @ 0x61ed5a28dac0] error while decoding MB 0 56, bytestream 20230
[h264 @ 0x61ed596b4980] error while decoding MB 74 58, bytestream -26
[h264 @ 0x61ed596b4980] left block unavailable for requested intra mode
[h264 @ 0x61ed596b4980] error while decoding MB 0 13, bytestream 190179
[h264 @ 0x61ed5bc54c80] error while decoding MB 33 59, bytestream -5
[h264 @ 0x61ed69eb9ac0] error while decoding MB 106 66, bytestream -16
[h264 @ 0x61ed596b4980] error while decoding MB 61 65, bytestream -28
[h264 @ 0x61ed5a28dac0] left block unavailable for requested intra mode
[h264 @ 0x61ed5a28dac0] error while decoding MB 0 57, bytestream 7016
[h264 @ 0x61ed596b4980] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x61ed596b4980] error while decoding MB 0 42, bytestream 6282
[h264 @ 0x61ed5a28dac0] error while decoding MB 71 66, bytestream -13
[h264 @ 0x61ed69eb9ac0] error while decoding MB 42 63, bytestream -22
[h264 @ 0x61ed596b4980] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x61ed596b4980] error while decoding MB 0 59, bytestream 8690
[h264 @ 0x61ed5a28dac0] error while decoding MB 18 62, bytestream -24
[h264 @ 0x61ed596b4980] error while decoding MB 1 54, bytestream -15
[h264 @ 0x61ed596b4980] left block unavailable for requested intra mode
[h264 @ 0x61ed596b4980] error while decoding MB 0 56, bytestream 4880
[h264 @ 0x61ed5a28dac0] error while decoding MB 82 66, bytestream -18
[h264 @ 0x61ed69eb9ac0] error while decoding MB 20 60, bytestream -23
[h264 @ 0x61ed5a28dac0] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x61ed5a28dac0] error while decoding MB 0 56, bytestream 11762
[h264 @ 0x61ed5a28dac0] error while decoding MB 103 63, bytestream -20
[h264 @ 0x61ed69eb9ac0] left block unavailable for requested intra mode
[h264 @ 0x61ed69eb9ac0] error while decoding MB 0 58, bytestream 10918
[h264 @ 0x61ed5a28dac0] error while decoding MB 31 66, bytestream -18
[h264 @ 0x61ed69eb9ac0] error while decoding MB 93 57, bytestream -11
[h264 @ 0x61ed5a28dac0] left block unavailable for requested intra mode
[h264 @ 0x61ed5a28dac0] error while decoding MB 0 40, bytestream 8118
[h264 @ 0x61ed5a28dac0] error while decoding MB 33 66, bytestream -9
[h264 @ 0x61ed69eb9ac0] error while decoding MB 67 64, bytestream -10
[h264 @ 0x61ed5a28dac0] error while decoding MB 31 67, bytestream -19
[h264 @ 0x61ed5a28dac0] left block unavailable for requested intra mode
[h264 @ 0x61ed5a28dac0] error while decoding MB 0 66, bytestream 3449
[h264 @ 0x61ed5a28dac0] error while decoding MB 78 64, bytestream -15
[h264 @ 0x61ed5a28dac0] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x61ed5a28dac0] error while decoding MB 0 52, bytestream 6872
[h264 @ 0x61ed596b4980] error while decoding MB 45 56, bytestream -5
[h264 @ 0x61ed596b4980] error while decoding MB 81 57, bytestream -7
[h264 @ 0x61ed56a6ff40] cabac decode of qscale diff failed at 94 23
[h264 @ 0x61ed56a6ff40] error while decoding MB 94 23, bytestream 7546
[h264 @ 0x61ed69eb9ac0] error while decoding MB 8 61, bytestream -28
[h264 @ 0x61ed596b4980] error while decoding MB 15 67, bytestream -5
[h264 @ 0x61ed5a28dac0] error while decoding MB 41 61, bytestream -5
[h264 @ 0x61ed69eb9ac0] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x61ed69eb9ac0] error while decoding MB 0 50, bytestream 59721
[h264 @ 0x61ed69eb9ac0] error while decoding MB 118 63, bytestream -15
[h264 @ 0x61ed596b4980] error while decoding MB 63 61, bytestream -5
[h264 @ 0x61ed570e6680] error while decoding MB 104 29, bytestream -9
[h264 @ 0x61ed69eb9ac0] error while decoding MB 78 50, bytestream -12
[h264 @ 0x61ed69eb9ac0] left block unavailable for requested intra mode
[h264 @ 0x61ed69eb9ac0] error while decoding MB 0 48, bytestream 65792
[h264 @ 0x61ed596b4980] error while decoding MB 39 63, bytestream -21
[h264 @ 0x61ed5a28dac0] error while decoding MB 94 62, bytestream -31
[h264 @ 0x61ed69eb9ac0] error while decoding MB 25 57, bytestream -28
#####################
[rtsp @ 0x61ed5b7ad240] getaddrinfo(): Name or service not known
[ WARN:0@29074.745] global cap.cpp:175 open VIDEOIO(CV_IMAGES): raised OpenCV exception:

OpenCV(4.11.0) /io/opencv/modules/videoio/src/cap_images.cpp:237: error: (-5:Bad argument) CAP_IMAGES: error, expected '0?[1-9][du]' pattern, got: rtsp://admin:rmc%4012345@103.168.199.92:554/c1/b1743154220/e1743163200/replay/ in function 'icvExtractPattern'


No person detected in the video.
Processed 33281 frames before detection.
No person detected in the video.
Saved successfully
Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
-- <re.Match object; span=(0, 9), match='06:27 :47'>
Extracted Time: 06:27 :47
06:27 :47
***29-03-2025***
Trying start time: 06:00:00
Connecting to recorded video at 1743208200
URL: rtsp://admin:rmc%4012345@103.168.199.92:554/c1/b1743208200/e1743211800/replay/
[rtsp @ 0x61ed5a1c1d40] getaddrinfo(): Name or service not known
[ WARN:0@29083.319] global cap.cpp:175 open VIDEOIO(CV_IMAGES): raised OpenCV exception:

OpenCV(4.11.0) /io/opencv/modules/videoio/src/cap_images.cpp:237: error: (-5:Bad argument) CAP_IMAGES: error, expected '0?[1-9][du]' pattern, got: rtsp://admin:rmc%4012345@103.168.199.92:554/c1/b1743208200/e1743211800/replay/ in function 'icvExtractPattern'


Trying start time: 06:00:00
Connecting to recorded video at 1743208200
URL: rtsp://admin:rmc%4012345@103.168.199.92:554/c1/b1743208200/e1743211800/replay/
[rtsp @ 0x61ed5a75ff00] getaddrinfo(): Name or service not known
[rtsp @ 0x61ed5a75ff00] getaddrinfo(): Name or service not known
Stream found at 06:00:00
Trying start time: 15:00:20
Connecting to recorded video at 1743240620
URL: rtsp://admin:rmc%4012345@103.168.199.92:554/c1/b1743240620/e1743249600/replay/
[rtsp @ 0x61ed5a75ff00] getaddrinfo(): Name or service not known
[rtsp @ 0x61ed5a75ff00] getaddrinfo(): Name or service not known
Stream found at 15:00:20
#####################
[rtsp @ 0x61ed5b581b80] getaddrinfo(): Name or service not known
[rtsp @ 0x61ed5b581b80] getaddrinfo(): Name or service not known
[h264 @ 0x61ed55aa7740] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x61ed55aa7740] error while decoding MB 0 21, bytestream 6134
[h264 @ 0x61ed57b86b00] error while decoding MB 36 64, bytestream -34
[h264 @ 0x61ed57b86b00] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x61ed57b86b00] error while decoding MB 0 61, bytestream 7513
[h264 @ 0x61ed59622540] error while decoding MB 78 51, bytestream 147
[h264 @ 0x61ed5a639e40] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x61ed5a639e40] error while decoding MB 0 46, bytestream 20976
[h264 @ 0x61ed5744e4c0] error while decoding MB 41 62, bytestream -22
[h264 @ 0x61ed5a476100] left block unavailable for requested intra mode
[h264 @ 0x61ed5a476100] error while decoding MB 0 59, bytestream 6709
[h264 @ 0x61ed56c629c0] error while decoding MB 69 66, bytestream -24
[h264 @ 0x61ed5a476100] error while decoding MB 64 64, bytestream -7
[h264 @ 0x61ed6d4105c0] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x61ed6d4105c0] error while decoding MB 0 60, bytestream 7900
[h264 @ 0x61ed59622540] error while decoding MB 83 66, bytestream -11
[h264 @ 0x61ed59622540] error while decoding MB 83 64, bytestream -23
[h264 @ 0x61ed59622540] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x61ed59622540] error while decoding MB 0 19, bytestream 174937
[h264 @ 0x61ed6d4105c0] left block unavailable for requested intra mode
[h264 @ 0x61ed6d4105c0] error while decoding MB 0 43, bytestream 3998
[h264 @ 0x61ed558af800] error while decoding MB 47 59, bytestream -7
[h264 @ 0x61ed59622540] left block unavailable for requested intra mode
[h264 @ 0x61ed59622540] error while decoding MB 0 2, bytestream 207238
[h264 @ 0x61ed6d4105c0] error while decoding MB 17 59, bytestream -22
[h264 @ 0x61ed558af800] error while decoding MB 115 63, bytestream -6
[h264 @ 0x61ed55dfd3c0] left block unavailable for requested intra mode
[h264 @ 0x61ed55dfd3c0] error while decoding MB 0 25, bytestream 8516
[h264 @ 0x61ed59622540] error while decoding MB 69 66, bytestream -17
[h264 @ 0x61ed6d4105c0] error while decoding MB 12 66, bytestream -5
[h264 @ 0x61ed5744e4c0] error while decoding MB 38 63, bytestream -7
[h264 @ 0x61ed6d4cb7c0] error while decoding MB 111 60, bytestream -16
[h264 @ 0x61ed55aa7740] left block unavailable for requested intra mode
[h264 @ 0x61ed55aa7740] error while decoding MB 0 59, bytestream 6116
[h264 @ 0x61ed6d4cb7c0] left block unavailable for requested intra mode
[h264 @ 0x61ed6d4cb7c0] error while decoding MB 0 55, bytestream 8574
[h264 @ 0x61ed55aa7740] error while decoding MB 82 61, bytestream -10
[h264 @ 0x61ed6d4cb7c0] error while decoding MB 30 64, bytestream -15
[h264 @ 0x61ed55aa7740] error while decoding MB 21 67, bytestream -13
[h264 @ 0x61ed558af800] error while decoding MB 25 44, bytestream -6
[h264 @ 0x61ed55dfd3c0] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x61ed55dfd3c0] error while decoding MB 0 52, bytestream 9364
[h264 @ 0x61ed6d4cb7c0] left block unavailable for requested intra mode
[h264 @ 0x61ed6d4cb7c0] error while decoding MB 0 27, bytestream 125722
[h264 @ 0x61ed6d4cb7c0] error while decoding MB 21 56, bytestream -18
[h264 @ 0x61ed6d4cb7c0] error while decoding MB 88 61, bytestream -7
[h264 @ 0x61ed55aa7740] error while decoding MB 48 62, bytestream -16
[h264 @ 0x61ed5a639e40] left block unavailable for requested intra mode
[h264 @ 0x61ed5a639e40] error while decoding MB 0 56, bytestream 10109
[h264 @ 0x61ed57b86b00] error while decoding MB 19 65, bytestream -18
[h264 @ 0x61ed5a639e40] error while decoding MB 86 64, bytestream -22
[h264 @ 0x61ed57b86b00] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x61ed57b86b00] error while decoding MB 0 49, bytestream 55619
[h264 @ 0x61ed57b86b00] error while decoding MB 16 59, bytestream -40
[h264 @ 0x61ed5744e4c0] error while decoding MB 96 59, bytestream -16
[h264 @ 0x61ed5a639e40] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x61ed5a639e40] error while decoding MB 0 49, bytestream 13051
[h264 @ 0x61ed5744e4c0] error while decoding MB 64 61, bytestream -13
[h264 @ 0x61ed5a639e40] error while decoding MB 94 59, bytestream -37
[h264 @ 0x61ed57b86b00] error while decoding MB 9 63, bytestream -15
[h264 @ 0x61ed55dfd3c0] error while decoding MB 109 34, bytestream -5
[h264 @ 0x61ed5744e4c0] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x61ed5744e4c0] error while decoding MB 0 53, bytestream 4646
[h264 @ 0x61ed5a639e40] error while decoding MB 55 58, bytestream -26
[h264 @ 0x61ed57b86b00] error while decoding MB 33 56, bytestream -21
[h264 @ 0x61ed57b86b00] error while decoding MB 96 64, bytestream -10
[h264 @ 0x61ed5744e4c0] error while decoding MB 36 41, bytestream -30
[h264 @ 0x61ed5a639e40] error while decoding MB 39 54, bytestream -9
[h264 @ 0x61ed55aa7740] error while decoding MB 52 18, bytestream -10
[h264 @ 0x61ed57b86b00] error while decoding MB 28 65, bytestream -16
[h264 @ 0x61ed5744e4c0] error while decoding MB 20 62, bytestream -20
[h264 @ 0x61ed5a639e40] left block unavailable for requested intra mode
[h264 @ 0x61ed5a639e40] error while decoding MB 0 55, bytestream 4494
[h264 @ 0x61ed5744e4c0] left block unavailable for requested intra mode
[h264 @ 0x61ed5744e4c0] error while decoding MB 0 49, bytestream 6038
[h264 @ 0x61ed5a639e40] error while decoding MB 40 66, bytestream -22
[h264 @ 0x61ed5744e4c0] error while decoding MB 26 61, bytestream -15
[h264 @ 0x61ed5a639e40] error while decoding MB 61 66, bytestream -11
[h264 @ 0x61ed5a639e40] left block unavailable for requested intra mode
[h264 @ 0x61ed5a639e40] error while decoding MB 0 63, bytestream 2593
[h264 @ 0x61ed57b86b00] error while decoding MB 63 63, bytestream -17
[h264 @ 0x61ed5744e4c0] error while decoding MB 68 55, bytestream -16
[h264 @ 0x61ed5744e4c0] error while decoding MB 83 66, bytestream -18
[h264 @ 0x61ed5a639e40] error while decoding MB 66 65, bytestream -20
[h264 @ 0x61ed5a639e40] error while decoding MB 111 65, bytestream -18
[h264 @ 0x61ed5a639e40] error while decoding MB 82 66, bytestream -15
[h264 @ 0x61ed57b86b00] left block unavailable for requested intra mode
[h264 @ 0x61ed57b86b00] error while decoding MB 0 53, bytestream 4826
[h264 @ 0x61ed558af800] error while decoding MB 110 62, bytestream -9
[h264 @ 0x61ed59622540] left block unavailable for requested intra mode
[h264 @ 0x61ed59622540] error while decoding MB 0 28, bytestream 6548
[h264 @ 0x61ed57b86b00] left block unavailable for requested intra mode
[h264 @ 0x61ed57b86b00] error while decoding MB 0 48, bytestream 6371
[h264 @ 0x61ed57b86b00] error while decoding MB 107 65, bytestream -22
[h264 @ 0x61ed5a639e40] error while decoding MB 72 66, bytestream -17
[h264 @ 0x61ed57b86b00] error while decoding MB 60 60, bytestream -26
[h264 @ 0x61ed5a639e40] error while decoding MB 69 60, bytestream -8
[h264 @ 0x61ed5a639e40] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x61ed5a639e40] error while decoding MB 0 25, bytestream 145756
[h264 @ 0x61ed5744e4c0] error while decoding MB 75 64, bytestream -13
[h264 @ 0x61ed5a639e40] error while decoding MB 100 58, bytestream -12
[h264 @ 0x61ed5a639e40] left block unavailable for requested intra mode
[h264 @ 0x61ed5a639e40] error while decoding MB 0 51, bytestream 60540
[h264 @ 0x61ed5948dec0] left block unavailable for requested intra mode
[h264 @ 0x61ed5948dec0] error while decoding MB 0 53, bytestream 7933
[h264 @ 0x61ed5a476100] error while decoding MB 34 66, bytestream -15
[h264 @ 0x61ed56c629c0] left block unavailable for requested intra mode
[h264 @ 0x61ed56c629c0] error while decoding MB 0 55, bytestream 10730
[h264 @ 0x61ed5a476100] left block unavailable for requested intra mode
[h264 @ 0x61ed5a476100] error while decoding MB 0 60, bytestream 3629
[h264 @ 0x61ed5a639e40] error while decoding MB 72 63, bytestream -9
[h264 @ 0x61ed56c629c0] error while decoding MB 5 57, bytestream -21
[h264 @ 0x61ed5a476100] error while decoding MB 12 65, bytestream -15
[h264 @ 0x61ed5948dec0] error while decoding MB 69 49, bytestream -20
[h264 @ 0x61ed5948dec0] error while decoding MB 13 62, bytestream -44
[h264 @ 0x61ed5a639e40] error while decoding MB 62 44, bytestream -7
[h264 @ 0x61ed56c629c0] error while decoding MB 99 66, bytestream -33
[h264 @ 0x61ed57b86b00] error while decoding MB 77 66, bytestream -5
[h264 @ 0x61ed5a476100] error while decoding MB 69 61, bytestream -28
[h264 @ 0x61ed56c629c0] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x61ed56c629c0] error while decoding MB 0 57, bytestream 5734
[h264 @ 0x61ed5a476100] left block unavailable for requested intra mode
[h264 @ 0x61ed5a476100] error while decoding MB 0 47, bytestream 10111
[h264 @ 0x61ed5a476100] left block unavailable for requested intra mode
[h264 @ 0x61ed5a476100] error while decoding MB 0 54, bytestream 77
[h264 @ 0x61ed5948dec0] error while decoding MB 98 65, bytestream -42
[h264 @ 0x61ed5a639e40] error while decoding MB 30 38, bytestream -5
[h264 @ 0x61ed56c629c0] error while decoding MB 56 67, bytestream -7
[h264 @ 0x61ed5948dec0] error while decoding MB 73 59, bytestream -20
[h264 @ 0x61ed56c629c0] error while decoding MB 53 62, bytestream -10
[h264 @ 0x61ed57b86b00] error while decoding MB 119 34, bytestream -7
[h264 @ 0x61ed5948dec0] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x61ed5948dec0] error while decoding MB 0 9, bytestream 125270
[h264 @ 0x61ed59622540] error while decoding MB 116 61, bytestream -20
[h264 @ 0x61ed6d4105c0] error while decoding MB 96 60, bytestream -18
[h264 @ 0x61ed6d4cb7c0] left block unavailable for requested intra mode
[h264 @ 0x61ed6d4cb7c0] error while decoding MB 0 54, bytestream 5028
[h264 @ 0x61ed55aa7740] error while decoding MB 4 58, bytestream -38
[h264 @ 0x61ed6d4cb7c0] left block unavailable for requested intra mode
[h264 @ 0x61ed6d4cb7c0] error while decoding MB 0 49, bytestream 8598
[h264 @ 0x61ed558af800] error while decoding MB 32 39, bytestream -8
[h264 @ 0x61ed55aa7740] error while decoding MB 76 64, bytestream -15
[h264 @ 0x61ed59622540] error while decoding MB 14 30, bytestream -5
[h264 @ 0x61ed55dfd3c0] error while decoding MB 15 61, bytestream -6
[h264 @ 0x61ed5948dec0] error while decoding MB 46 53, bytestream -12
[h264 @ 0x61ed5948dec0] error while decoding MB 32 60, bytestream -25
[h264 @ 0x61ed5948dec0] left block unavailable for requested intra mode
[h264 @ 0x61ed5948dec0] error while decoding MB 0 55, bytestream 7422
[h264 @ 0x61ed5a639e40] error while decoding MB 58 35, bytestream -9
[h264 @ 0x61ed56c629c0] left block unavailable for requested intra mode
[h264 @ 0x61ed56c629c0] error while decoding MB 0 45, bytestream 79778
[h264 @ 0x61ed5a476100] error while decoding MB 17 64, bytestream -7
[h264 @ 0x61ed5948dec0] error while decoding MB 9 64, bytestream -19
[h264 @ 0x61ed56c629c0] left block unavailable for requested intra mode
[h264 @ 0x61ed56c629c0] error while decoding MB 0 59, bytestream 4292
[h264 @ 0x61ed5948dec0] left block unavailable for requested intra mode
[h264 @ 0x61ed5948dec0] error while decoding MB 0 51, bytestream 5919
[h264 @ 0x61ed56c629c0] error while decoding MB 95 54, bytestream -32
[h264 @ 0x61ed5a476100] error while decoding MB 76 64, bytestream -11
[h264 @ 0x61ed56c629c0] error while decoding MB 6 58, bytestream -10
[h264 @ 0x61ed5948dec0] top block unavailable for requested intra mode
[h264 @ 0x61ed5948dec0] error while decoding MB 98 0, bytestream 171527
[h264 @ 0x61ed55aa7740] error while decoding MB 18 64, bytestream -6
[h264 @ 0x61ed55dfd3c0] error while decoding MB 14 66, bytestream -22
[h264 @ 0x61ed6d4cb7c0] error while decoding MB 34 66, bytestream -25
[h264 @ 0x61ed55aa7740] error while decoding MB 68 63, bytestream -18
[h264 @ 0x61ed55aa7740] error while decoding MB 117 60, bytestream -20
[h264 @ 0x61ed55dfd3c0] error while decoding MB 95 66, bytestream -20
[h264 @ 0x61ed5a476100] error while decoding MB 31 66, bytestream -5
[h264 @ 0x61ed6d4cb7c0] error while decoding MB 55 66, bytestream -14
[h264 @ 0x61ed55dfd3c0] error while decoding MB 104 65, bytestream -22
[h264 @ 0x61ed55aa7740] error while decoding MB 118 58, bytestream -39
[h264 @ 0x61ed6d4cb7c0] left block unavailable for requested intra mode
[h264 @ 0x61ed6d4cb7c0] error while decoding MB 0 39, bytestream 95375
[h264 @ 0x61ed558af800] error while decoding MB 116 14, bytestream -11
[h264 @ 0x61ed55dfd3c0] error while decoding MB 107 67, bytestream -11
[h264 @ 0x61ed6d4cb7c0] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x61ed6d4cb7c0] error while decoding MB 0 58, bytestream 5723
[h264 @ 0x61ed55aa7740] error while decoding MB 85 58, bytestream -50
[h264 @ 0x61ed6d4cb7c0] error while decoding MB 69 65, bytestream -12
[h264 @ 0x61ed55dfd3c0] error while decoding MB 52 61, bytestream -13
[h264 @ 0x61ed59622540] error while decoding MB 41 64, bytestream -5
[h264 @ 0x61ed6d4cb7c0] error while decoding MB 35 64, bytestream -20
[h264 @ 0x61ed55aa7740] error while decoding MB 21 64, bytestream -11
[h264 @ 0x61ed6d4cb7c0] error while decoding MB 15 65, bytestream -11
[h264 @ 0x61ed55dfd3c0] left block unavailable for requested intra mode
[h264 @ 0x61ed55dfd3c0] error while decoding MB 0 57, bytestream 10665
[h264 @ 0x61ed55aa7740] error while decoding MB 74 66, bytestream -18
[h264 @ 0x61ed6d4cb7c0] error while decoding MB 52 61, bytestream -5
[h264 @ 0x61ed6d4cb7c0] error while decoding MB 43 49, bytestream -28
[h264 @ 0x61ed55aa7740] error while decoding MB 17 65, bytestream -16
[h264 @ 0x61ed55dfd3c0] left block unavailable for requested intra mode
[h264 @ 0x61ed55dfd3c0] error while decoding MB 0 54, bytestream 8180
[h264 @ 0x61ed6d4105c0] left block unavailable for requested intra mode
[h264 @ 0x61ed6d4105c0] error while decoding MB 0 20, bytestream 6273
[h264 @ 0x61ed6d4cb7c0] error while decoding MB 25 57, bytestream -12
[h264 @ 0x61ed55aa7740] error while decoding MB 81 58, bytestream -12
[h264 @ 0x61ed6d4cb7c0] error while decoding MB 77 60, bytestream -30
[h264 @ 0x61ed55dfd3c0] error while decoding MB 84 66, bytestream -34
[h264 @ 0x61ed55aa7740] error while decoding MB 88 63, bytestream -14
[h264 @ 0x61ed55dfd3c0] error while decoding MB 117 59, bytestream -21
[h264 @ 0x61ed5a476100] error while decoding MB 77 61, bytestream -5
[h264 @ 0x61ed6d4cb7c0] error while decoding MB 60 63, bytestream -10
[h264 @ 0x61ed55dfd3c0] error while decoding MB 42 63, bytestream -34
[h264 @ 0x61ed55aa7740] error while decoding MB 53 63, bytestream -31
[h264 @ 0x61ed6d4cb7c0] error while decoding MB 69 66, bytestream -17
[h264 @ 0x61ed558af800] error while decoding MB 21 46, bytestream -7
[h264 @ 0x61ed55dfd3c0] error while decoding MB 78 64, bytestream -16
[h264 @ 0x61ed6d4cb7c0] left block unavailable for requested intra mode
[h264 @ 0x61ed6d4cb7c0] error while decoding MB 0 56, bytestream 30684
[h264 @ 0x61ed55dfd3c0] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x61ed55dfd3c0] error while decoding MB 0 18, bytestream 171200
[h264 @ 0x61ed55dfd3c0] error while decoding MB 101 65, bytestream -7
[h264 @ 0x61ed55dfd3c0] error while decoding MB 28 58, bytestream -20
[h264 @ 0x61ed6d4105c0] error while decoding MB 6 11, bytestream -9
[h264 @ 0x61ed55dfd3c0] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x61ed55dfd3c0] error while decoding MB 0 55, bytestream 13693
[h264 @ 0x61ed6d4cb7c0] error while decoding MB 15 62, bytestream -37
[h264 @ 0x61ed55dfd3c0] error while decoding MB 57 65, bytestream -22
[h264 @ 0x61ed55aa7740] error while decoding MB 87 64, bytestream -20
[h264 @ 0x61ed57b86b00] left block unavailable for requested intra mode
[h264 @ 0x61ed57b86b00] error while decoding MB 0 59, bytestream 2700
[h264 @ 0x61ed57b86b00] error while decoding MB 43 66, bytestream -29
[h264 @ 0x61ed57b86b00] error while decoding MB 116 61, bytestream -24
[h264 @ 0x61ed5744e4c0] error while decoding MB 84 50, bytestream -24
[h264 @ 0x61ed5a476100] error while decoding MB 100 65, bytestream -13
[h264 @ 0x61ed59622540] error while decoding MB 57 66, bytestream -24
[h264 @ 0x61ed6d4105c0] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x61ed6d4105c0] error while decoding MB 0 62, bytestream 8652
[h264 @ 0x61ed6d4105c0] error while decoding MB 14 66, bytestream -28
[h264 @ 0x61ed558af800] error while decoding MB 43 66, bytestream -22
[h264 @ 0x61ed59622540] error while decoding MB 82 66, bytestream -22
[h264 @ 0x61ed59622540] error while decoding MB 116 62, bytestream -18
[h264 @ 0x61ed558af800] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x61ed558af800] error while decoding MB 0 67, bytestream 546
[h264 @ 0x61ed6d4105c0] error while decoding MB 86 64, bytestream -26
[h264 @ 0x61ed558af800] error while decoding MB 119 67, bytestream -21
[h264 @ 0x61ed59622540] error while decoding MB 15 53, bytestream -24
[h264 @ 0x61ed55dfd3c0] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x61ed55dfd3c0] error while decoding MB 0 56, bytestream 12767
[h264 @ 0x61ed6d4cb7c0] error while decoding MB 114 64, bytestream -25
[h264 @ 0x61ed55aa7740] error while decoding MB 26 66, bytestream -17
[h264 @ 0x61ed6d4cb7c0] error while decoding MB 83 63, bytestream -26
[h264 @ 0x61ed55dfd3c0] error while decoding MB 106 64, bytestream -18
[h264 @ 0x61ed6d4cb7c0] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x61ed6d4cb7c0] error while decoding MB 0 50, bytestream 8999
[h264 @ 0x61ed55dfd3c0] error while decoding MB 105 54, bytestream -5
[h264 @ 0x61ed55dfd3c0] error while decoding MB 15 62, bytestream -33
[h264 @ 0x61ed55dfd3c0] left block unavailable for requested intra mode
[h264 @ 0x61ed55dfd3c0] error while decoding MB 0 56, bytestream 12686
#####################
[rtsp @ 0x61ed5b7ad240] getaddrinfo(): Name or service not known
[rtsp @ 0x61ed5b7ad240] getaddrinfo(): Name or service not known
[h264 @ 0x61ed570e49c0] error while decoding MB 92 49, bytestream -9
[h264 @ 0x61ed590345c0] left block unavailable for requested intra mode
[h264 @ 0x61ed590345c0] error while decoding MB 0 38, bytestream 63274
[h264 @ 0x61ed6970a6c0] error while decoding MB 6 63, bytestream -20
[h264 @ 0x61ed55e28100] left block unavailable for requested intra mode
[h264 @ 0x61ed55e28100] error while decoding MB 0 44, bytestream 60671
[h264 @ 0x61ed55e28100] error while decoding MB 36 66, bytestream -14
[h264 @ 0x61ed570e49c0] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x61ed570e49c0] error while decoding MB 0 36, bytestream 67492
[h264 @ 0x61ed584674c0] left block unavailable for requested intra mode
[h264 @ 0x61ed584674c0] error while decoding MB 0 46, bytestream 47319
[h264 @ 0x61ed56a8f9c0] error while decoding MB 107 56, bytestream -16
[h264 @ 0x61ed5a268040] left block unavailable for requested intra mode
[h264 @ 0x61ed5a268040] error while decoding MB 0 39, bytestream 62167
[h264 @ 0x61ed5a268040] error while decoding MB 99 56, bytestream -12
[h264 @ 0x61ed6970a6c0] error while decoding MB 10 66, bytestream -9
[h264 @ 0x61ed55e1b9c0] left block unavailable for requested intra mode
[h264 @ 0x61ed55e1b9c0] error while decoding MB 0 60, bytestream 10294
[h264 @ 0x61ed590345c0] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x61ed590345c0] error while decoding MB 0 41, bytestream 5081
[h264 @ 0x61ed590345c0] left block unavailable for requested intra mode
[h264 @ 0x61ed590345c0] error while decoding MB 0 54, bytestream 2115
[h264 @ 0x61ed590345c0] left block unavailable for requested intra mode
[h264 @ 0x61ed590345c0] error while decoding MB 0 30, bytestream 75529
[h264 @ 0x61ed55ff7d00] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x61ed55ff7d00] error while decoding MB 0 52, bytestream 31209
[h264 @ 0x61ed57534100] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x61ed57534100] error while decoding MB 0 37, bytestream 75815
[h264 @ 0x61ed55ff7d00] left block unavailable for requested intra mode
[h264 @ 0x61ed55ff7d00] error while decoding MB 0 56, bytestream 1661
[h264 @ 0x61ed55ff7d00] error while decoding MB 103 63, bytestream -26
[h264 @ 0x61ed590345c0] error while decoding MB 23 67, bytestream -30
[h264 @ 0x61ed57534100] error while decoding MB 93 62, bytestream -9
[h264 @ 0x61ed55e28100] error while decoding MB 107 61, bytestream -8
[h264 @ 0x61ed584674c0] error while decoding MB 101 61, bytestream -22
[h264 @ 0x61ed55e28100] error while decoding MB 42 64, bytestream -7
[h264 @ 0x61ed5a268040] error while decoding MB 76 67, bytestream -13
[h264 @ 0x61ed5a268040] error while decoding MB 88 65, bytestream -9
[h264 @ 0x61ed5a268040] error while decoding MB 116 63, bytestream -7
[h264 @ 0x61ed5a268040] error while decoding MB 57 60, bytestream -5
[h264 @ 0x61ed56a8f9c0] error while decoding MB 78 48, bytestream -10
[h264 @ 0x61ed59480c00] error while decoding MB 10 63, bytestream -28
[h264 @ 0x61ed55e1b9c0] error while decoding MB 41 61, bytestream -17
[h264 @ 0x61ed59480c00] error while decoding MB 74 60, bytestream -19
[h264 @ 0x61ed5b67f100] error while decoding MB 67 54, bytestream -7
[h264 @ 0x61ed59480c00] left block unavailable for requested intra mode
[h264 @ 0x61ed59480c00] error while decoding MB 0 19, bytestream 11989
[h264 @ 0x61ed5b67f100] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x61ed5b67f100] error while decoding MB 0 60, bytestream 6306
[h264 @ 0x61ed5a268040] error while decoding MB 45 2, bytestream -22
[h264 @ 0x61ed6970a6c0] error while decoding MB 61 4, bytestream -7
[h264 @ 0x61ed56a8f9c0] error while decoding MB 14 62, bytestream -6
[h264 @ 0x61ed570e49c0] error while decoding MB 17 65, bytestream -5
[h264 @ 0x61ed55ff7d00] cabac decode of qscale diff failed at 104 55
[h264 @ 0x61ed55ff7d00] error while decoding MB 104 55, bytestream 1119
[h264 @ 0x61ed5b67f100] error while decoding MB 43 55, bytestream -7
[h264 @ 0x61ed55ff7d00] error while decoding MB 3 55, bytestream -5
[h264 @ 0x61ed5a268040] error while decoding MB 84 49, bytestream -17
[h264 @ 0x61ed5b67f100] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x61ed5b67f100] error while decoding MB 0 51, bytestream 948
[h264 @ 0x61ed59480c00] left block unavailable for requested intra mode
[h264 @ 0x61ed59480c00] error while decoding MB 0 53, bytestream 4729
[h264 @ 0x61ed55e28100] error while decoding MB 98 19, bytestream -7
[h264 @ 0x61ed5a268040] error while decoding MB 43 45, bytestream -5
[h264 @ 0x61ed590345c0] left block unavailable for requested intra mode
[h264 @ 0x61ed590345c0] error while decoding MB 0 45, bytestream 3292
[h264 @ 0x61ed590345c0] error while decoding MB 30 49, bytestream -16
[h264 @ 0x61ed570e49c0] error while decoding MB 68 54, bytestream -39
[h264 @ 0x61ed55ff7d00] error while decoding MB 52 24, bytestream -5
[h264 @ 0x61ed6970a6c0] error while decoding MB 91 48, bytestream -28
[h264 @ 0x61ed6970a6c0] error while decoding MB 5 52, bytestream -34
[h264 @ 0x61ed55e28100] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x61ed55e28100] error while decoding MB 0 25, bytestream 87047
[h264 @ 0x61ed5b67f100] error while decoding MB 48 51, bytestream -8
[h264 @ 0x61ed55e1b9c0] error while decoding MB 78 55, bytestream -12
[h264 @ 0x61ed59480c00] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x61ed59480c00] error while decoding MB 0 64, bytestream 7952
[h264 @ 0x61ed55ff7d00] error while decoding MB 97 64, bytestream -6
[h264 @ 0x61ed5b67f100] error while decoding MB 26 57, bytestream -21
[h264 @ 0x61ed55e1b9c0] error while decoding MB 66 66, bytestream -6
[h264 @ 0x61ed56a8f9c0] error while decoding MB 45 18, bytestream -5
[h264 @ 0x61ed590345c0] error while decoding MB 87 58, bytestream -7
[h264 @ 0x61ed55ff7d00] error while decoding MB 114 66, bytestream -30
[h264 @ 0x61ed56a8f9c0] error while decoding MB 62 24, bytestream -7
[h264 @ 0x61ed5b67f100] error while decoding MB 27 20, bytestream -8
[h264 @ 0x61ed55ff7d00] left block unavailable for requested intra mode
[h264 @ 0x61ed55ff7d00] error while decoding MB 0 59, bytestream 7556
[h264 @ 0x61ed590345c0] error while decoding MB 113 65, bytestream -11
[h264 @ 0x61ed590345c0] left block unavailable for requested intra mode
[h264 @ 0x61ed590345c0] error while decoding MB 0 65, bytestream 1979
[h264 @ 0x61ed57534100] error while decoding MB 87 63, bytestream -6
[h264 @ 0x61ed5b67f100] left block unavailable for requested intra mode
[h264 @ 0x61ed5b67f100] error while decoding MB 0 53, bytestream 2610
[h264 @ 0x61ed570e49c0] error while decoding MB 45 59, bytestream -8
[h264 @ 0x61ed6970a6c0] error while decoding MB 108 64, bytestream -22
[h264 @ 0x61ed55e28100] error while decoding MB 111 50, bytestream -10
[h264 @ 0x61ed570e49c0] error while decoding MB 98 65, bytestream -27
[h264 @ 0x61ed55e28100] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x61ed55e28100] error while decoding MB 0 57, bytestream 4742
[h264 @ 0x61ed55e28100] error while decoding MB 57 56, bytestream -5
[h264 @ 0x61ed570e49c0] error while decoding MB 89 62, bytestream -30
[h264 @ 0x61ed584674c0] left block unavailable for requested intra mode
[h264 @ 0x61ed584674c0] error while decoding MB 0 53, bytestream 6734
[h264 @ 0x61ed5a268040] left block unavailable for requested intra mode
[h264 @ 0x61ed5a268040] error while decoding MB 0 10, bytestream 114496
[h264 @ 0x61ed56a8f9c0] error while decoding MB 45 55, bytestream -7
[h264 @ 0x61ed590345c0] error while decoding MB 98 66, bytestream -5
[h264 @ 0x61ed59480c00] error while decoding MB 84 48, bytestream -8
[h264 @ 0x61ed59480c00] error while decoding MB 70 66, bytestream -11
[h264 @ 0x61ed57534100] error while decoding MB 114 63, bytestream -20
[h264 @ 0x61ed55e1b9c0] error while decoding MB 75 30, bytestream -7
[h264 @ 0x61ed590345c0] error while decoding MB 40 62, bytestream -6
[h264 @ 0x61ed57534100] error while decoding MB 80 57, bytestream -10
[h264 @ 0x61ed55ff7d00] error while decoding MB 28 57, bytestream -44
[h264 @ 0x61ed57534100] error while decoding MB 38 66, bytestream -9
[h264 @ 0x61ed55ff7d00] error while decoding MB 59 58, bytestream -14
[h264 @ 0x61ed55ff7d00] error while decoding MB 34 64, bytestream -6
[h264 @ 0x61ed5b67f100] error while decoding MB 21 14, bytestream -7
[h264 @ 0x61ed590345c0] error while decoding MB 108 67, bytestream -8
[h264 @ 0x61ed57534100] error while decoding MB 41 64, bytestream -11
[h264 @ 0x61ed590345c0] error while decoding MB 22 64, bytestream -20
[h264 @ 0x61ed57534100] error while decoding MB 103 58, bytestream -22
[h264 @ 0x61ed590345c0] error while decoding MB 82 55, bytestream -14
[h264 @ 0x61ed590345c0] left block unavailable for requested intra mode
[h264 @ 0x61ed590345c0] error while decoding MB 0 26, bytestream 90051
[h264 @ 0x61ed57534100] error while decoding MB 27 67, bytestream -24
[h264 @ 0x61ed57534100] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x61ed57534100] error while decoding MB 0 40, bytestream 56910
[h264 @ 0x61ed55ff7d00] left block unavailable for requested intra mode
[h264 @ 0x61ed55ff7d00] error while decoding MB 0 44, bytestream 59110
[h264 @ 0x61ed57534100] error while decoding MB 86 64, bytestream -14
[h264 @ 0x61ed590345c0] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x61ed590345c0] error while decoding MB 0 57, bytestream 20808
[h264 @ 0x61ed55ff7d00] error while decoding MB 105 56, bytestream -18
[h264 @ 0x61ed5a268040] left block unavailable for requested intra mode
[h264 @ 0x61ed5a268040] error while decoding MB 0 26, bytestream 6704
[h264 @ 0x61ed59480c00] left block unavailable for requested intra mode
[h264 @ 0x61ed59480c00] error while decoding MB 0 16, bytestream 134413
[h264 @ 0x61ed55e1b9c0] left block unavailable for requested intra mode
[h264 @ 0x61ed55e1b9c0] error while decoding MB 0 53, bytestream 13954
[h264 @ 0x61ed5b67f100] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x61ed5b67f100] error while decoding MB 0 61, bytestream 8626
[h264 @ 0x61ed5b67f100] left block unavailable for requested intra mode
[h264 @ 0x61ed5b67f100] error while decoding MB 0 28, bytestream 79545
[h264 @ 0x61ed5b67f100] error while decoding MB 65 61, bytestream -6
[h264 @ 0x61ed59480c00] error while decoding MB 65 61, bytestream -14
[h264 @ 0x61ed584674c0] error while decoding MB 86 41, bytestream -8
[h264 @ 0x61ed55e1b9c0] error while decoding MB 82 66, bytestream -6
[h264 @ 0x61ed59480c00] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x61ed59480c00] error while decoding MB 0 63, bytestream 11218
[h264 @ 0x61ed55ff7d00] error while decoding MB 118 57, bytestream -14
[h264 @ 0x61ed55ff7d00] error while decoding MB 66 66, bytestream -5
[h264 @ 0x61ed57534100] error while decoding MB 116 61, bytestream -16
[h264 @ 0x61ed590345c0] error while decoding MB 64 62, bytestream -18
[h264 @ 0x61ed55ff7d00] left block unavailable for requested intra mode
[h264 @ 0x61ed55ff7d00] error while decoding MB 0 62, bytestream 6468
[h264 @ 0x61ed57534100] error while decoding MB 89 63, bytestream -22
[h264 @ 0x61ed590345c0] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x61ed590345c0] error while decoding MB 0 9, bytestream 141308
[h264 @ 0x61ed55ff7d00] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x61ed55ff7d00] error while decoding MB 0 51, bytestream 10336
[h264 @ 0x61ed590345c0] error while decoding MB 117 51, bytestream -10
[h264 @ 0x61ed55ff7d00] error while decoding MB 91 65, bytestream -12
[h264 @ 0x61ed57534100] error while decoding MB 81 59, bytestream -20
[h264 @ 0x61ed57534100] error while decoding MB 19 44, bytestream -12
[h264 @ 0x61ed55ff7d00] left block unavailable for requested intra mode
[h264 @ 0x61ed55ff7d00] error while decoding MB 0 53, bytestream 2730
[h264 @ 0x61ed57534100] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x61ed57534100] error while decoding MB 0 53, bytestream 1864
[h264 @ 0x61ed590345c0] error while decoding MB 116 54, bytestream -12
[h264 @ 0x61ed55ff7d00] left block unavailable for requested intra mode
[h264 @ 0x61ed55ff7d00] error while decoding MB 0 27, bytestream 81961
[h264 @ 0x61ed57534100] error while decoding MB 49 60, bytestream -20
[h264 @ 0x61ed55e28100] error while decoding MB 35 41, bytestream -7
[h264 @ 0x61ed55e28100] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x61ed55e28100] error while decoding MB 0 44, bytestream 2714
[h264 @ 0x61ed55e1b9c0] error while decoding MB 47 54, bytestream -24
[h264 @ 0x61ed6970a6c0] error while decoding MB 44 63, bytestream -6
[h264 @ 0x61ed5b67f100] error while decoding MB 34 44, bytestream -8
[h264 @ 0x61ed5a268040] error while decoding MB 62 4, bytestream -5
[h264 @ 0x61ed55ff7d00] left block unavailable for requested intra mode
[h264 @ 0x61ed55ff7d00] error while decoding MB 0 45, bytestream 4753
[h264 @ 0x61ed55e1b9c0] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x61ed55e1b9c0] error while decoding MB 0 52, bytestream 1400
[h264 @ 0x61ed590345c0] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x61ed590345c0] error while decoding MB 0 43, bytestream 40487
[h264 @ 0x61ed5a268040] error while decoding MB 90 66, bytestream -5
[h264 @ 0x61ed55ff7d00] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x61ed55ff7d00] error while decoding MB 0 10, bytestream 68316
[h264 @ 0x61ed55ff7d00] left block unavailable for requested intra mode
[h264 @ 0x61ed55ff7d00] error while decoding MB 0 45, bytestream 11056
[h264 @ 0x61ed55e1b9c0] error while decoding MB 119 58, bytestream -7
[h264 @ 0x61ed57534100] error while decoding MB 81 49, bytestream -9
[h264 @ 0x61ed6970a6c0] error while decoding MB 105 58, bytestream -28
[h264 @ 0x61ed570e49c0] error while decoding MB 68 48, bytestream -26
[h264 @ 0x61ed590345c0] error while decoding MB 82 18, bytestream -5
[h264 @ 0x61ed55e28100] error while decoding MB 11 50, bytestream -26
[h264 @ 0x61ed55ff7d00] error while decoding MB 3 43, bytestream -8
[h264 @ 0x61ed5a268040] error while decoding MB 118 48, bytestream -20
[h264 @ 0x61ed56a8f9c0] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x61ed56a8f9c0] error while decoding MB 0 40, bytestream 4910
[h264 @ 0x61ed584674c0] left block unavailable for requested intra mode
[h264 @ 0x61ed584674c0] error while decoding MB 0 49, bytestream 2232
[h264 @ 0x61ed55e1b9c0] error while decoding MB 40 63, bytestream -10
[h264 @ 0x61ed59480c00] left block unavailable for requested intra mode
[h264 @ 0x61ed59480c00] error while decoding MB 0 47, bytestream 4110
[h264 @ 0x61ed584674c0] error while decoding MB 70 57, bytestream -6
[h264 @ 0x61ed570e49c0] error while decoding MB 51 64, bytestream -6
[h264 @ 0x61ed5b67f100] error while decoding MB 85 44, bytestream -16
[h264 @ 0x61ed57534100] left block unavailable for requested intra mode
[h264 @ 0x61ed57534100] error while decoding MB 0 39, bytestream 2948
[h264 @ 0x61ed5a268040] left block unavailable for requested intra mode
[h264 @ 0x61ed5a268040] error while decoding MB 0 14, bytestream 78004
[h264 @ 0x61ed6970a6c0] error while decoding MB 89 54, bytestream -5
[h264 @ 0x61ed55e1b9c0] left block unavailable for requested intra mode
[h264 @ 0x61ed55e1b9c0] error while decoding MB 0 48, bytestream 3802
[h264 @ 0x61ed570e49c0] left block unavailable for requested intra mode
[h264 @ 0x61ed570e49c0] error while decoding MB 0 54, bytestream 2460
[h264 @ 0x61ed590345c0] error while decoding MB 2 46, bytestream -6
[h264 @ 0x61ed59480c00] error while decoding MB 102 53, bytestream -5
[h264 @ 0x61ed5a268040] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x61ed5a268040] error while decoding MB 0 16, bytestream 63389
[h264 @ 0x61ed59480c00] error while decoding MB 6 62, bytestream -24
[h264 @ 0x61ed584674c0] error while decoding MB 5 65, bytestream -5
[h264 @ 0x61ed5a268040] left block unavailable for requested intra mode
[h264 @ 0x61ed5a268040] error while decoding MB 0 23, bytestream 14088
[h264 @ 0x61ed55ff7d00] error while decoding MB 96 42, bytestream -8
[h264 @ 0x61ed57534100] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x61ed57534100] error while decoding MB 0 57, bytestream 6760
[h264 @ 0x61ed55e28100] error while decoding MB 110 60, bytestream -36
[h264 @ 0x61ed55ff7d00] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x61ed55ff7d00] error while decoding MB 0 17, bytestream 12546
[h264 @ 0x61ed6970a6c0] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x61ed6970a6c0] error while decoding MB 0 18, bytestream 86430
[h264 @ 0x61ed57534100] error while decoding MB 34 40, bytestream -5
[h264 @ 0x61ed55e1b9c0] error while decoding MB 62 14, bytestream -15
[h264 @ 0x61ed59480c00] error while decoding MB 67 51, bytestream -30
[h264 @ 0x61ed57534100] left block unavailable for requested intra mode
[h264 @ 0x61ed57534100] error while decoding MB 0 16, bytestream 11546
[h264 @ 0x61ed55ff7d00] error while decoding MB 86 60, bytestream -9
[h264 @ 0x61ed57534100] error while decoding MB 40 56, bytestream -28
[h264 @ 0x61ed6970a6c0] error while decoding MB 111 58, bytestream -18
[h264 @ 0x61ed570e49c0] error while decoding MB 34 66, bytestream -10
[h264 @ 0x61ed55e28100] error while decoding MB 112 47, bytestream -12
[h264 @ 0x61ed6970a6c0] left block unavailable for requested intra mode
[h264 @ 0x61ed6970a6c0] error while decoding MB 0 21, bytestream 101856
[h264 @ 0x61ed56a8f9c0] error while decoding MB 87 60, bytestream -8
[h264 @ 0x61ed59480c00] error while decoding MB 21 53, bytestream -22
[h264 @ 0x61ed55e28100] error while decoding MB 102 27, bytestream -22
[h264 @ 0x61ed5a268040] error while decoding MB 29 49, bytestream -8
[h264 @ 0x61ed56a8f9c0] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x61ed56a8f9c0] error while decoding MB 0 27, bytestream 43672
[h264 @ 0x61ed584674c0] left block unavailable for requested intra mode
[h264 @ 0x61ed584674c0] error while decoding MB 0 6, bytestream 102544
[h264 @ 0x61ed5b67f100] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x61ed5b67f100] error while decoding MB 0 50, bytestream 1608
[h264 @ 0x61ed570e49c0] error while decoding MB 93 47, bytestream -12
[h264 @ 0x61ed584674c0] left block unavailable for requested intra mode
[h264 @ 0x61ed584674c0] error while decoding MB 0 54, bytestream 3302
[h264 @ 0x61ed56a8f9c0] error while decoding MB 114 63, bytestream -7
[h264 @ 0x61ed5a268040] error while decoding MB 81 50, bytestream -14
[h264 @ 0x61ed55e28100] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x61ed55e28100] error while decoding MB 0 60, bytestream 995
[h264 @ 0x61ed56a8f9c0] left block unavailable for requested intra mode
[h264 @ 0x61ed56a8f9c0] error while decoding MB 0 33, bytestream 38098
[h264 @ 0x61ed5b67f100] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x61ed5b67f100] error while decoding MB 0 41, bytestream 4872
[h264 @ 0x61ed55e1b9c0] left block unavailable for requested intra mode
[h264 @ 0x61ed55e1b9c0] error while decoding MB 0 20, bytestream 11529
[h264 @ 0x61ed6970a6c0] left block unavailable for requested intra mode
[h264 @ 0x61ed6970a6c0] error while decoding MB 0 42, bytestream 4465
[h264 @ 0x61ed570e49c0] left block unavailable for requested intra mode
[h264 @ 0x61ed570e49c0] error while decoding MB 0 60, bytestream 7707
[h264 @ 0x61ed590345c0] error while decoding MB 74 60, bytestream -7
[h264 @ 0x61ed5a268040] left block unavailable for requested intra mode
[h264 @ 0x61ed5a268040] error while decoding MB 0 16, bytestream 46050
[h264 @ 0x61ed55e1b9c0] error while decoding MB 94 50, bytestream -24
[h264 @ 0x61ed59480c00] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x61ed59480c00] error while decoding MB 0 44, bytestream 31034
[h264 @ 0x61ed55e28100] left block unavailable for requested intra mode
[h264 @ 0x61ed55e28100] error while decoding MB 0 45, bytestream 2704
[h264 @ 0x61ed55ff7d00] error while decoding MB 87 33, bytestream -5
[h264 @ 0x61ed6970a6c0] left block unavailable for requested intra mode
[h264 @ 0x61ed6970a6c0] error while decoding MB 0 45, bytestream 3754
[h264 @ 0x61ed584674c0] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x61ed584674c0] error while decoding MB 0 59, bytestream 15370
[h264 @ 0x61ed57534100] left block unavailable for requested intra mode
[h264 @ 0x61ed57534100] error while decoding MB 0 57, bytestream 1388
[h264 @ 0x61ed5a268040] left block unavailable for requested intra mode
[h264 @ 0x61ed5a268040] error while decoding MB 0 3, bytestream 112724
[h264 @ 0x61ed55e1b9c0] error while decoding MB 71 14, bytestream -5
[h264 @ 0x61ed56a8f9c0] error while decoding MB 44 4, bytestream -9
[h264 @ 0x61ed55ff7d00] error while decoding MB 46 63, bytestream -12
[h264 @ 0x61ed57534100] error while decoding MB 5 61, bytestream -12
[h264 @ 0x61ed590345c0] left block unavailable for requested intra mode
[h264 @ 0x61ed590345c0] error while decoding MB 0 55, bytestream 22333
[h264 @ 0x61ed59480c00] error while decoding MB 32 20, bytestream -7
[h264 @ 0x61ed584674c0] error while decoding MB 74 64, bytestream -6
[h264 @ 0x61ed5b67f100] error while decoding MB 46 19, bytestream -6
[h264 @ 0x61ed5a268040] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x61ed5a268040] error while decoding MB 0 35, bytestream 16322
[h264 @ 0x61ed6970a6c0] error while decoding MB 39 63, bytestream -5
[h264 @ 0x61ed56a8f9c0] left block unavailable for requested intra mode
[h264 @ 0x61ed56a8f9c0] error while decoding MB 0 48, bytestream 4128
[h264 @ 0x61ed55ff7d00] error while decoding MB 3 54, bytestream -6
[h264 @ 0x61ed5a268040] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x61ed5a268040] error while decoding MB 0 27, bytestream 99657
[h264 @ 0x61ed55e1b9c0] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x61ed55e1b9c0] error while decoding MB 0 48, bytestream 3330
[h264 @ 0x61ed59480c00] error while decoding MB 4 65, bytestream -6
[h264 @ 0x61ed5b67f100] error while decoding MB 106 50, bytestream -16
[h264 @ 0x61ed55e1b9c0] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x61ed55e1b9c0] error while decoding MB 0 44, bytestream 14434
[h264 @ 0x61ed59480c00] error while decoding MB 3 56, bytestream -18
[h264 @ 0x61ed55e1b9c0] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x61ed55e1b9c0] error while decoding MB 0 42, bytestream 5956
[h264 @ 0x61ed5b67f100] error while decoding MB 50 44, bytestream -8
[h264 @ 0x61ed55e1b9c0] error while decoding MB 69 51, bytestream -36
[h264 @ 0x61ed59480c00] left block unavailable for requested intra mode
[h264 @ 0x61ed59480c00] error while decoding MB 0 48, bytestream 4266
[h264 @ 0x61ed5b67f100] error while decoding MB 27 55, bytestream -40
[h264 @ 0x61ed5a268040] error while decoding MB 104 21, bytestream -5
[h264 @ 0x61ed55e1b9c0] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x61ed55e1b9c0] error while decoding MB 0 25, bytestream 72117
[h264 @ 0x61ed55ff7d00] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x61ed55ff7d00] error while decoding MB 0 29, bytestream 6988
[h264 @ 0x61ed57534100] error while decoding MB 117 66, bytestream -5
[h264 @ 0x61ed55e1b9c0] error while decoding MB 76 65, bytestream -8
[h264 @ 0x61ed59480c00] error while decoding MB 118 63, bytestream -5
[h264 @ 0x61ed570e49c0] error while decoding MB 119 54, bytestream -22
[h264 @ 0x61ed55e28100] left block unavailable for requested intra mode
[h264 @ 0x61ed55e28100] error while decoding MB 0 45, bytestream 39392
[h264 @ 0x61ed5a268040] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x61ed5a268040] error while decoding MB 0 34, bytestream 6834
[h264 @ 0x61ed56a8f9c0] error while decoding MB 76 50, bytestream -6
[h264 @ 0x61ed55e28100] left block unavailable for requested intra mode
[h264 @ 0x61ed55e28100] error while decoding MB 0 48, bytestream 3217
[h264 @ 0x61ed5b67f100] error while decoding MB 66 47, bytestream -24
[h264 @ 0x61ed59480c00] error while decoding MB 87 59, bytestream -5
[h264 @ 0x61ed55ff7d00] error while decoding MB 28 56, bytestream -32
[h264 @ 0x61ed6970a6c0] error while decoding MB 85 51, bytestream -13
[h264 @ 0x61ed57534100] error while decoding MB 23 65, bytestream -5
[h264 @ 0x61ed570e49c0] left block unavailable for requested intra mode
[h264 @ 0x61ed570e49c0] error while decoding MB 0 47, bytestream 36874
[h264 @ 0x61ed5a268040] left block unavailable for requested intra mode
[h264 @ 0x61ed5a268040] error while decoding MB 0 17, bytestream 12364
[h264 @ 0x61ed584674c0] error while decoding MB 91 65, bytestream -18
[h264 @ 0x61ed56a8f9c0] left block unavailable for requested intra mode
[h264 @ 0x61ed56a8f9c0] error while decoding MB 0 47, bytestream 4988
[h264 @ 0x61ed55e1b9c0] error while decoding MB 54 65, bytestream -5
[h264 @ 0x61ed590345c0] error while decoding MB 5 58, bytestream -48
[h264 @ 0x61ed59480c00] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x61ed59480c00] error while decoding MB 0 28, bytestream 6675
[h264 @ 0x61ed5a268040] error while decoding MB 71 42, bytestream -6
[h264 @ 0x61ed55e1b9c0] error while decoding MB 71 63, bytestream -5
[h264 @ 0x61ed6970a6c0] error while decoding MB 40 63, bytestream -6
[h264 @ 0x61ed590345c0] error while decoding MB 63 38, bytestream -16
[h264 @ 0x61ed55ff7d00] error while decoding MB 102 54, bytestream -18
[h264 @ 0x61ed5b67f100] error while decoding MB 26 65, bytestream -6
[h264 @ 0x61ed57534100] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x61ed57534100] error while decoding MB 0 63, bytestream 2724
[h264 @ 0x61ed55e1b9c0] error while decoding MB 93 54, bytestream -7
[h264 @ 0x61ed59480c00] error while decoding MB 70 65, bytestream -9
[h264 @ 0x61ed55ff7d00] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x61ed55ff7d00] error while decoding MB 0 47, bytestream 364
[h264 @ 0x61ed57534100] error while decoding MB 69 48, bytestream -46
[h264 @ 0x61ed55e1b9c0] error while decoding MB 63 65, bytestream -6
[h264 @ 0x61ed55e1b9c0] left block unavailable for requested intra mode
[h264 @ 0x61ed55e1b9c0] error while decoding MB 0 32, bytestream 5726
[h264 @ 0x61ed590345c0] left block unavailable for requested intra mode
[h264 @ 0x61ed590345c0] error while decoding MB 0 48, bytestream 4754
[h264 @ 0x61ed57534100] error while decoding MB 8 30, bytestream -7
[h264 @ 0x61ed6970a6c0] error while decoding MB 39 24, bytestream -9
[h264 @ 0x61ed57534100] left block unavailable for requested intra mode
[h264 @ 0x61ed57534100] error while decoding MB 0 37, bytestream 6947
[h264 @ 0x61ed56a8f9c0] left block unavailable for requested intra mode
[h264 @ 0x61ed56a8f9c0] error while decoding MB 0 50, bytestream 3164
[h264 @ 0x61ed590345c0] error while decoding MB 70 35, bytestream -5
[h264 @ 0x61ed590345c0] left block unavailable for requested intra mode
[h264 @ 0x61ed590345c0] error while decoding MB 0 39, bytestream 5258
[h264 @ 0x61ed57534100] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x61ed57534100] error while decoding MB 0 52, bytestream 4074
[h264 @ 0x61ed590345c0] left block unavailable for requested intra mode
[h264 @ 0x61ed590345c0] error while decoding MB 0 40, bytestream 4302
[h264 @ 0x61ed55e1b9c0] error while decoding MB 72 56, bytestream -9
[h264 @ 0x61ed570e49c0] error while decoding MB 105 67, bytestream -6
[h264 @ 0x61ed584674c0] left block unavailable for requested intra mode
[h264 @ 0x61ed584674c0] error while decoding MB 0 37, bytestream 1878
[h264 @ 0x61ed5b67f100] error while decoding MB 98 67, bytestream -6
[h264 @ 0x61ed55e1b9c0] error while decoding MB 25 58, bytestream -34
[h264 @ 0x61ed56a8f9c0] error while decoding MB 109 15, bytestream -7
[h264 @ 0x61ed5b67f100] error while decoding MB 98 64, bytestream -12
[h264 @ 0x61ed55e28100] left block unavailable for requested intra mode
[h264 @ 0x61ed55e28100] error while decoding MB 0 39, bytestream 4634
[h264 @ 0x61ed6970a6c0] error while decoding MB 109 65, bytestream -36
[h264 @ 0x61ed55e28100] left block unavailable for requested intra mode
[h264 @ 0x61ed55e28100] error while decoding MB 0 37, bytestream 396
[h264 @ 0x61ed5b67f100] error while decoding MB 5 58, bytestream -34
[h264 @ 0x61ed55e1b9c0] left block unavailable for requested intra mode
[h264 @ 0x61ed55e1b9c0] error while decoding MB 0 8, bytestream 78494
[h264 @ 0x61ed584674c0] error while decoding MB 90 52, bytestream -10
[h264 @ 0x61ed5a268040] error while decoding MB 39 64, bytestream -16
[h264 @ 0x61ed56a8f9c0] left block unavailable for requested intra mode
[h264 @ 0x61ed56a8f9c0] error while decoding MB 0 61, bytestream 4818
[h264 @ 0x61ed584674c0] error while decoding MB 99 49, bytestream -8
[h264 @ 0x61ed5a268040] error while decoding MB 8 67, bytestream -6
[h264 @ 0x61ed6970a6c0] error while decoding MB 30 49, bytestream -6
[h264 @ 0x61ed57534100] error while decoding MB 103 54, bytestream -8
[h264 @ 0x61ed590345c0] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x61ed590345c0] error while decoding MB 0 43, bytestream 5074
[h264 @ 0x61ed5b67f100] error while decoding MB 36 62, bytestream -5
[h264 @ 0x61ed57534100] left block unavailable for requested intra mode
[h264 @ 0x61ed57534100] error while decoding MB 0 41, bytestream 5428
[h264 @ 0x61ed590345c0] error while decoding MB 67 54, bytestream -16
[h264 @ 0x61ed55ff7d00] left block unavailable for requested intra mode
[h264 @ 0x61ed55ff7d00] error while decoding MB 0 50, bytestream 23760
[h264 @ 0x61ed584674c0] left block unavailable for requested intra mode
[h264 @ 0x61ed584674c0] error while decoding MB 0 18, bytestream 11290
[h264 @ 0x61ed570e49c0] error while decoding MB 9 16, bytestream -9
[h264 @ 0x61ed55e28100] error while decoding MB 105 15, bytestream -9
[h264 @ 0x61ed57534100] left block unavailable for requested intra mode
[h264 @ 0x61ed57534100] error while decoding MB 0 22, bytestream 14619
[h264 @ 0x61ed59480c00] left block unavailable for requested intra mode
[h264 @ 0x61ed59480c00] error while decoding MB 0 36, bytestream 6870
[h264 @ 0x61ed570e49c0] left block unavailable for requested intra mode
[h264 @ 0x61ed570e49c0] error while decoding MB 0 30, bytestream 4210
[h264 @ 0x61ed55e28100] left block unavailable for requested intra mode
[h264 @ 0x61ed55e28100] error while decoding MB 0 55, bytestream 2976
[h264 @ 0x61ed55ff7d00] error while decoding MB 43 36, bytestream -14
[h264 @ 0x61ed59480c00] left block unavailable for requested intra mode
[h264 @ 0x61ed59480c00] error while decoding MB 0 3, bytestream 104912
[h264 @ 0x61ed55e1b9c0] left block unavailable for requested intra mode
[h264 @ 0x61ed55e1b9c0] error while decoding MB 0 38, bytestream 3350
[h264 @ 0x61ed59480c00] error while decoding MB 110 49, bytestream -8
[h264 @ 0x61ed55ff7d00] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x61ed55ff7d00] error while decoding MB 0 16, bytestream 91926
[h264 @ 0x61ed5b67f100] error while decoding MB 30 63, bytestream -5
[h264 @ 0x61ed5b67f100] left block unavailable for requested intra mode
[h264 @ 0x61ed5b67f100] error while decoding MB 0 44, bytestream 4099
[h264 @ 0x61ed55e28100] error while decoding MB 10 46, bytestream -22
[h264 @ 0x61ed6970a6c0] left block unavailable for requested intra mode
[h264 @ 0x61ed6970a6c0] error while decoding MB 0 46, bytestream 27530
[h264 @ 0x61ed55e1b9c0] error while decoding MB 109 49, bytestream -10
[h264 @ 0x61ed56a8f9c0] error while decoding MB 40 14, bytestream -5
[h264 @ 0x61ed590345c0] error while decoding MB 39 60, bytestream -14
[h264 @ 0x61ed55ff7d00] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x61ed55ff7d00] error while decoding MB 0 20, bytestream 118972
[h264 @ 0x61ed57534100] error while decoding MB 6 65, bytestream -28
[h264 @ 0x61ed590345c0] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x61ed590345c0] error while decoding MB 0 18, bytestream 68138
[h264 @ 0x61ed55e28100] error while decoding MB 69 43, bytestream -6
[h264 @ 0x61ed55ff7d00] error while decoding MB 108 60, bytestream -5
[h264 @ 0x61ed6970a6c0] error while decoding MB 33 45, bytestream -8
[h264 @ 0x61ed55e28100] error while decoding MB 70 55, bytestream -14
[h264 @ 0x61ed55ff7d00] error while decoding MB 0 65, bytestream -5
[h264 @ 0x61ed570e49c0] error while decoding MB 4 61, bytestream -26
[h264 @ 0x61ed55e28100] error while decoding MB 99 58, bytestream -28
[h264 @ 0x61ed584674c0] error while decoding MB 83 63, bytestream -8
[h264 @ 0x61ed5a268040] error while decoding MB 41 62, bytestream -12
[h264 @ 0x61ed55ff7d00] error while decoding MB 104 49, bytestream -8
[h264 @ 0x61ed584674c0] error while decoding MB 117 61, bytestream -16
[h264 @ 0x61ed5a268040] error while decoding MB 66 46, bytestream -6
[h264 @ 0x61ed6970a6c0] error while decoding MB 18 50, bytestream -7
[h264 @ 0x61ed56a8f9c0] error while decoding MB 95 53, bytestream -8
[h264 @ 0x61ed5a268040] left block unavailable for requested intra mode
[h264 @ 0x61ed5a268040] error while decoding MB 0 50, bytestream 32576
[h264 @ 0x61ed56a8f9c0] left block unavailable for requested intra mode
[h264 @ 0x61ed56a8f9c0] error while decoding MB 0 58, bytestream 2735
[h264 @ 0x61ed584674c0] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x61ed584674c0] error while decoding MB 0 47, bytestream 34733
[h264 @ 0x61ed57534100] error while decoding MB 21 38, bytestream -6
[h264 @ 0x61ed55ff7d00] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x61ed55ff7d00] error while decoding MB 0 46, bytestream 208
[h264 @ 0x61ed590345c0] error while decoding MB 58 50, bytestream -14
[h264 @ 0x61ed5b67f100] error while decoding MB 117 59, bytestream -8
[h264 @ 0x61ed57534100] error while decoding MB 117 48, bytestream -10
[h264 @ 0x61ed590345c0] error while decoding MB 68 55, bytestream -14
[h264 @ 0x61ed55ff7d00] error while decoding MB 110 58, bytestream -26
[h264 @ 0x61ed6970a6c0] error while decoding MB 114 56, bytestream -5
[h264 @ 0x61ed570e49c0] error while decoding MB 26 51, bytestream -12
[h264 @ 0x61ed59480c00] error while decoding MB 72 64, bytestream -5
[h264 @ 0x61ed55e28100] left block unavailable for requested intra mode
[h264 @ 0x61ed55e28100] error while decoding MB 0 42, bytestream 2018
[h264 @ 0x61ed584674c0] error while decoding MB 73 63, bytestream -6
[h264 @ 0x61ed59480c00] left block unavailable for requested intra mode
[h264 @ 0x61ed59480c00] error while decoding MB 0 21, bytestream 73666
[h264 @ 0x61ed55ff7d00] left block unavailable for requested intra mode
[h264 @ 0x61ed55ff7d00] error while decoding MB 0 47, bytestream 9614
[h264 @ 0x61ed5a268040] error while decoding MB 114 45, bytestream -14
[h264 @ 0x61ed56a8f9c0] error while decoding MB 103 47, bytestream -12
[h264 @ 0x61ed584674c0] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x61ed584674c0] error while decoding MB 0 51, bytestream 4040
[h264 @ 0x61ed56a8f9c0] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x61ed56a8f9c0] error while decoding MB 0 36, bytestream 30420
[h264 @ 0x61ed5b67f100] left block unavailable for requested intra mode
[h264 @ 0x61ed5b67f100] error while decoding MB 0 27, bytestream 8556
[h264 @ 0x61ed584674c0] error while decoding MB 4 56, bytestream -12
[h264 @ 0x61ed5b67f100] error while decoding MB 93 56, bytestream -8
[h264 @ 0x61ed55e1b9c0] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x61ed55e1b9c0] error while decoding MB 0 41, bytestream 9954
[h264 @ 0x61ed59480c00] error while decoding MB 31 55, bytestream -22
[h264 @ 0x61ed5b67f100] error while decoding MB 43 55, bytestream -8
[h264 @ 0x61ed59480c00] error while decoding MB 100 57, bytestream -20
[h264 @ 0x61ed5b67f100] error while decoding MB 112 66, bytestream -20
[h264 @ 0x61ed57534100] error while decoding MB 96 58, bytestream -20
[h264 @ 0x61ed57534100] left block unavailable for requested intra mode
[h264 @ 0x61ed57534100] error while decoding MB 0 18, bytestream 11369
[h264 @ 0x61ed55ff7d00] left block unavailable for requested intra mode
[h264 @ 0x61ed55ff7d00] error while decoding MB 0 21, bytestream 21974
[h264 @ 0x61ed6970a6c0] error while decoding MB 64 48, bytestream -8
[h264 @ 0x61ed570e49c0] error while decoding MB 22 47, bytestream -22
[h264 @ 0x61ed55e28100] left block unavailable for requested intra mode
[h264 @ 0x61ed55e28100] error while decoding MB 0 61, bytestream 1389
[h264 @ 0x61ed59480c00] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x61ed59480c00] error while decoding MB 0 40, bytestream 5696
[h264 @ 0x61ed56a8f9c0] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x61ed56a8f9c0] error while decoding MB 0 50, bytestream 6762
[h264 @ 0x61ed584674c0] left block unavailable for requested intra mode
[h264 @ 0x61ed584674c0] error while decoding MB 0 51, bytestream 3806
[h264 @ 0x61ed5a268040] left block unavailable for requested intra mode
[h264 @ 0x61ed5a268040] error while decoding MB 0 49, bytestream 8730
[h264 @ 0x61ed56a8f9c0] error while decoding MB 119 57, bytestream -20
[h264 @ 0x61ed570e49c0] error while decoding MB 8 59, bytestream -6
[h264 @ 0x61ed584674c0] error while decoding MB 26 60, bytestream -6
[h264 @ 0x61ed57534100] error while decoding MB 0 20, bytestream -6
[h264 @ 0x61ed55e28100] left block unavailable for requested intra mode
[h264 @ 0x61ed55e28100] error while decoding MB 0 24, bytestream 60964
[h264 @ 0x61ed584674c0] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x61ed584674c0] error while decoding MB 0 36, bytestream 6568
[h264 @ 0x61ed55ff7d00] error while decoding MB 46 53, bytestream -10
[h264 @ 0x61ed590345c0] error while decoding MB 32 49, bytestream -6
[h264 @ 0x61ed57534100] error while decoding MB 91 64, bytestream -5
[h264 @ 0x61ed590345c0] error while decoding MB 108 51, bytestream -18
[h264 @ 0x61ed55ff7d00] error while decoding MB 35 60, bytestream -5
[h264 @ 0x61ed55ff7d00] error while decoding MB 49 63, bytestream -14
[h264 @ 0x61ed5b67f100] error while decoding MB 88 15, bytestream -9
[h264 @ 0x61ed55ff7d00] error while decoding MB 61 4, bytestream -5
[h264 @ 0x61ed5b67f100] error while decoding MB 106 15, bytestream -7
[h264 @ 0x61ed57534100] error while decoding MB 66 67, bytestream -16
[h264 @ 0x61ed590345c0] error while decoding MB 84 59, bytestream -10
[h264 @ 0x61ed55ff7d00] error while decoding MB 8 62, bytestream -10
[h264 @ 0x61ed55ff7d00] error while decoding MB 89 63, bytestream -18
[h264 @ 0x61ed590345c0] left block unavailable for requested intra mode
[h264 @ 0x61ed590345c0] error while decoding MB 0 24, bytestream 8238
[h264 @ 0x61ed57534100] error while decoding MB 72 36, bytestream -6
[h264 @ 0x61ed570e49c0] error while decoding MB 31 52, bytestream -20
[h264 @ 0x61ed55e28100] error while decoding MB 74 65, bytestream -10
[h264 @ 0x61ed6970a6c0] error while decoding MB 79 60, bytestream -18
[h264 @ 0x61ed56a8f9c0] error while decoding MB 105 64, bytestream -18
[h264 @ 0x61ed5b67f100] error while decoding MB 100 65, bytestream -30
[h264 @ 0x61ed55e1b9c0] error while decoding MB 109 60, bytestream -26
[h264 @ 0x61ed59480c00] error while decoding MB 18 52, bytestream -16
[h264 @ 0x61ed59480c00] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x61ed59480c00] error while decoding MB 0 48, bytestream 3091
[h264 @ 0x61ed584674c0] error while decoding MB 89 66, bytestream -5
[h264 @ 0x61ed55e28100] error while decoding MB 118 35, bytestream -6
[h264 @ 0x61ed57534100] left block unavailable for requested intra mode
[h264 @ 0x61ed57534100] error while decoding MB 0 54, bytestream 2337
[h264 @ 0x61ed55ff7d00] error while decoding MB 105 59, bytestream -16
[h264 @ 0x61ed590345c0] left block unavailable for requested intra mode
[h264 @ 0x61ed590345c0] error while decoding MB 0 67, bytestream 536
[h264 @ 0x61ed55ff7d00] left block unavailable for requested intra mode
[h264 @ 0x61ed55ff7d00] error while decoding MB 0 59, bytestream 5148
[h264 @ 0x61ed57534100] error while decoding MB 70 64, bytestream -10
[h264 @ 0x61ed570e49c0] left block unavailable for requested intra mode
[h264 @ 0x61ed570e49c0] error while decoding MB 0 58, bytestream 683
[h264 @ 0x61ed57534100] error while decoding MB 25 63, bytestream -8
[h264 @ 0x61ed57534100] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x61ed57534100] error while decoding MB 0 53, bytestream 8305
[h264 @ 0x61ed55ff7d00] error while decoding MB 29 59, bytestream -12
[h264 @ 0x61ed57534100] error while decoding MB 94 62, bytestream -18
[h264 @ 0x61ed590345c0] error while decoding MB 107 66, bytestream -24
[h264 @ 0x61ed55ff7d00] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x61ed55ff7d00] error while decoding MB 0 29, bytestream 61044
[h264 @ 0x61ed5b67f100] error while decoding MB 0 59, bytestream -7
[h264 @ 0x61ed57534100] error while decoding MB 103 58, bytestream -8
[h264 @ 0x61ed55ff7d00] error while decoding MB 94 55, bytestream -17
[h264 @ 0x61ed55ff7d00] error while decoding MB 116 66, bytestream -28
[h264 @ 0x61ed5b67f100] cabac decode of qscale diff failed at 10 25
[h264 @ 0x61ed5b67f100] error while decoding MB 10 25, bytestream 3687
[h264 @ 0x61ed57534100] error while decoding MB 62 54, bytestream -8
[h264 @ 0x61ed590345c0] error while decoding MB 30 64, bytestream -30
[h264 @ 0x61ed55e28100] error while decoding MB 119 61, bytestream -6
[h264 @ 0x61ed570e49c0] error while decoding MB 100 52, bytestream -12
[h264 @ 0x61ed55e28100] error while decoding MB 103 63, bytestream -8
[h264 @ 0x61ed57534100] error while decoding MB 111 53, bytestream -6
[h264 @ 0x61ed55e28100] error while decoding MB 27 64, bytestream -22
[h264 @ 0x61ed6970a6c0] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x61ed6970a6c0] error while decoding MB 0 23, bytestream 94133
[h264 @ 0x61ed5a268040] error while decoding MB 8 50, bytestream -14
[h264 @ 0x61ed584674c0] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x61ed584674c0] error while decoding MB 0 28, bytestream 5776
[h264 @ 0x61ed584674c0] error while decoding MB 9 64, bytestream -6
[h264 @ 0x61ed584674c0] error while decoding MB 114 66, bytestream -14
[h264 @ 0x61ed56a8f9c0] left block unavailable for requested intra mode
[h264 @ 0x61ed56a8f9c0] error while decoding MB 0 39, bytestream 4206
[h264 @ 0x61ed584674c0] error while decoding MB 27 63, bytestream -6
[h264 @ 0x61ed55e28100] error while decoding MB 14 44, bytestream -7
[h264 @ 0x61ed56a8f9c0] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x61ed56a8f9c0] error while decoding MB 0 56, bytestream 5752
[h264 @ 0x61ed570e49c0] error while decoding MB 29 61, bytestream -6
[h264 @ 0x61ed584674c0] error while decoding MB 100 66, bytestream -16
[h264 @ 0x61ed5a268040] error while decoding MB 37 64, bytestream -8
[h264 @ 0x61ed59480c00] error while decoding MB 112 60, bytestream -8
[h264 @ 0x61ed584674c0] error while decoding MB 10 34, bytestream -5
[h264 @ 0x61ed59480c00] error while decoding MB 116 64, bytestream -24
[h264 @ 0x61ed5b67f100] error while decoding MB 112 59, bytestream -7
[h264 @ 0x61ed55e1b9c0] error while decoding MB 8 50, bytestream -18
[h264 @ 0x61ed5b67f100] error while decoding MB 39 20, bytestream -7
[h264 @ 0x61ed6970a6c0] error while decoding MB 98 62, bytestream -16
[h264 @ 0x61ed55e28100] error while decoding MB 113 60, bytestream -18
[h264 @ 0x61ed590345c0] error while decoding MB 26 39, bytestream -5
[h264 @ 0x61ed55e28100] error while decoding MB 62 63, bytestream -8
[h264 @ 0x61ed584674c0] error while decoding MB 64 66, bytestream -10
[h264 @ 0x61ed55e28100] error while decoding MB 89 15, bytestream -7
[h264 @ 0x61ed56a8f9c0] error while decoding MB 8 65, bytestream -26
[h264 @ 0x61ed570e49c0] error while decoding MB 107 57, bytestream -7
[h264 @ 0x61ed5a268040] left block unavailable for requested intra mode
[h264 @ 0x61ed5a268040] error while decoding MB 0 65, bytestream 142
[h264 @ 0x61ed56a8f9c0] error while decoding MB 112 64, bytestream -19
[h264 @ 0x61ed6970a6c0] error while decoding MB 68 24, bytestream -6
[h264 @ 0x61ed56a8f9c0] error while decoding MB 106 64, bytestream -24
[h264 @ 0x61ed56a8f9c0] error while decoding MB 74 43, bytestream -8
[h264 @ 0x61ed5a268040] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x61ed5a268040] error while decoding MB 0 27, bytestream 85752
[h264 @ 0x61ed56a8f9c0] left block unavailable for requested intra mode
[h264 @ 0x61ed56a8f9c0] error while decoding MB 0 24, bytestream 83446
[h264 @ 0x61ed5b67f100] left block unavailable for requested intra mode
[h264 @ 0x61ed5b67f100] error while decoding MB 0 16, bytestream 12080
[h264 @ 0x61ed57534100] left block unavailable for requested intra mode
[h264 @ 0x61ed57534100] error while decoding MB 0 44, bytestream 2935
[h264 @ 0x61ed59480c00] left block unavailable for requested intra mode
[h264 @ 0x61ed59480c00] error while decoding MB 0 15, bytestream 12358
[h264 @ 0x61ed55e28100] cabac decode of qscale diff failed at 109 15
[h264 @ 0x61ed55e28100] error while decoding MB 109 15, bytestream 23155
[h264 @ 0x61ed5a268040] error while decoding MB 22 51, bytestream -6
[h264 @ 0x61ed570e49c0] left block unavailable for requested intra mode
[h264 @ 0x61ed570e49c0] error while decoding MB 0 20, bytestream 37219
[h264 @ 0x61ed6970a6c0] left block unavailable for requested intra mode
[h264 @ 0x61ed6970a6c0] error while decoding MB 0 21, bytestream 22882
[h264 @ 0x61ed584674c0] error while decoding MB 55 64, bytestream -5
[h264 @ 0x61ed55e1b9c0] left block unavailable for requested intra mode
[h264 @ 0x61ed55e1b9c0] error while decoding MB 0 27, bytestream 81331
[h264 @ 0x61ed55e28100] left block unavailable for requested intra mode
[h264 @ 0x61ed55e28100] error while decoding MB 0 33, bytestream 5702
[h264 @ 0x61ed590345c0] error while decoding MB 74 29, bytestream -9
[h264 @ 0x61ed59480c00] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x61ed59480c00] error while decoding MB 0 37, bytestream 5482
[h264 @ 0x61ed5b67f100] error while decoding MB 32 55, bytestream -12
[h264 @ 0x61ed55e1b9c0] error while decoding MB 93 58, bytestream -12
[h264 @ 0x61ed5b67f100] error while decoding MB 27 56, bytestream -29
[h264 @ 0x61ed55e28100] cabac decode of qscale diff failed at 39 21
[h264 @ 0x61ed55e28100] error while decoding MB 39 21, bytestream 10236
[h264 @ 0x61ed590345c0] error while decoding MB 115 30, bytestream -9
[h264 @ 0x61ed59480c00] error while decoding MB 53 23, bytestream -5
[h264 @ 0x61ed590345c0] error while decoding MB 108 51, bytestream -10
[h264 @ 0x61ed57534100] error while decoding MB 33 57, bytestream -22
[h264 @ 0x61ed55ff7d00] error while decoding MB 34 58, bytestream -16
[h264 @ 0x61ed55e1b9c0] error while decoding MB 64 53, bytestream -5
[h264 @ 0x61ed590345c0] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x61ed590345c0] error while decoding MB 0 57, bytestream 21067
[h264 @ 0x61ed55ff7d00] error while decoding MB 111 59, bytestream -24
[h264 @ 0x61ed56a8f9c0] error while decoding MB 53 62, bytestream -5
[h264 @ 0x61ed57534100] error while decoding MB 79 62, bytestream -14
[h264 @ 0x61ed590345c0] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x61ed590345c0] error while decoding MB 0 24, bytestream 50428
[h264 @ 0x61ed584674c0] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x61ed584674c0] error while decoding MB 0 34, bytestream 3752
[h264 @ 0x61ed5a268040] error while decoding MB 103 56, bytestream -8
[h264 @ 0x61ed590345c0] error while decoding MB 43 26, bytestream -5
[h264 @ 0x61ed584674c0] error while decoding MB 112 61, bytestream -32
[h264 @ 0x61ed590345c0] left block unavailable for requested intra mode
[h264 @ 0x61ed590345c0] error while decoding MB 0 57, bytestream 1561
[h264 @ 0x61ed570e49c0] error while decoding MB 29 20, bytestream -5
[h264 @ 0x61ed55e1b9c0] error while decoding MB 89 15, bytestream -5
[h264 @ 0x61ed590345c0] error while decoding MB 34 61, bytestream -12
[h264 @ 0x61ed55ff7d00] left block unavailable for requested intra mode
[h264 @ 0x61ed55ff7d00] error while decoding MB 0 60, bytestream 328
[h264 @ 0x61ed57534100] error while decoding MB 69 59, bytestream -6
[h264 @ 0x61ed55e1b9c0] error while decoding MB 102 20, bytestream -5
[h264 @ 0x61ed55e28100] error while decoding MB 48 57, bytestream -14
[h264 @ 0x61ed6970a6c0] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x61ed6970a6c0] error while decoding MB 0 41, bytestream 6494
[h264 @ 0x61ed570e49c0] error while decoding MB 112 64, bytestream -6
[h264 @ 0x61ed55e1b9c0] error while decoding MB 22 64, bytestream -6
[h264 @ 0x61ed55e28100] error while decoding MB 65 49, bytestream -5
[h264 @ 0x61ed55ff7d00] error while decoding MB 103 62, bytestream -26
[h264 @ 0x61ed55e1b9c0] error while decoding MB 109 39, bytestream -5
[h264 @ 0x61ed590345c0] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x61ed590345c0] error while decoding MB 0 65, bytestream 4610
[h264 @ 0x61ed59480c00] error while decoding MB 100 57, bytestream -5
[h264 @ 0x61ed570e49c0] left block unavailable for requested intra mode
[h264 @ 0x61ed570e49c0] error while decoding MB 0 25, bytestream 8960
[h264 @ 0x61ed55ff7d00] error while decoding MB 103 60, bytestream -8
[h264 @ 0x61ed5b67f100] error while decoding MB 8 49, bytestream -5
[h264 @ 0x61ed6970a6c0] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x61ed6970a6c0] error while decoding MB 0 36, bytestream 7444
[h264 @ 0x61ed6970a6c0] error while decoding MB 27 65, bytestream -8
[h264 @ 0x61ed570e49c0] error while decoding MB 48 53, bytestream -8
[h264 @ 0x61ed55ff7d00] error while decoding MB 74 58, bytestream -5
[h264 @ 0x61ed5a268040] error while decoding MB 19 56, bytestream -5
[h264 @ 0x61ed570e49c0] error while decoding MB 53 54, bytestream -8
[h264 @ 0x61ed55ff7d00] error while decoding MB 74 49, bytestream -5
[h264 @ 0x61ed56a8f9c0] error while decoding MB 37 66, bytestream -8
[h264 @ 0x61ed584674c0] error while decoding MB 42 55, bytestream -25
[h264 @ 0x61ed55e28100] error while decoding MB 10 27, bytestream -6
[h264 @ 0x61ed59480c00] error while decoding MB 100 66, bytestream -14
[h264 @ 0x61ed5b67f100] error while decoding MB 103 62, bytestream -20
[h264 @ 0x61ed59480c00] error while decoding MB 87 62, bytestream -6
[h264 @ 0x61ed5b67f100] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x61ed5b67f100] error while decoding MB 0 48, bytestream 5094
[h264 @ 0x61ed59480c00] left block unavailable for requested intra mode
[h264 @ 0x61ed59480c00] error while decoding MB 0 20, bytestream 9876
[h264 @ 0x61ed59480c00] left block unavailable for requested intra mode
[h264 @ 0x61ed59480c00] error while decoding MB 0 47, bytestream 10102
[h264 @ 0x61ed5b67f100] error while decoding MB 63 55, bytestream -6
[h264 @ 0x61ed55e1b9c0] error while decoding MB 87 67, bytestream -15
[h264 @ 0x61ed59480c00] error while decoding MB 47 61, bytestream -10
[h264 @ 0x61ed55e1b9c0] error while decoding MB 63 64, bytestream -20
[h264 @ 0x61ed55e1b9c0] error while decoding MB 105 59, bytestream -6
[h264 @ 0x61ed55e28100] error while decoding MB 89 14, bytestream -7
[h264 @ 0x61ed55ff7d00] error while decoding MB 3 65, bytestream -6
[h264 @ 0x61ed57534100] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x61ed57534100] error while decoding MB 0 44, bytestream 3974
[h264 @ 0x61ed5b67f100] error while decoding MB 64 52, bytestream -16
[h264 @ 0x61ed55e1b9c0] error while decoding MB 110 51, bytestream -10
[h264 @ 0x61ed59480c00] error while decoding MB 108 66, bytestream -8
[h264 @ 0x61ed584674c0] error while decoding MB 112 39, bytestream -7
[h264 @ 0x61ed59480c00] left block unavailable for requested intra mode
[h264 @ 0x61ed59480c00] error while decoding MB 0 61, bytestream 427
[h264 @ 0x61ed57534100] error while decoding MB 36 53, bytestream -10
[h264 @ 0x61ed55e28100] error while decoding MB 70 61, bytestream -5
[h264 @ 0x61ed55e28100] cabac decode of qscale diff failed at 107 16
[h264 @ 0x61ed55e28100] error while decoding MB 107 16, bytestream 8751
[h264 @ 0x61ed59480c00] error while decoding MB 45 17, bytestream -5
[h264 @ 0x61ed5a268040] left block unavailable for requested intra mode
[h264 @ 0x61ed5a268040] error while decoding MB 0 63, bytestream 11541
[h264 @ 0x61ed55e1b9c0] error while decoding MB 68 52, bytestream -26
[h264 @ 0x61ed59480c00] error while decoding MB 69 57, bytestream -30
[h264 @ 0x61ed57534100] error while decoding MB 75 54, bytestream -16
[h264 @ 0x61ed590345c0] error while decoding MB 76 64, bytestream -10
[h264 @ 0x61ed590345c0] error while decoding MB 62 47, bytestream -20
[h264 @ 0x61ed590345c0] error while decoding MB 22 16, bytestream -6
[h264 @ 0x61ed59480c00] error while decoding MB 63 26, bytestream -7
[h264 @ 0x61ed5a268040] error while decoding MB 74 54, bytestream -5
[h264 @ 0x61ed57534100] left block unavailable for requested intra mode
[h264 @ 0x61ed57534100] error while decoding MB 0 45, bytestream 5054
[h264 @ 0x61ed57534100] error while decoding MB 6 51, bytestream -34
[h264 @ 0x61ed590345c0] error while decoding MB 49 58, bytestream -6
[h264 @ 0x61ed55ff7d00] error while decoding MB 88 65, bytestream -12
[h264 @ 0x61ed57534100] left block unavailable for requested intra mode
[h264 @ 0x61ed57534100] error while decoding MB 0 51, bytestream 6466
[h264 @ 0x61ed55e1b9c0] error while decoding MB 118 34, bytestream -7
[h264 @ 0x61ed584674c0] left block unavailable for requested intra mode
[h264 @ 0x61ed584674c0] error while decoding MB 0 48, bytestream 3626
[h264 @ 0x61ed590345c0] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x61ed590345c0] error while decoding MB 0 54, bytestream 2968
[h264 @ 0x61ed57534100] error while decoding MB 99 55, bytestream -8
[h264 @ 0x61ed590345c0] left block unavailable for requested intra mode
[h264 @ 0x61ed590345c0] error while decoding MB 0 61, bytestream 2281
[h264 @ 0x61ed59480c00] error while decoding MB 24 59, bytestream -8
[h264 @ 0x61ed55ff7d00] error while decoding MB 33 52, bytestream -6
[h264 @ 0x61ed5b67f100] error while decoding MB 48 17, bytestream -5
[h264 @ 0x61ed584674c0] error while decoding MB 61 59, bytestream -5
[h264 @ 0x61ed55ff7d00] error while decoding MB 110 65, bytestream -28
[h264 @ 0x61ed590345c0] error while decoding MB 119 57, bytestream -32
[h264 @ 0x61ed55ff7d00] left block unavailable for requested intra mode
[h264 @ 0x61ed55ff7d00] error while decoding MB 0 52, bytestream 4990
[h264 @ 0x61ed55e28100] error while decoding MB 91 62, bytestream -6
[h264 @ 0x61ed590345c0] error while decoding MB 22 54, bytestream -30
[h264 @ 0x61ed57534100] error while decoding MB 90 65, bytestream -8
[h264 @ 0x61ed55e1b9c0] error while decoding MB 90 39, bytestream -5
[h264 @ 0x61ed57534100] left block unavailable for requested intra mode
[h264 @ 0x61ed57534100] error while decoding MB 0 11, bytestream 117494
[h264 @ 0x61ed5a268040] left block unavailable for requested intra mode
[h264 @ 0x61ed5a268040] error while decoding MB 0 25, bytestream 9486
[h264 @ 0x61ed5a268040] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x61ed5a268040] error while decoding MB 0 57, bytestream 10392
[h264 @ 0x61ed584674c0] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x61ed584674c0] error while decoding MB 0 5, bytestream 123951
[h264 @ 0x61ed59480c00] left block unavailable for requested intra mode
[h264 @ 0x61ed59480c00] error while decoding MB 0 23, bytestream 9822
[h264 @ 0x61ed5b67f100] left block unavailable for requested intra mode
[h264 @ 0x61ed5b67f100] error while decoding MB 0 24, bytestream 56400
[h264 @ 0x61ed55e1b9c0] cabac decode of qscale diff failed at 30 20
[h264 @ 0x61ed55e1b9c0] error while decoding MB 30 20, bytestream 11891
[h264 @ 0x61ed5b67f100] error while decoding MB 82 61, bytestream -18
[h264 @ 0x61ed5b67f100] error while decoding MB 119 64, bytestream -5
[h264 @ 0x61ed570e49c0] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x61ed570e49c0] error while decoding MB 0 17, bytestream 11688
[h264 @ 0x61ed590345c0] error while decoding MB 40 61, bytestream -16
Processed 43836 frames before detection.
Processed 80432 frames before detection.
Saved successfully
Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
-- <re.Match object; span=(0, 8), match='06:36:35'>
Extracted Time: 06:36:35
06:36:35
Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
-- <re.Match object; span=(11, 19), match='16:07:45'>
Extracted Time: 16:07:45
16:07:45
***30-03-2025***
Trying start time: 06:00:00
Connecting to recorded video at 1743294600
URL: rtsp://admin:rmc%4012345@103.168.199.92:554/c1/b1743294600/e1743298200/replay/
[rtsp @ 0x61ed595a0440] getaddrinfo(): Name or service not known
[rtsp @ 0x61ed595a0440] getaddrinfo(): Name or service not known
Stream found at 06:00:00
Trying start time: 15:00:20
Connecting to recorded video at 1743327020
URL: rtsp://admin:rmc%4012345@103.168.199.92:554/c1/b1743327020/e1743336000/replay/
[rtsp @ 0x61ed596aa900] getaddrinfo(): Name or service not known
[rtsp @ 0x61ed596aa900] getaddrinfo(): Name or service not known
Stream found at 15:00:20
#####################
[rtsp @ 0x61ed558bc000] getaddrinfo(): Name or service not known
[rtsp @ 0x61ed558bc000] getaddrinfo(): Name or service not known
[h264 @ 0x61ed56c632c0] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x61ed56c632c0] error while decoding MB 0 53, bytestream 342
[h264 @ 0x61ed59617c80] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x61ed59617c80] error while decoding MB 0 53, bytestream 342
[h264 @ 0x61ed58cd66c0] error while decoding MB 103 55, bytestream -5
[h264 @ 0x61ed5a635d80] left block unavailable for requested intra mode
[h264 @ 0x61ed5a635d80] error while decoding MB 0 51, bytestream 5406
[h264 @ 0x61ed58cd66c0] error while decoding MB 39 61, bytestream -20
[h264 @ 0x61ed59617c80] error while decoding MB 113 34, bytestream -22
[h264 @ 0x61ed5a635d80] error while decoding MB 65 63, bytestream -21
[h264 @ 0x61ed58cd66c0] error while decoding MB 48 66, bytestream -27
[h264 @ 0x61ed5a635d80] error while decoding MB 24 53, bytestream -14
[h264 @ 0x61ed59031280] error while decoding MB 114 5, bytestream -5
[h264 @ 0x61ed58cd66c0] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x61ed58cd66c0] error while decoding MB 0 53, bytestream 8079
[h264 @ 0x61ed5a635d80] error while decoding MB 9 59, bytestream -15
[h264 @ 0x61ed58cd66c0] error while decoding MB 102 64, bytestream -22
[h264 @ 0x61ed5a635d80] error while decoding MB 36 50, bytestream -22
[h264 @ 0x61ed58cd66c0] left block unavailable for requested intra mode
[h264 @ 0x61ed58cd66c0] error while decoding MB 0 54, bytestream 11100
[h264 @ 0x61ed59031280] left block unavailable for requested intra mode
[h264 @ 0x61ed59031280] error while decoding MB 0 50, bytestream 1511
[h264 @ 0x61ed5a635d80] left block unavailable for requested intra mode
[h264 @ 0x61ed5a635d80] error while decoding MB 0 48, bytestream 301
[h264 @ 0x61ed58cd66c0] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x61ed58cd66c0] error while decoding MB 0 47, bytestream 4283
[h264 @ 0x61ed5c0080c0] left block unavailable for requested intra mode
[h264 @ 0x61ed5c0080c0] error while decoding MB 0 18, bytestream 8532
[h264 @ 0x61ed59617c80] error while decoding MB 90 66, bytestream -24
[h264 @ 0x61ed5ad447c0] error while decoding MB 87 54, bytestream -15
[h264 @ 0x61ed5a46d040] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x61ed5a46d040] error while decoding MB 0 60, bytestream 6728
[h264 @ 0x61ed5ad447c0] error while decoding MB 89 48, bytestream -24
[h264 @ 0x61ed57457b00] error while decoding MB 44 61, bytestream -18
[h264 @ 0x61ed5a46d040] left block unavailable for requested intra mode
[h264 @ 0x61ed5a46d040] error while decoding MB 0 43, bytestream 5493
[h264 @ 0x61ed57457b00] error while decoding MB 52 62, bytestream -21
[h264 @ 0x61ed5ad447c0] error while decoding MB 62 55, bytestream -10
[h264 @ 0x61ed58253e80] error while decoding MB 98 62, bytestream -9
[h264 @ 0x61ed57457b00] left block unavailable for requested intra mode
[h264 @ 0x61ed57457b00] error while decoding MB 0 49, bytestream 2446
[h264 @ 0x61ed58253e80] error while decoding MB 75 30, bytestream -21
[h264 @ 0x61ed59031280] error while decoding MB 35 66, bytestream -9
[h264 @ 0x61ed58cd66c0] error while decoding MB 90 60, bytestream -20
[h264 @ 0x61ed58253e80] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x61ed58253e80] error while decoding MB 0 33, bytestream 3464
[h264 @ 0x61ed59617c80] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x61ed59617c80] error while decoding MB 0 17, bytestream 56408
[h264 @ 0x61ed5bc44b00] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x61ed5bc44b00] error while decoding MB 0 48, bytestream 39965
[h264 @ 0x61ed58253e80] error while decoding MB 35 66, bytestream -8
[h264 @ 0x61ed57457b00] error while decoding MB 19 45, bytestream -7
[h264 @ 0x61ed5bc44b00] error while decoding MB 80 64, bytestream -11
[h264 @ 0x61ed5bc44b00] left block unavailable for requested intra mode
[h264 @ 0x61ed5bc44b00] error while decoding MB 0 59, bytestream 8748
[h264 @ 0x61ed58253e80] error while decoding MB 115 55, bytestream -22
[h264 @ 0x61ed5bc58b00] error while decoding MB 96 40, bytestream -14
[h264 @ 0x61ed5bc58b00] error while decoding MB 94 59, bytestream -7
[h264 @ 0x61ed5c0080c0] error while decoding MB 105 25, bytestream -7
[h264 @ 0x61ed59031280] left block unavailable for requested intra mode
[h264 @ 0x61ed59031280] error while decoding MB 0 62, bytestream 3345
[h264 @ 0x61ed5ad29b40] error while decoding MB 6 59, bytestream -14
[h264 @ 0x61ed57457b00] error while decoding MB 59 45, bytestream -5
[h264 @ 0x61ed5bc58b00] left block unavailable for requested intra mode
[h264 @ 0x61ed5bc58b00] error while decoding MB 0 41, bytestream 5549
[h264 @ 0x61ed59031280] error while decoding MB 35 53, bytestream -7
[h264 @ 0x61ed58cd66c0] left block unavailable for requested intra mode
[h264 @ 0x61ed58cd66c0] error while decoding MB 0 46, bytestream 4701
[h264 @ 0x61ed59617c80] error while decoding MB 11 66, bytestream -21
[h264 @ 0x61ed58cd66c0] error while decoding MB 37 56, bytestream -27
[h264 @ 0x61ed58cd66c0] error while decoding MB 99 62, bytestream -9
[h264 @ 0x61ed5bc44b00] error while decoding MB 18 26, bytestream -13
[h264 @ 0x61ed58cd66c0] error while decoding MB 23 57, bytestream -17
[h264 @ 0x61ed58cd66c0] error while decoding MB 43 61, bytestream -23
[h264 @ 0x61ed59617c80] left block unavailable for requested intra mode
[h264 @ 0x61ed59617c80] error while decoding MB 0 60, bytestream 13143
[h264 @ 0x61ed5a635d80] error while decoding MB 99 64, bytestream -27
[h264 @ 0x61ed5a635d80] error while decoding MB 87 64, bytestream -10
[h264 @ 0x61ed59031280] error while decoding MB 94 26, bytestream -5
[h264 @ 0x61ed58cd66c0] left block unavailable for requested intra mode
[h264 @ 0x61ed58cd66c0] error while decoding MB 0 54, bytestream 42465
[h264 @ 0x61ed58cd66c0] left block unavailable for requested intra mode
[h264 @ 0x61ed58cd66c0] error while decoding MB 0 55, bytestream 5815
[h264 @ 0x61ed58cd66c0] left block unavailable for requested intra mode
[h264 @ 0x61ed58cd66c0] error while decoding MB 0 19, bytestream 161578
[h264 @ 0x61ed59617c80] error while decoding MB 63 62, bytestream -9
[h264 @ 0x61ed58cd66c0] error while decoding MB 99 60, bytestream -35
[h264 @ 0x61ed58cd66c0] error while decoding MB 44 64, bytestream -10
[h264 @ 0x61ed5a635d80] error while decoding MB 1 61, bytestream -24
[h264 @ 0x61ed5a635d80] error while decoding MB 53 64, bytestream -19
[h264 @ 0x61ed5bc58b00] error while decoding MB 11 17, bytestream -7
[h264 @ 0x61ed5a635d80] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x61ed5a635d80] error while decoding MB 0 41, bytestream 7733
[h264 @ 0x61ed58253e80] left block unavailable for requested intra mode
[h264 @ 0x61ed58253e80] error while decoding MB 0 40, bytestream 3294
[h264 @ 0x61ed5a635d80] left block unavailable for requested intra mode
[h264 @ 0x61ed5a635d80] error while decoding MB 0 16, bytestream 197831
[h264 @ 0x61ed58cd66c0] error while decoding MB 53 53, bytestream -26
[h264 @ 0x61ed5a635d80] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x61ed5a635d80] error while decoding MB 0 45, bytestream 10103
[h264 @ 0x61ed58cd66c0] error while decoding MB 38 60, bytestream -10
[h264 @ 0x61ed5a635d80] left block unavailable for requested intra mode
[h264 @ 0x61ed5a635d80] error while decoding MB 0 56, bytestream 9098
[h264 @ 0x61ed5a635d80] left block unavailable for requested intra mode
[h264 @ 0x61ed5a635d80] error while decoding MB 0 10, bytestream 205474
[h264 @ 0x61ed5a635d80] error while decoding MB 101 64, bytestream -22
[h264 @ 0x61ed59617c80] error while decoding MB 30 53, bytestream -19
[h264 @ 0x61ed57457b00] error while decoding MB 91 60, bytestream -17
[h264 @ 0x61ed5a46d040] left block unavailable for requested intra mode
[h264 @ 0x61ed5a46d040] error while decoding MB 0 47, bytestream 9322
[h264 @ 0x61ed5ad447c0] error while decoding MB 79 53, bytestream -24
[h264 @ 0x61ed5bc44b00] error while decoding MB 29 67, bytestream -10
[h264 @ 0x61ed58253e80] error while decoding MB 49 64, bytestream -17
[h264 @ 0x61ed5c0080c0] error while decoding MB 44 42, bytestream -32
[h264 @ 0x61ed59031280] error while decoding MB 82 33, bytestream -5
[h264 @ 0x61ed58253e80] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x61ed58253e80] error while decoding MB 0 62, bytestream 4183
[h264 @ 0x61ed5a635d80] error while decoding MB 34 64, bytestream -5
#####################
[rtsp @ 0x61ed560def00] getaddrinfo(): Name or service not known
[rtsp @ 0x61ed560def00] getaddrinfo(): Name or service not known
[h264 @ 0x61ed69068780] error while decoding MB 10 25, bytestream -7
[h264 @ 0x61ed6a4373c0] left block unavailable for requested intra mode
[h264 @ 0x61ed6a4373c0] error while decoding MB 0 61, bytestream 15564
[h264 @ 0x61ed5b785940] error while decoding MB 7 63, bytestream -5
[h264 @ 0x61ed5b785940] error while decoding MB 47 61, bytestream -7
[h264 @ 0x61ed5947ef40] left block unavailable for requested intra mode
[h264 @ 0x61ed5947ef40] error while decoding MB 0 62, bytestream 502
[h264 @ 0x61ed57d3f680] left block unavailable for requested intra mode
[h264 @ 0x61ed57d3f680] error while decoding MB 0 56, bytestream 27784
[h264 @ 0x61ed6a4373c0] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x61ed6a4373c0] error while decoding MB 0 30, bytestream 7396
[h264 @ 0x61ed57441900] error while decoding MB 93 66, bytestream -12
[h264 @ 0x61ed5947ef40] error while decoding MB 8 67, bytestream -36
[h264 @ 0x61ed5b785940] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x61ed5b785940] error while decoding MB 0 43, bytestream 42492
[h264 @ 0x61ed55bbf340] error while decoding MB 69 63, bytestream -30
[h264 @ 0x61ed5b785940] left block unavailable for requested intra mode
[h264 @ 0x61ed5b785940] error while decoding MB 0 54, bytestream 33269
[h264 @ 0x61ed57d3f680] left block unavailable for requested intra mode
[h264 @ 0x61ed57d3f680] error while decoding MB 0 23, bytestream 8871
[h264 @ 0x61ed69068780] left block unavailable for requested intra mode
[h264 @ 0x61ed69068780] error while decoding MB 0 25, bytestream 10218
[h264 @ 0x61ed5947ef40] error while decoding MB 16 63, bytestream -8
Processed 44365 frames before detection.
Processed 90666 frames before detection.
Saved successfully
Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
-- <re.Match object; span=(11, 19), match='06.37.02'>
Extracted Time: 06.37.02
06.37.02
Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
-- <re.Match object; span=(0, 8), match='16.15.56'>
Extracted Time: 16.15.56
16.15.56
***31-03-2025***
Trying start time: 06:00:00
Connecting to recorded video at 1743381000
URL: rtsp://admin:rmc%4012345@103.168.199.92:554/c1/b1743381000/e1743384600/replay/
[rtsp @ 0x61ed589dcf80] getaddrinfo(): Name or service not known
[rtsp @ 0x61ed589dcf80] getaddrinfo(): Name or service not known
Stream found at 06:00:00
Trying start time: 15:00:20
Connecting to recorded video at 1743413420
URL: rtsp://admin:rmc%4012345@103.168.199.92:554/c1/b1743413420/e1743422400/replay/
[rtsp @ 0x61ed589dcf80] getaddrinfo(): Name or service not known
[rtsp @ 0x61ed589dcf80] getaddrinfo(): Name or service not known
Stream found at 15:00:20
#####################
[rtsp @ 0x61ed5a2913c0] getaddrinfo(): Name or service not known
[rtsp @ 0x61ed5a2913c0] getaddrinfo(): Name or service not known
[h264 @ 0x61ed5a989d40] error while decoding MB 39 53, bytestream -17
[h264 @ 0x61ed58f3b400] error while decoding MB 43 66, bytestream -13
[h264 @ 0x61ed5a989d40] error while decoding MB 19 63, bytestream -14
[h264 @ 0x61ed5a989d40] error while decoding MB 49 58, bytestream -6
[h264 @ 0x61ed58c41480] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x61ed58c41480] error while decoding MB 0 57, bytestream 19922
[h264 @ 0x61ed568c7a40] left block unavailable for requested intra mode
[h264 @ 0x61ed568c7a40] error while decoding MB 0 53, bytestream 374
[h264 @ 0x61ed6d4cbd80] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x61ed6d4cbd80] error while decoding MB 0 37, bytestream 6747
[h264 @ 0x61ed58254d80] error while decoding MB 58 59, bytestream -18
[h264 @ 0x61ed6d4cbd80] error while decoding MB 100 67, bytestream -5
[h264 @ 0x61ed58254d80] error while decoding MB 7 66, bytestream -9
[h264 @ 0x61ed568c7a40] error while decoding MB 23 66, bytestream -20
[h264 @ 0x61ed6d4cbd80] left block unavailable for requested intra mode
[h264 @ 0x61ed6d4cbd80] error while decoding MB 0 23, bytestream 92103
[h264 @ 0x61ed58254d80] error while decoding MB 86 64, bytestream -16
[h264 @ 0x61ed568c7a40] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x61ed568c7a40] error while decoding MB 0 53, bytestream 20585
[h264 @ 0x61ed568c7a40] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x61ed568c7a40] error while decoding MB 0 65, bytestream 6320
[h264 @ 0x61ed6d4cbd80] error while decoding MB 103 63, bytestream -30
[h264 @ 0x61ed58254d80] error while decoding MB 28 65, bytestream -8
[h264 @ 0x61ed6d4cbd80] error while decoding MB 20 61, bytestream -7
[h264 @ 0x61ed6d4cbd80] error while decoding MB 27 66, bytestream -10
[h264 @ 0x61ed58254d80] error while decoding MB 41 54, bytestream -5
[h264 @ 0x61ed593461c0] error while decoding MB 13 15, bytestream -7
[h264 @ 0x61ed58254d80] error while decoding MB 107 63, bytestream -9
[h264 @ 0x61ed6d4cbd80] error while decoding MB 105 57, bytestream -27
[h264 @ 0x61ed58254d80] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x61ed58254d80] error while decoding MB 0 47, bytestream 5810
[h264 @ 0x61ed58254d80] left block unavailable for requested intra mode
[h264 @ 0x61ed58254d80] error while decoding MB 0 19, bytestream 160684
[h264 @ 0x61ed6d4cbd80] error while decoding MB 17 55, bytestream -26
[h264 @ 0x61ed568c7a40] left block unavailable for requested intra mode
[h264 @ 0x61ed568c7a40] error while decoding MB 0 56, bytestream 9293
[h264 @ 0x61ed58254d80] error while decoding MB 38 56, bytestream -25
[h264 @ 0x61ed568c7a40] error while decoding MB 89 67, bytestream -5
[h264 @ 0x61ed6d4cbd80] left block unavailable for requested intra mode
[h264 @ 0x61ed6d4cbd80] error while decoding MB 0 23, bytestream 129103
[h264 @ 0x61ed6d4cbd80] left block unavailable for requested intra mode
[h264 @ 0x61ed6d4cbd80] error while decoding MB 0 20, bytestream 156403
[h264 @ 0x61ed58254d80] error while decoding MB 15 64, bytestream -18
[h264 @ 0x61ed568c7a40] error while decoding MB 27 43, bytestream -6
[h264 @ 0x61ed5a475bc0] error while decoding MB 57 61, bytestream -7
[h264 @ 0x61ed5a45d1c0] error while decoding MB 40 57, bytestream -8
[h264 @ 0x61ed5a475bc0] error while decoding MB 65 62, bytestream -12
[h264 @ 0x61ed5a475bc0] left block unavailable for requested intra mode
[h264 @ 0x61ed5a475bc0] error while decoding MB 0 66, bytestream 2582
[h264 @ 0x61ed59efe540] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x61ed59efe540] error while decoding MB 0 54, bytestream 1088
[h264 @ 0x61ed59efe540] error while decoding MB 67 54, bytestream -15
[h264 @ 0x61ed5c0066c0] error while decoding MB 109 61, bytestream -16
[h264 @ 0x61ed58c41480] left block unavailable for requested intra mode
[h264 @ 0x61ed58c41480] error while decoding MB 0 66, bytestream 8525
[h264 @ 0x61ed58f3b400] left block unavailable for requested intra mode
[h264 @ 0x61ed58f3b400] error while decoding MB 0 53, bytestream 4698
[h264 @ 0x61ed593461c0] error while decoding MB 9 60, bytestream -23
[h264 @ 0x61ed593461c0] error while decoding MB 50 61, bytestream -21
[h264 @ 0x61ed6d4cbd80] error while decoding MB 6 57, bytestream -19
[h264 @ 0x61ed5a45d1c0] error while decoding MB 81 59, bytestream -15
[h264 @ 0x61ed5a475bc0] left block unavailable for requested intra mode
[h264 @ 0x61ed5a475bc0] error while decoding MB 0 4, bytestream 196525
[h264 @ 0x61ed5a989d40] error while decoding MB 48 59, bytestream -14
[h264 @ 0x61ed5a475bc0] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x61ed5a475bc0] error while decoding MB 0 53, bytestream 5826
[h264 @ 0x61ed59efe540] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x61ed59efe540] error while decoding MB 0 51, bytestream 4336
[h264 @ 0x61ed58c41480] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x61ed58c41480] error while decoding MB 0 62, bytestream 15601
[h264 @ 0x61ed5a45d1c0] error while decoding MB 33 43, bytestream -5
[h264 @ 0x61ed58c41480] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x61ed58c41480] error while decoding MB 0 49, bytestream 12660
[h264 @ 0x61ed59efe540] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x61ed59efe540] error while decoding MB 0 27, bytestream 128145
[h264 @ 0x61ed59efe540] left block unavailable for requested intra mode
[h264 @ 0x61ed59efe540] error while decoding MB 0 67, bytestream 640
[h264 @ 0x61ed5c0066c0] left block unavailable for requested intra mode
[h264 @ 0x61ed5c0066c0] error while decoding MB 0 48, bytestream 9611
[h264 @ 0x61ed58c41480] left block unavailable for requested intra mode
[h264 @ 0x61ed58c41480] error while decoding MB 0 57, bytestream 28251
[h264 @ 0x61ed5a989d40] error while decoding MB 6 60, bytestream -7
[h264 @ 0x61ed5ba99a80] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x61ed5ba99a80] error while decoding MB 0 19, bytestream 150941
[h264 @ 0x61ed58f3b400] error while decoding MB 73 66, bytestream -11
[h264 @ 0x61ed593461c0] left block unavailable for requested intra mode
[h264 @ 0x61ed593461c0] error while decoding MB 0 52, bytestream 1935
[h264 @ 0x61ed58f3b400] error while decoding MB 66 58, bytestream -7
[h264 @ 0x61ed58f3b400] left block unavailable for requested intra mode
[h264 @ 0x61ed58f3b400] error while decoding MB 0 26, bytestream 113914
#####################
[rtsp @ 0x61ed5a476200] getaddrinfo(): Name or service not known
[rtsp @ 0x61ed5a476200] getaddrinfo(): Name or service not known
[h264 @ 0x61ed56f90f80] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x61ed56f90f80] error while decoding MB 0 18, bytestream 131963
[h264 @ 0x61ed57d3a240] error while decoding MB 30 62, bytestream -13
[h264 @ 0x61ed56f90f80] left block unavailable for requested intra mode
[h264 @ 0x61ed56f90f80] error while decoding MB 0 52, bytestream 37111
[h264 @ 0x61ed52d23c00] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x61ed52d23c00] error while decoding MB 0 45, bytestream 55804
[h264 @ 0x61ed57d3a240] error while decoding MB 79 65, bytestream -11
[h264 @ 0x61ed52d23c00] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x61ed52d23c00] error while decoding MB 0 62, bytestream 9899
[h264 @ 0x61ed52d23c00] left block unavailable for requested intra mode
[h264 @ 0x61ed52d23c00] error while decoding MB 0 57, bytestream 3341
[h264 @ 0x61ed57d3a240] top block unavailable for requested intra mode -1
[h264 @ 0x61ed57d3a240] error while decoding MB 115 0, bytestream 130684
[h264 @ 0x61ed52d23c00] error while decoding MB 89 62, bytestream -25
[h264 @ 0x61ed52d23c00] left block unavailable for requested intra mode
[h264 @ 0x61ed52d23c00] error while decoding MB 0 56, bytestream 27532
[h264 @ 0x61ed52d23c00] left block unavailable for requested intra mode
[h264 @ 0x61ed52d23c00] error while decoding MB 0 46, bytestream 44625
[h264 @ 0x61ed56f90f80] error while decoding MB 3 57, bytestream -38
[h264 @ 0x61ed57d3a240] left block unavailable for requested intra mode
[h264 @ 0x61ed57d3a240] error while decoding MB 0 62, bytestream 6737
[h264 @ 0x61ed56f90f80] left block unavailable for requested intra mode
[h264 @ 0x61ed56f90f80] error while decoding MB 0 30, bytestream 96412
[h264 @ 0x61ed56f90f80] left block unavailable for requested intra mode
[h264 @ 0x61ed56f90f80] error while decoding MB 0 61, bytestream 6128
[h264 @ 0x61ed57d3a240] error while decoding MB 24 62, bytestream -18
[h264 @ 0x61ed56f90f80] error while decoding MB 12 54, bytestream -48
[h264 @ 0x61ed56f90f80] error while decoding MB 118 53, bytestream -12
[h264 @ 0x61ed56f90f80] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x61ed56f90f80] error while decoding MB 0 57, bytestream 18519
[h264 @ 0x61ed52d23c00] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x61ed52d23c00] error while decoding MB 0 61, bytestream 3749
[h264 @ 0x61ed56c629c0] left block unavailable for requested intra mode
[h264 @ 0x61ed56c629c0] error while decoding MB 0 36, bytestream 72891
[h264 @ 0x61ed6c239d00] left block unavailable for requested intra mode
[h264 @ 0x61ed6c239d00] error while decoding MB 0 51, bytestream 2475
[h264 @ 0x61ed5ac83400] left block unavailable for requested intra mode
[h264 @ 0x61ed5ac83400] error while decoding MB 0 22, bytestream 7253
[h264 @ 0x61ed5b7a72c0] left block unavailable for requested intra mode
[h264 @ 0x61ed5b7a72c0] error while decoding MB 0 25, bytestream 101679
[h264 @ 0x61ed52d25080] cabac decode of qscale diff failed at 36 37
[h264 @ 0x61ed52d25080] error while decoding MB 36 37, bytestream 8805
[h264 @ 0x61ed56a908c0] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x61ed56a908c0] error while decoding MB 0 40, bytestream 67322
[h264 @ 0x61ed56a908c0] left block unavailable for requested intra mode
[h264 @ 0x61ed56a908c0] error while decoding MB 0 17, bytestream 129667
[h264 @ 0x61ed56f90f80] left block unavailable for requested intra mode
[h264 @ 0x61ed56f90f80] error while decoding MB 0 62, bytestream 9249
[h264 @ 0x61ed5b7a72c0] left block unavailable for requested intra mode
[h264 @ 0x61ed5b7a72c0] error while decoding MB 0 30, bytestream 57996
[h264 @ 0x61ed5ac83400] error while decoding MB 6 64, bytestream -5
[h264 @ 0x61ed56c629c0] error while decoding MB 26 63, bytestream -5
[h264 @ 0x61ed56a908c0] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x61ed56a908c0] error while decoding MB 0 47, bytestream 28055
[h264 @ 0x61ed57d3a240] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x61ed57d3a240] error while decoding MB 0 54, bytestream 29524
[h264 @ 0x61ed56a908c0] left block unavailable for requested intra mode
[h264 @ 0x61ed56a908c0] error while decoding MB 0 18, bytestream 8329
[h264 @ 0x61ed57d3a240] error while decoding MB 110 66, bytestream -28
[h264 @ 0x61ed56a908c0] error while decoding MB 78 52, bytestream -9
[h264 @ 0x61ed56f90f80] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x61ed56f90f80] error while decoding MB 0 15, bytestream 109986
[h264 @ 0x61ed56c629c0] left block unavailable for requested intra mode
[h264 @ 0x61ed56c629c0] error while decoding MB 0 53, bytestream 27412
[h264 @ 0x61ed5b7a72c0] error while decoding MB 22 14, bytestream -5
[h264 @ 0x61ed6c239d00] error while decoding MB 103 40, bytestream -8
[h264 @ 0x61ed590349c0] error while decoding MB 80 46, bytestream -6
[h264 @ 0x61ed52d23c00] left block unavailable for requested intra mode
[h264 @ 0x61ed52d23c00] error while decoding MB 0 21, bytestream 16927
[h264 @ 0x61ed6c239d00] error while decoding MB 63 31, bytestream -5
[h264 @ 0x61ed52d23c00] top block unavailable for requested intra mode -1
[h264 @ 0x61ed52d23c00] error while decoding MB 107 0, bytestream 60448
[h264 @ 0x61ed56f90f80] error while decoding MB 9 33, bytestream -5
[h264 @ 0x61ed57d3a240] error while decoding MB 82 52, bytestream -6
[h264 @ 0x61ed5b7a72c0] error while decoding MB 74 52, bytestream -6
[h264 @ 0x61ed57d3a240] error while decoding MB 1 25, bytestream -9
[h264 @ 0x61ed56f90f80] error while decoding MB 29 14, bytestream -7
[h264 @ 0x61ed57d3a240] left block unavailable for requested intra mode
[h264 @ 0x61ed57d3a240] error while decoding MB 0 40, bytestream 15377
[h264 @ 0x61ed56a65f40] error while decoding MB 0 44, bytestream -10
[h264 @ 0x61ed6a435700] error while decoding MB 94 20, bytestream -5
[h264 @ 0x61ed56c629c0] error while decoding MB 66 40, bytestream -6
[h264 @ 0x61ed5ac83400] error while decoding MB 109 37, bytestream -5
[h264 @ 0x61ed6c239d00] error while decoding MB 25 39, bytestream -15
[h264 @ 0x61ed52d23c00] left block unavailable for requested intra mode
[h264 @ 0x61ed52d23c00] error while decoding MB 0 66, bytestream 1893
[h264 @ 0x61ed6a435700] left block unavailable for requested intra mode
[h264 @ 0x61ed6a435700] error while decoding MB 0 21, bytestream 94433
[h264 @ 0x61ed57d3a240] error while decoding MB 111 32, bytestream -6
[h264 @ 0x61ed5b7a72c0] left block unavailable for requested intra mode
[h264 @ 0x61ed5b7a72c0] error while decoding MB 0 49, bytestream 19511
[h264 @ 0x61ed56a908c0] error while decoding MB 4 15, bytestream -7
[h264 @ 0x61ed52d25080] left block unavailable for requested intra mode
[h264 @ 0x61ed52d25080] error while decoding MB 0 50, bytestream 1910
[h264 @ 0x61ed52d23c00] error while decoding MB 92 24, bytestream -7
Processed 52619 frames before detection.
Processed 86726 frames before detection.
Saved successfully
Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
-- <re.Match object; span=(0, 8), match='06:43:54'>
Extracted Time: 06:43:54
06:43:54
Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
-- <re.Match object; span=(0, 8), match='16:12.49'>
Extracted Time: 16:12.49
16:12.49
====== 0Nc_01 completed ========
(nc_env) hepl@HCUDT0177:~/Desktop/New_Folder/Keerthanaa/Keerthii/MAR_2025/VA_research_task/NCS/NC_00$

# %%
import cv2

# %%
cap = cv2.VideoCapture('/home/hepl/Desktop/New_Folder/Keerthanaa/Keerthii/MAR_2025/VA_research_task/NCS/NC_00/testing_date__.json')

if not cap.isOpened():
    ret, f = cap.read()
    if not ret:
        print('yes')
else:print("no")
# Out:
# yes

# %%
(nc_env) hepl@HCUDT0177:~/Desktop/New_Folder/Keerthanaa/Keerthii/MAR_2025/VA_research_task/NCS/NC_00$ python3 nc_0_test.py
====Process done====
***24-03-2025***
Trying start time: 06:00:00
Connecting to recorded video at 1742776200
URL: rtsp://admin:rmc%4012345@103.168.199.92:554/c1/b1742776200/e1742779800/replay/
[rtsp @ 0x5fcb402a8d80] getaddrinfo(): Name or service not known
[rtsp @ 0x5fcb402a8d80] getaddrinfo(): Name or service not known
Stream found at 06:00:00
Trying start time: 15:00:20
Connecting to recorded video at 1742808620
URL: rtsp://admin:rmc%4012345@103.168.199.92:554/c1/b1742808620/e1742817600/replay/
[rtsp @ 0x5fcb410d9f80] getaddrinfo(): Name or service not known
[rtsp @ 0x5fcb410d9f80] getaddrinfo(): Name or service not known
[h264 @ 0x5fcb3f103280] error while decoding MB 85 63, bytestream -6
Stream found at 15:00:20
#####################
[rtsp @ 0x5fcb3b984740] getaddrinfo(): Name or service not known
[rtsp @ 0x5fcb3b984740] getaddrinfo(): Name or service not known
[h264 @ 0x5fcb3b9828c0] cabac decode of qscale diff failed at 116 22
[h264 @ 0x5fcb3b9828c0] error while decoding MB 116 22, bytestream 2038
[h264 @ 0x5fcb41e38e40] cabac decode of qscale diff failed at 116 22
[h264 @ 0x5fcb41e38e40] error while decoding MB 116 22, bytestream 2038
[h264 @ 0x5fcb3bdab740] error while decoding MB 40 43, bytestream -11
WARNING ⚠️ NMS time limit 2.050s exceeded
WARNING ⚠️ NMS time limit 2.050s exceeded
WARNING ⚠️ NMS time limit 2.050s exceeded
WARNING ⚠️ NMS time limit 2.050s exceeded
WARNING ⚠️ NMS time limit 2.050s exceeded
WARNING ⚠️ NMS time limit 2.050s exceeded
WARNING ⚠️ NMS time limit 2.050s exceeded
WARNING ⚠️ NMS time limit 2.050s exceeded
WARNING ⚠️ NMS time limit 2.050s exceeded
WARNING ⚠️ NMS time limit 2.050s exceeded
WARNING ⚠️ NMS time limit 2.050s exceeded
WARNING ⚠️ NMS time limit 2.050s exceeded
WARNING ⚠️ NMS time limit 2.050s exceeded
WARNING ⚠️ NMS time limit 2.050s exceeded
WARNING ⚠️ NMS time limit 2.050s exceeded
WARNING ⚠️ NMS time limit 2.050s exceeded
WARNING ⚠️ NMS time limit 2.050s exceeded
WARNING ⚠️ NMS time limit 2.050s exceeded
WARNING ⚠️ NMS time limit 2.050s exceeded
WARNING ⚠️ NMS time limit 2.050s exceeded
WARNING ⚠️ NMS time limit 2.050s exceeded
WARNING ⚠️ NMS time limit 2.050s exceeded
WARNING ⚠️ NMS time limit 2.050s exceeded
WARNING ⚠️ NMS time limit 2.050s exceeded
[ WARN:0@1267.211] global cap_ffmpeg_impl.hpp:453 _opencv_ffmpeg_interrupt_callback Stream timeout triggered after 30411.815528 ms
[ WARN:0@1268.055] global cap_ffmpeg_impl.hpp:453 _opencv_ffmpeg_interrupt_callback Stream timeout triggered after 31908.117362 ms
[h264 @ 0x5fcb3bdab740] error while decoding MB 32 16, bytestream -7
WARNING ⚠️ NMS time limit 2.050s exceeded
WARNING ⚠️ NMS time limit 2.050s exceeded
No person detected in the video.
#####################
[rtsp @ 0x5fcb3c196040] getaddrinfo(): Name or service not known
[ WARN:0@1432.330] global cap_ffmpeg_impl.hpp:453 _opencv_ffmpeg_interrupt_callback Stream timeout triggered after 30091.583355 ms
[ WARN:0@1434.207] global cap.cpp:175 open VIDEOIO(CV_IMAGES): raised OpenCV exception:

OpenCV(4.11.0) /io/opencv/modules/videoio/src/cap_images.cpp:237: error: (-5:Bad argument) CAP_IMAGES: error, expected '0?[1-9][du]' pattern, got: rtsp://admin:rmc%4012345@103.168.199.92:554/c1/b1742808620/e1742817600/replay/ in function 'icvExtractPattern'


No person detected in the video.
No person detected in the video.
No person detected in the video.
Saved successfully
***25-03-2025***
Trying start time: 06:00:00
Connecting to recorded video at 1742862600
URL: rtsp://admin:rmc%4012345@103.168.199.92:554/c1/b1742862600/e1742866200/replay/
[rtsp @ 0x5fcb3bfeb640] getaddrinfo(): Name or service not known
[rtsp @ 0x5fcb3bfeb640] getaddrinfo(): Name or service not known
[h264 @ 0x5fcb3b943a40] error while decoding MB 5 23, bytestream -5
Stream found at 06:00:00
Trying start time: 15:00:20
Connecting to recorded video at 1742895020
URL: rtsp://admin:rmc%4012345@103.168.199.92:554/c1/b1742895020/e1742904000/replay/
[rtsp @ 0x5fcb3bf7b640] getaddrinfo(): Name or service not known
[rtsp @ 0x5fcb3bf7b640] getaddrinfo(): Name or service not known
Stream found at 15:00:20
#####################
[rtsp @ 0x5fcb3e7e42c0] getaddrinfo(): Name or service not known
[rtsp @ 0x5fcb3e7e42c0] getaddrinfo(): Name or service not known
[h264 @ 0x5fcb3c531440] error while decoding MB 14 50, bytestream -5
[h264 @ 0x5fcb3ff1ca00] error while decoding MB 14 50, bytestream -5
WARNING ⚠️ NMS time limit 2.050s exceeded
WARNING ⚠️ NMS time limit 2.050s exceeded
WARNING ⚠️ NMS time limit 2.050s exceeded
WARNING ⚠️ NMS time limit 2.050s exceeded
WARNING ⚠️ NMS time limit 2.050s exceeded
WARNING ⚠️ NMS time limit 2.050s exceeded
WARNING ⚠️ NMS time limit 2.050s exceeded
WARNING ⚠️ NMS time limit 2.050s exceeded
WARNING ⚠️ NMS time limit 2.050s exceeded
WARNING ⚠️ NMS time limit 2.050s exceeded
WARNING ⚠️ NMS time limit 2.050s exceeded
WARNING ⚠️ NMS time limit 2.050s exceeded
WARNING ⚠️ NMS time limit 2.050s exceeded
WARNING ⚠️ NMS time limit 2.050s exceeded
WARNING ⚠️ NMS time limit 2.050s exceeded
WARNING ⚠️ NMS time limit 2.050s exceeded
WARNING ⚠️ NMS time limit 2.050s exceeded
WARNING ⚠️ NMS time limit 2.050s exceeded
WARNING ⚠️ NMS time limit 2.050s exceeded
WARNING ⚠️ NMS time limit 2.050s exceeded
WARNING ⚠️ NMS time limit 2.050s exceeded
WARNING ⚠️ NMS time limit 2.050s exceeded
WARNING ⚠️ NMS time limit 2.050s exceeded
WARNING ⚠️ NMS time limit 2.050s exceeded
WARNING ⚠️ NMS time limit 2.050s exceeded
[ WARN:0@2525.659] global cap_ffmpeg_impl.hpp:453 _opencv_ffmpeg_interrupt_callback Stream timeout triggered after 30002.102198 ms
[ WARN:0@2525.687] global cap_ffmpeg_impl.hpp:453 _opencv_ffmpeg_interrupt_callback Stream timeout triggered after 30603.693830 ms
[h264 @ 0x5fcb3ff1ca00] error while decoding MB 54 43, bytestream -5
[h264 @ 0x5fcb3e7e1300] left block unavailable for requested intra mode
[h264 @ 0x5fcb3e7e1300] error while decoding MB 0 58, bytestream 20025
[h264 @ 0x5fcb3bef26c0] cabac decode of qscale diff failed at 24 22
[h264 @ 0x5fcb3bef26c0] error while decoding MB 24 22, bytestream 3080
[h264 @ 0x5fcb3bbd6640] error while decoding MB 78 52, bytestream -5
[h264 @ 0x5fcb41c650c0] left block unavailable for requested intra mode
[h264 @ 0x5fcb41c650c0] error while decoding MB 0 2, bytestream 25412
[h264 @ 0x5fcb41c650c0] error while decoding MB 37 48, bytestream -5
[h264 @ 0x5fcb407ec800] error while decoding MB 65 8, bytestream -8
[h264 @ 0x5fcb3e4c5100] error while decoding MB 67 61, bytestream -7
[h264 @ 0x5fcb3bbd6640] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x5fcb3bbd6640] error while decoding MB 0 45, bytestream 9173
[h264 @ 0x5fcb41fe8900] error while decoding MB 70 28, bytestream -11
[h264 @ 0x5fcb407ec800] error while decoding MB 117 6, bytestream -6
[h264 @ 0x5fcb3ff1ca00] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x5fcb3ff1ca00] error while decoding MB 0 63, bytestream 9315
[h264 @ 0x5fcb40d45080] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x5fcb40d45080] error while decoding MB 0 51, bytestream 10417
[h264 @ 0x5fcb407ec800] error while decoding MB 65 60, bytestream -5
[h264 @ 0x5fcb41c650c0] error while decoding MB 64 42, bytestream -5
[h264 @ 0x5fcb407ec800] error while decoding MB 76 24, bytestream -5
[h264 @ 0x5fcb3ff1ca00] error while decoding MB 61 55, bytestream -18
[h264 @ 0x5fcb3bbd6640] error while decoding MB 95 23, bytestream -5
[h264 @ 0x5fcb3e4c5100] error while decoding MB 117 19, bytestream -5
[h264 @ 0x5fcb3bef26c0] error while decoding MB 119 34, bytestream -5
[h264 @ 0x5fcb407ec800] error while decoding MB 57 23, bytestream -5
[h264 @ 0x5fcb3e7e1300] left block unavailable for requested intra mode
[h264 @ 0x5fcb3e7e1300] error while decoding MB 0 36, bytestream 6351
[h264 @ 0x5fcb40d45080] error while decoding MB 84 28, bytestream -13
[h264 @ 0x5fcb3f521bc0] error while decoding MB 46 50, bytestream -9
[h264 @ 0x5fcb40d45080] error while decoding MB 118 66, bytestream -5
[h264 @ 0x5fcb3f521bc0] error while decoding MB 58 24, bytestream -10
[h264 @ 0x5fcb3bef26c0] error while decoding MB 73 53, bytestream -5
[h264 @ 0x5fcb3f521bc0] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x5fcb3f521bc0] error while decoding MB 0 63, bytestream 3912
[h264 @ 0x5fcb3e7e1300] error while decoding MB 80 66, bytestream -10
[h264 @ 0x5fcb3ff1ca00] error while decoding MB 81 61, bytestream -13
[h264 @ 0x5fcb407ec800] left block unavailable for requested intra mode
[h264 @ 0x5fcb407ec800] error while decoding MB 0 25, bytestream 1135
[h264 @ 0x5fcb407d8980] error while decoding MB 51 32, bytestream -5
[h264 @ 0x5fcb3e4c5100] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x5fcb3e4c5100] error while decoding MB 0 21, bytestream 166745
[h264 @ 0x5fcb3e4c5100] error while decoding MB 21 29, bytestream -20
[h264 @ 0x5fcb41c650c0] error while decoding MB 103 28, bytestream -5
[h264 @ 0x5fcb41fe8900] error while decoding MB 82 17, bytestream -7
[h264 @ 0x5fcb3bef26c0] error while decoding MB 66 30, bytestream -8
[h264 @ 0x5fcb3c36d7c0] error while decoding MB 60 66, bytestream -5
[h264 @ 0x5fcb41fe8900] error while decoding MB 103 32, bytestream -5
[h264 @ 0x5fcb40d45080] error while decoding MB 115 50, bytestream -18
[h264 @ 0x5fcb407ec800] error while decoding MB 114 25, bytestream -20
[h264 @ 0x5fcb41c650c0] error while decoding MB 28 59, bytestream -24
[h264 @ 0x5fcb41fe8900] error while decoding MB 98 21, bytestream -13
[h264 @ 0x5fcb40d45080] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x5fcb40d45080] error while decoding MB 0 39, bytestream 13594
[h264 @ 0x5fcb407d8980] error while decoding MB 31 66, bytestream -5
[h264 @ 0x5fcb3e7e1300] error while decoding MB 80 15, bytestream -9
[h264 @ 0x5fcb3bef26c0] left block unavailable for requested intra mode
[h264 @ 0x5fcb3bef26c0] error while decoding MB 0 58, bytestream 9061
[h264 @ 0x5fcb3e7e1300] error while decoding MB 67 61, bytestream -9
[h264 @ 0x5fcb3e4c5100] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x5fcb3e4c5100] error while decoding MB 0 7, bytestream 50528
[h264 @ 0x5fcb40d45080] error while decoding MB 41 15, bytestream -5
[h264 @ 0x5fcb3ff1ca00] left block unavailable for requested intra mode
[h264 @ 0x5fcb3ff1ca00] error while decoding MB 0 47, bytestream 6711
[h264 @ 0x5fcb3e4c5100] error while decoding MB 68 53, bytestream -16
[h264 @ 0x5fcb3bbd6640] error while decoding MB 90 35, bytestream -19
[h264 @ 0x5fcb3e7e1300] error while decoding MB 47 61, bytestream -19
[h264 @ 0x5fcb3ff1ca00] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x5fcb3ff1ca00] error while decoding MB 0 47, bytestream 71902
[h264 @ 0x5fcb3ff1ca00] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x5fcb3ff1ca00] error while decoding MB 0 61, bytestream 6818
[h264 @ 0x5fcb3bbd6640] error while decoding MB 12 47, bytestream -15
[h264 @ 0x5fcb407d8980] error while decoding MB 39 58, bytestream -17
[h264 @ 0x5fcb3bef26c0] error while decoding MB 3 45, bytestream -7
[h264 @ 0x5fcb40d45080] error while decoding MB 52 16, bytestream -5
[h264 @ 0x5fcb407d8980] error while decoding MB 72 43, bytestream -20
[h264 @ 0x5fcb3ff1ca00] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x5fcb3ff1ca00] error while decoding MB 0 21, bytestream 58889
[h264 @ 0x5fcb40d45080] error while decoding MB 82 55, bytestream -14
[h264 @ 0x5fcb3c36d7c0] error while decoding MB 94 64, bytestream -24
[h264 @ 0x5fcb40d45080] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x5fcb40d45080] error while decoding MB 0 35, bytestream 4226
[h264 @ 0x5fcb407d8980] error while decoding MB 47 66, bytestream -10
[h264 @ 0x5fcb3ff1ca00] left block unavailable for requested intra mode
[h264 @ 0x5fcb3ff1ca00] error while decoding MB 0 16, bytestream 8708
[h264 @ 0x5fcb407d8980] left block unavailable for requested intra mode
[h264 @ 0x5fcb407d8980] error while decoding MB 0 19, bytestream 60154
[h264 @ 0x5fcb41fe8900] error while decoding MB 65 25, bytestream -5
[h264 @ 0x5fcb41fe8900] left block unavailable for requested intra mode
[h264 @ 0x5fcb41fe8900] error while decoding MB 0 49, bytestream 5495
[h264 @ 0x5fcb3ff1ca00] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x5fcb3ff1ca00] error while decoding MB 0 51, bytestream 6315
[h264 @ 0x5fcb41fe8900] error while decoding MB 70 60, bytestream -5
[h264 @ 0x5fcb41fe8900] error while decoding MB 21 19, bytestream -5
[h264 @ 0x5fcb41c650c0] error while decoding MB 114 5, bytestream -5
[h264 @ 0x5fcb3bef26c0] error while decoding MB 51 49, bytestream -17
[h264 @ 0x5fcb3bef26c0] error while decoding MB 22 39, bytestream -17
[h264 @ 0x5fcb40d45080] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x5fcb40d45080] error while decoding MB 0 52, bytestream 9307
[h264 @ 0x5fcb3c36d7c0] left block unavailable for requested intra mode
[h264 @ 0x5fcb3c36d7c0] error while decoding MB 0 57, bytestream 9601
[h264 @ 0x5fcb3ff1ca00] left block unavailable for requested intra mode
[h264 @ 0x5fcb3ff1ca00] error while decoding MB 0 16, bytestream 4015
[h264 @ 0x5fcb407d8980] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x5fcb407d8980] error while decoding MB 0 61, bytestream 10788
[h264 @ 0x5fcb41fe8900] error while decoding MB 66 19, bytestream -7
[h264 @ 0x5fcb407d8980] error while decoding MB 17 32, bytestream -5
[h264 @ 0x5fcb41c650c0] error while decoding MB 102 54, bytestream -8
[h264 @ 0x5fcb3ff1ca00] left block unavailable for requested intra mode
[h264 @ 0x5fcb3ff1ca00] error while decoding MB 0 62, bytestream 7300
[h264 @ 0x5fcb41fe8900] error while decoding MB 107 66, bytestream -19
[h264 @ 0x5fcb407d8980] left block unavailable for requested intra mode
[h264 @ 0x5fcb407d8980] error while decoding MB 0 57, bytestream 10314
[h264 @ 0x5fcb3bef26c0] error while decoding MB 105 28, bytestream -5
[h264 @ 0x5fcb40d45080] error while decoding MB 6 66, bytestream -18
[h264 @ 0x5fcb40d45080] left block unavailable for requested intra mode
[h264 @ 0x5fcb40d45080] error while decoding MB 0 65, bytestream 7135
[h264 @ 0x5fcb407d8980] error while decoding MB 88 29, bytestream -35
[h264 @ 0x5fcb3e7e1300] left block unavailable for requested intra mode
[h264 @ 0x5fcb3e7e1300] error while decoding MB 0 67, bytestream 8030
[h264 @ 0x5fcb40d45080] error while decoding MB 61 45, bytestream -7
[h264 @ 0x5fcb3e7e1300] error while decoding MB 58 47, bytestream -14
[h264 @ 0x5fcb407d8980] left block unavailable for requested intra mode
[h264 @ 0x5fcb407d8980] error while decoding MB 0 48, bytestream 2444
[h264 @ 0x5fcb407d8980] left block unavailable for requested intra mode
[h264 @ 0x5fcb407d8980] error while decoding MB 0 66, bytestream 5487
[h264 @ 0x5fcb3bef26c0] error while decoding MB 61 34, bytestream -5
[h264 @ 0x5fcb3f521bc0] error while decoding MB 34 26, bytestream -7
[h264 @ 0x5fcb3e7e1300] error while decoding MB 72 5, bytestream -7
[h264 @ 0x5fcb3e7e1300] error while decoding MB 68 50, bytestream -17
[h264 @ 0x5fcb3bbd6640] left block unavailable for requested intra mode
[h264 @ 0x5fcb3bbd6640] error while decoding MB 0 41, bytestream 155
[h264 @ 0x5fcb3bef26c0] error while decoding MB 115 37, bytestream -5
[h264 @ 0x5fcb407d8980] error while decoding MB 102 64, bytestream -23
[h264 @ 0x5fcb3f521bc0] error while decoding MB 26 62, bytestream -17
[h264 @ 0x5fcb41fe8900] left block unavailable for requested intra mode
[h264 @ 0x5fcb41fe8900] error while decoding MB 0 7, bytestream 10016
[h264 @ 0x5fcb41c650c0] left block unavailable for requested intra mode
[h264 @ 0x5fcb41c650c0] error while decoding MB 0 67, bytestream 1493
[h264 @ 0x5fcb40d45080] error while decoding MB 111 35, bytestream -5
[h264 @ 0x5fcb3e7e1300] error while decoding MB 78 22, bytestream -19
[h264 @ 0x5fcb41fe8900] error while decoding MB 101 55, bytestream -9
[h264 @ 0x5fcb3ff1ca00] left block unavailable for requested intra mode
[h264 @ 0x5fcb3ff1ca00] error while decoding MB 0 35, bytestream 13002
[h264 @ 0x5fcb3bbd6640] error while decoding MB 57 60, bytestream -7
[h264 @ 0x5fcb41fe8900] error while decoding MB 20 44, bytestream -6
[h264 @ 0x5fcb3e7e1300] error while decoding MB 89 63, bytestream -10
[h264 @ 0x5fcb40d45080] left block unavailable for requested intra mode
[h264 @ 0x5fcb40d45080] error while decoding MB 0 56, bytestream 9260
[h264 @ 0x5fcb407ec800] error while decoding MB 105 46, bytestream -18
[h264 @ 0x5fcb3bef26c0] left block unavailable for requested intra mode
[h264 @ 0x5fcb3bef26c0] error while decoding MB 0 43, bytestream 86701
[h264 @ 0x5fcb3bef26c0] error while decoding MB 51 58, bytestream -14
[h264 @ 0x5fcb3c36d7c0] left block unavailable for requested intra mode
[h264 @ 0x5fcb3c36d7c0] error while decoding MB 0 49, bytestream 6515
[h264 @ 0x5fcb3bbd6640] error while decoding MB 77 20, bytestream -11
[h264 @ 0x5fcb3e7e1300] error while decoding MB 90 62, bytestream -5
[h264 @ 0x5fcb3bef26c0] error while decoding MB 67 16, bytestream -7
[h264 @ 0x5fcb3c36d7c0] error while decoding MB 56 61, bytestream -5
[h264 @ 0x5fcb3bef26c0] error while decoding MB 91 63, bytestream -29
[h264 @ 0x5fcb40d45080] error while decoding MB 118 62, bytestream -23
[h264 @ 0x5fcb3c36d7c0] error while decoding MB 67 5, bytestream -5
[h264 @ 0x5fcb3ff1ca00] cabac decode of qscale diff failed at 109 15
[h264 @ 0x5fcb3ff1ca00] error while decoding MB 109 15, bytestream 1971
[h264 @ 0x5fcb3c36d7c0] error while decoding MB 43 20, bytestream -19
[h264 @ 0x5fcb3c36d7c0] error while decoding MB 25 64, bytestream -23
[h264 @ 0x5fcb407d8980] error while decoding MB 41 5, bytestream -7
[h264 @ 0x5fcb3bbd6640] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x5fcb3bbd6640] error while decoding MB 0 32, bytestream 36709
[h264 @ 0x5fcb3c36d7c0] error while decoding MB 72 50, bytestream -7
[h264 @ 0x5fcb3e4c5100] error while decoding MB 23 56, bytestream -5
[h264 @ 0x5fcb41fe8900] error while decoding MB 42 45, bytestream -25
[h264 @ 0x5fcb407d8980] error while decoding MB 17 57, bytestream -5
[h264 @ 0x5fcb3f521bc0] error while decoding MB 77 43, bytestream -5
[h264 @ 0x5fcb41fe8900] error while decoding MB 46 61, bytestream -37
[h264 @ 0x5fcb3e4c5100] left block unavailable for requested intra mode
[h264 @ 0x5fcb3e4c5100] error while decoding MB 0 52, bytestream 42953
[h264 @ 0x5fcb3c36d7c0] error while decoding MB 115 14, bytestream -5
[h264 @ 0x5fcb3e7e1300] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x5fcb3e7e1300] error while decoding MB 0 59, bytestream 6248
[h264 @ 0x5fcb41fe8900] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x5fcb41fe8900] error while decoding MB 0 50, bytestream 64710
[h264 @ 0x5fcb3f521bc0] error while decoding MB 78 14, bytestream -5
[h264 @ 0x5fcb3f521bc0] error while decoding MB 75 14, bytestream -5
[h264 @ 0x5fcb407d8980] error while decoding MB 110 54, bytestream -7
[h264 @ 0x5fcb407ec800] left block unavailable for requested intra mode
[h264 @ 0x5fcb407ec800] error while decoding MB 0 29, bytestream 66044
[h264 @ 0x5fcb3bef26c0] error while decoding MB 79 54, bytestream -7
[h264 @ 0x5fcb3c36d7c0] error while decoding MB 29 61, bytestream -15
[h264 @ 0x5fcb3c36d7c0] error while decoding MB 13 58, bytestream -20
[h264 @ 0x5fcb3bef26c0] error while decoding MB 58 58, bytestream -33
[h264 @ 0x5fcb3e4c5100] error while decoding MB 32 54, bytestream -5
[h264 @ 0x5fcb3bbd6640] error while decoding MB 11 66, bytestream -13
[h264 @ 0x5fcb3f521bc0] error while decoding MB 51 27, bytestream -5
[h264 @ 0x5fcb40d45080] error while decoding MB 115 44, bytestream -5
[h264 @ 0x5fcb407ec800] error while decoding MB 101 54, bytestream -5
[h264 @ 0x5fcb3c36d7c0] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x5fcb3c36d7c0] error while decoding MB 0 24, bytestream 109364
[h264 @ 0x5fcb3c36d7c0] error while decoding MB 99 57, bytestream -7
[h264 @ 0x5fcb41fe8900] error while decoding MB 71 64, bytestream -13
[h264 @ 0x5fcb3c36d7c0] error while decoding MB 110 22, bytestream -6
[h264 @ 0x5fcb41c650c0] error while decoding MB 22 25, bytestream -5
[h264 @ 0x5fcb3ff1ca00] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x5fcb3ff1ca00] error while decoding MB 0 50, bytestream 32397
[h264 @ 0x5fcb407ec800] error while decoding MB 109 38, bytestream -7
[h264 @ 0x5fcb3f521bc0] error while decoding MB 107 48, bytestream -31
[h264 @ 0x5fcb3e7e1300] left block unavailable for requested intra mode
[h264 @ 0x5fcb3e7e1300] error while decoding MB 0 63, bytestream 4375
[h264 @ 0x5fcb3f521bc0] error while decoding MB 101 61, bytestream -9
[h264 @ 0x5fcb3bef26c0] error while decoding MB 89 55, bytestream -7
[h264 @ 0x5fcb3bbd6640] error while decoding MB 115 4, bytestream -7
[h264 @ 0x5fcb41c650c0] error while decoding MB 15 59, bytestream -5
[h264 @ 0x5fcb40d45080] error while decoding MB 10 15, bytestream -9
[h264 @ 0x5fcb3c36d7c0] error while decoding MB 73 66, bytestream -16
[h264 @ 0x5fcb40d45080] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x5fcb40d45080] error while decoding MB 0 28, bytestream 9568
[h264 @ 0x5fcb41fe8900] error while decoding MB 106 65, bytestream -7
[h264 @ 0x5fcb3bef26c0] left block unavailable for requested intra mode
[h264 @ 0x5fcb3bef26c0] error while decoding MB 0 33, bytestream 59385
[h264 @ 0x5fcb3ff1ca00] error while decoding MB 12 23, bytestream -9
[h264 @ 0x5fcb407d8980] error while decoding MB 23 59, bytestream -14
[h264 @ 0x5fcb3bef26c0] error while decoding MB 10 15, bytestream -7
[h264 @ 0x5fcb3f521bc0] error while decoding MB 52 32, bytestream -8
[h264 @ 0x5fcb3bbd6640] error while decoding MB 67 57, bytestream -5
[h264 @ 0x5fcb3bbd6640] error while decoding MB 34 35, bytestream -5
[h264 @ 0x5fcb3c36d7c0] error while decoding MB 117 41, bytestream -21
[h264 @ 0x5fcb3ff1ca00] error while decoding MB 76 34, bytestream -5
[h264 @ 0x5fcb40d45080] error while decoding MB 69 45, bytestream -19
[h264 @ 0x5fcb407ec800] error while decoding MB 1 15, bytestream -15
[h264 @ 0x5fcb3f521bc0] error while decoding MB 94 61, bytestream -35
[h264 @ 0x5fcb3c36d7c0] error while decoding MB 3 56, bytestream -40
[h264 @ 0x5fcb3f521bc0] left block unavailable for requested intra mode
[h264 @ 0x5fcb3f521bc0] error while decoding MB 0 48, bytestream 7248
[h264 @ 0x5fcb407ec800] error while decoding MB 60 57, bytestream -7
[h264 @ 0x5fcb3bbd6640] error while decoding MB 14 16, bytestream -5
#####################
[rtsp @ 0x5fcb3df0ce80] getaddrinfo(): Name or service not known
[rtsp @ 0x5fcb3df0ce80] getaddrinfo(): Name or service not known
WARNING ⚠️ NMS time limit 2.050s exceeded
[rtsp @ 0x5fcb3df0ce80] RTP: PT=60: bad cseq 5dd5 expected=09a2
[h264 @ 0x5fcb41c63980] left block unavailable for requested intra mode
[h264 @ 0x5fcb41c63980] error while decoding MB 0 19, bytestream 12999
[h264 @ 0x5fcb3e6560c0] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x5fcb3e6560c0] error while decoding MB 0 47, bytestream 308
[h264 @ 0x5fcb418bd480] error while decoding MB 77 58, bytestream -16
[h264 @ 0x5fcb3c6fb500] error while decoding MB 45 43, bytestream -7
[h264 @ 0x5fcb3f59f880] error while decoding MB 47 67, bytestream -5
[h264 @ 0x5fcb3e6560c0] error while decoding MB 90 64, bytestream -7
[h264 @ 0x5fcb3f59f880] error while decoding MB 119 36, bytestream -5
[h264 @ 0x5fcb41c63980] error while decoding MB 84 38, bytestream -5
[h264 @ 0x5fcb3e6560c0] left block unavailable for requested intra mode
[h264 @ 0x5fcb3e6560c0] error while decoding MB 0 37, bytestream 27705
[h264 @ 0x5fcb3bc6ed40] error while decoding MB 19 59, bytestream -11
[h264 @ 0x5fcb418bd480] left block unavailable for requested intra mode
[h264 @ 0x5fcb418bd480] error while decoding MB 0 32, bytestream 10539
[h264 @ 0x5fcb3c6fb500] error while decoding MB 29 63, bytestream -5
[h264 @ 0x5fcb3f60b140] error while decoding MB 24 34, bytestream -14
[h264 @ 0x5fcb3f59f880] error while decoding MB 53 46, bytestream -5
[h264 @ 0x5fcb3bc6ed40] error while decoding MB 58 15, bytestream -5
[h264 @ 0x5fcb3f60b140] error while decoding MB 90 51, bytestream -8
[h264 @ 0x5fcb3ebabe40] error while decoding MB 87 65, bytestream -20
[h264 @ 0x5fcb41c63980] left block unavailable for requested intra mode
[h264 @ 0x5fcb41c63980] error while decoding MB 0 58, bytestream 4045
[h264 @ 0x5fcb412501c0] error while decoding MB 5 60, bytestream -5
[h264 @ 0x5fcb42025d40] error while decoding MB 2 15, bytestream -11
[h264 @ 0x5fcb3e6560c0] error while decoding MB 29 55, bytestream -8
[h264 @ 0x5fcb3bc6ed40] error while decoding MB 15 57, bytestream -8
[h264 @ 0x5fcb418c5380] error while decoding MB 1 19, bytestream -7
[h264 @ 0x5fcb418bd480] cabac decode of qscale diff failed at 16 46
[h264 @ 0x5fcb418bd480] error while decoding MB 16 46, bytestream 11084
[h264 @ 0x5fcb3ebabe40] error while decoding MB 99 62, bytestream -5
[h264 @ 0x5fcb3c6fb500] error while decoding MB 116 58, bytestream -5
[h264 @ 0x5fcb3f59f880] error while decoding MB 33 12, bytestream -5
[h264 @ 0x5fcb3f60b140] error while decoding MB 45 60, bytestream -5
[h264 @ 0x5fcb418bd480] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x5fcb418bd480] error while decoding MB 0 19, bytestream 61438
[h264 @ 0x5fcb3f60b140] error while decoding MB 94 20, bytestream -9
[h264 @ 0x5fcb412501c0] left block unavailable for requested intra mode
[h264 @ 0x5fcb412501c0] error while decoding MB 0 30, bytestream 1890
[h264 @ 0x5fcb41c63980] error while decoding MB 25 43, bytestream -5
[h264 @ 0x5fcb41c63980] error while decoding MB 116 20, bytestream -30
[h264 @ 0x5fcb3f60b140] error while decoding MB 101 34, bytestream -18
[h264 @ 0x5fcb418bd480] error while decoding MB 90 50, bytestream -5
[h264 @ 0x5fcb412501c0] error while decoding MB 65 4, bytestream -5
[h264 @ 0x5fcb3c6fb500] left block unavailable for requested intra mode
[h264 @ 0x5fcb3c6fb500] error while decoding MB 0 54, bytestream 11192
[h264 @ 0x5fcb3c6fb500] error while decoding MB 7 16, bytestream -9
[h264 @ 0x5fcb42025d40] error while decoding MB 19 37, bytestream -9
[h264 @ 0x5fcb412501c0] error while decoding MB 42 24, bytestream -5
[h264 @ 0x5fcb418bd480] error while decoding MB 8 22, bytestream -22
[h264 @ 0x5fcb3ebabe40] error while decoding MB 66 25, bytestream -8
[h264 @ 0x5fcb42025d40] error while decoding MB 74 41, bytestream -7
[h264 @ 0x5fcb3f60b140] left block unavailable for requested intra mode
[h264 @ 0x5fcb3f60b140] error while decoding MB 0 42, bytestream 13265
[h264 @ 0x5fcb41c63980] cabac decode of qscale diff failed at 3 61
[h264 @ 0x5fcb41c63980] error while decoding MB 3 61, bytestream 14157
[h264 @ 0x5fcb42025d40] left block unavailable for requested intra mode
[h264 @ 0x5fcb42025d40] error while decoding MB 0 44, bytestream 10433
[h264 @ 0x5fcb3ebabe40] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x5fcb3ebabe40] error while decoding MB 0 28, bytestream 13147
[h264 @ 0x5fcb3c6fb500] error while decoding MB 71 63, bytestream -6
[h264 @ 0x5fcb3c6fb500] error while decoding MB 41 44, bytestream -10
[h264 @ 0x5fcb3e6560c0] left block unavailable for requested intra mode
[h264 @ 0x5fcb3e6560c0] error while decoding MB 0 40, bytestream 7709
[h264 @ 0x5fcb41c63980] error while decoding MB 97 55, bytestream -8
[h264 @ 0x5fcb3bc6ed40] error while decoding MB 2 35, bytestream -9
[h264 @ 0x5fcb3c6fb500] left block unavailable for requested intra mode
[h264 @ 0x5fcb3c6fb500] error while decoding MB 0 38, bytestream 4673
[h264 @ 0x5fcb3ebabe40] error while decoding MB 116 34, bytestream -6
[h264 @ 0x5fcb3f59f880] error while decoding MB 98 62, bytestream -7
[h264 @ 0x5fcb418c5380] error while decoding MB 61 14, bytestream -5
[h264 @ 0x5fcb3e6560c0] error while decoding MB 28 46, bytestream -19
[h264 @ 0x5fcb3bc6ed40] error while decoding MB 7 39, bytestream -8
[h264 @ 0x5fcb3f59f880] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x5fcb3f59f880] error while decoding MB 0 66, bytestream 11792
[h264 @ 0x5fcb418c5380] error while decoding MB 78 38, bytestream -7
[h264 @ 0x5fcb3f60b140] error while decoding MB 55 38, bytestream -5
[h264 @ 0x5fcb3bc6ed40] left block unavailable for requested intra mode
[h264 @ 0x5fcb3bc6ed40] error while decoding MB 0 32, bytestream 6724
[h264 @ 0x5fcb41c63980] error while decoding MB 105 66, bytestream -6
[h264 @ 0x5fcb3ebabe40] error while decoding MB 12 53, bytestream -5
[h264 @ 0x5fcb41c63980] error while decoding MB 89 24, bytestream -7
[h264 @ 0x5fcb418bd480] left block unavailable for requested intra mode
[h264 @ 0x5fcb418bd480] error while decoding MB 0 45, bytestream 14031
[h264 @ 0x5fcb3c6fb500] error while decoding MB 42 53, bytestream -7
[h264 @ 0x5fcb42025d40] error while decoding MB 40 35, bytestream -5
[h264 @ 0x5fcb3f60b140] error while decoding MB 5 36, bytestream -26
[h264 @ 0x5fcb3d1a5440] error while decoding MB 44 51, bytestream -5
[h264 @ 0x5fcb42025d40] error while decoding MB 117 47, bytestream -6
[h264 @ 0x5fcb418bd480] error while decoding MB 17 31, bytestream -9
[h264 @ 0x5fcb3f59f880] error while decoding MB 79 53, bytestream -6
[h264 @ 0x5fcb3e6560c0] error while decoding MB 51 60, bytestream -9
[h264 @ 0x5fcb42025d40] error while decoding MB 67 32, bytestream -5
[h264 @ 0x5fcb3ebabe40] error while decoding MB 92 14, bytestream -7
[h264 @ 0x5fcb418c5380] error while decoding MB 112 61, bytestream -33
[h264 @ 0x5fcb418c5380] left block unavailable for requested intra mode
[h264 @ 0x5fcb418c5380] error while decoding MB 0 16, bytestream 69781
[h264 @ 0x5fcb42025d40] error while decoding MB 89 27, bytestream -5
[h264 @ 0x5fcb418bd480] error while decoding MB 12 54, bytestream -5
[h264 @ 0x5fcb3c6fb500] error while decoding MB 3 23, bytestream -6
[h264 @ 0x5fcb418c5380] error while decoding MB 115 32, bytestream -7
[h264 @ 0x5fcb41c63980] error while decoding MB 49 30, bytestream -5
[h264 @ 0x5fcb3ebabe40] error while decoding MB 95 15, bytestream -13
[h264 @ 0x5fcb3bc6ed40] error while decoding MB 7 38, bytestream -5
[h264 @ 0x5fcb3d1a5440] error while decoding MB 44 40, bytestream -10
[h264 @ 0x5fcb3bc6ed40] left block unavailable for requested intra mode
[h264 @ 0x5fcb3bc6ed40] error while decoding MB 0 52, bytestream 4533
[h264 @ 0x5fcb42025d40] left block unavailable for requested intra mode
[h264 @ 0x5fcb42025d40] error while decoding MB 0 42, bytestream 5336
[h264 @ 0x5fcb3bc6ed40] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x5fcb3bc6ed40] error while decoding MB 0 7, bytestream 68783
[h264 @ 0x5fcb412501c0] error while decoding MB 45 17, bytestream -5
[h264 @ 0x5fcb3ebabe40] error while decoding MB 72 17, bytestream -9
[h264 @ 0x5fcb3c6fb500] left block unavailable for requested intra mode
[h264 @ 0x5fcb3c6fb500] error while decoding MB 0 64, bytestream 2687
[h264 @ 0x5fcb3e6560c0] error while decoding MB 91 37, bytestream -14
[h264 @ 0x5fcb418bd480] error while decoding MB 102 59, bytestream -14
[h264 @ 0x5fcb3f59f880] left block unavailable for requested intra mode
[h264 @ 0x5fcb3f59f880] error while decoding MB 0 47, bytestream 11537
[h264 @ 0x5fcb418c5380] error while decoding MB 43 17, bytestream -7
[h264 @ 0x5fcb42025d40] error while decoding MB 98 15, bytestream -13
[h264 @ 0x5fcb3ebabe40] left block unavailable for requested intra mode
[h264 @ 0x5fcb3ebabe40] error while decoding MB 0 16, bytestream 73309
[h264 @ 0x5fcb412501c0] error while decoding MB 108 62, bytestream -6
[h264 @ 0x5fcb3ebabe40] error while decoding MB 77 58, bytestream -5
[h264 @ 0x5fcb3ebabe40] error while decoding MB 81 49, bytestream -6
[h264 @ 0x5fcb42025d40] error while decoding MB 64 54, bytestream -5
[h264 @ 0x5fcb418bd480] error while decoding MB 55 28, bytestream -5
[h264 @ 0x5fcb3ebabe40] left block unavailable for requested intra mode
[h264 @ 0x5fcb3ebabe40] error while decoding MB 0 58, bytestream 11773
[h264 @ 0x5fcb3f59f880] error while decoding MB 4 54, bytestream -5
[h264 @ 0x5fcb412501c0] error while decoding MB 4 28, bytestream -9
[h264 @ 0x5fcb3e6560c0] left block unavailable for requested intra mode
[h264 @ 0x5fcb3e6560c0] error while decoding MB 0 45, bytestream 24230
[h264 @ 0x5fcb418bd480] left block unavailable for requested intra mode
[h264 @ 0x5fcb418bd480] error while decoding MB 0 41, bytestream 10640
[h264 @ 0x5fcb3c6fb500] error while decoding MB 88 66, bytestream -7
[h264 @ 0x5fcb418bd480] error while decoding MB 109 45, bytestream -11
[h264 @ 0x5fcb3f60b140] error while decoding MB 88 15, bytestream -13
[h264 @ 0x5fcb412501c0] error while decoding MB 84 24, bytestream -5
[h264 @ 0x5fcb418c5380] error while decoding MB 111 59, bytestream -18
[h264 @ 0x5fcb3d1a5440] error while decoding MB 7 34, bytestream -5
[h264 @ 0x5fcb41c63980] error while decoding MB 30 51, bytestream -5
[h264 @ 0x5fcb41c63980] error while decoding MB 5 35, bytestream -6
[h264 @ 0x5fcb3f59f880] left block unavailable for requested intra mode
[h264 @ 0x5fcb3f59f880] error while decoding MB 0 38, bytestream 7829
[h264 @ 0x5fcb3d1a5440] left block unavailable for requested intra mode
[h264 @ 0x5fcb3d1a5440] error while decoding MB 0 19, bytestream 122944
[h264 @ 0x5fcb3f59f880] error while decoding MB 59 4, bytestream -5
[h264 @ 0x5fcb418c5380] error while decoding MB 70 21, bytestream -12
[h264 @ 0x5fcb3bc6ed40] error while decoding MB 2 21, bytestream -5
[h264 @ 0x5fcb412501c0] error while decoding MB 67 46, bytestream -8
[h264 @ 0x5fcb412501c0] error while decoding MB 56 23, bytestream -5
[h264 @ 0x5fcb3c6fb500] error while decoding MB 22 40, bytestream -8
[h264 @ 0x5fcb3f59f880] error while decoding MB 94 14, bytestream -5
[h264 @ 0x5fcb3bc6ed40] error while decoding MB 63 64, bytestream -5
[h264 @ 0x5fcb3ebabe40] error while decoding MB 1 67, bytestream -8
[h264 @ 0x5fcb418c5380] error while decoding MB 67 56, bytestream -5
[h264 @ 0x5fcb3ebabe40] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x5fcb3ebabe40] error while decoding MB 0 48, bytestream 11604
[h264 @ 0x5fcb3d1a5440] error while decoding MB 99 46, bytestream -6
[h264 @ 0x5fcb3f60b140] error while decoding MB 9 35, bytestream -9
[h264 @ 0x5fcb3c6fb500] error while decoding MB 42 52, bytestream -22
[h264 @ 0x5fcb3d1a5440] error while decoding MB 12 35, bytestream -5
[h264 @ 0x5fcb3ebabe40] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x5fcb3ebabe40] error while decoding MB 0 59, bytestream 7728
[h264 @ 0x5fcb3f60b140] error while decoding MB 36 35, bytestream -5
[h264 @ 0x5fcb3e6560c0] error while decoding MB 94 51, bytestream -7
[h264 @ 0x5fcb412501c0] error while decoding MB 118 60, bytestream -5
[h264 @ 0x5fcb3c6fb500] left block unavailable for requested intra mode
[h264 @ 0x5fcb3c6fb500] error while decoding MB 0 34, bytestream 5420
[h264 @ 0x5fcb418c5380] error while decoding MB 2 16, bytestream -9
[h264 @ 0x5fcb3d1a5440] error while decoding MB 68 40, bytestream -7
[h264 @ 0x5fcb3f59f880] error while decoding MB 65 14, bytestream -9
[h264 @ 0x5fcb3d1a5440] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x5fcb3d1a5440] error while decoding MB 0 64, bytestream 5873
[h264 @ 0x5fcb3d1a5440] left block unavailable for requested intra mode
[h264 @ 0x5fcb3d1a5440] error while decoding MB 0 15, bytestream 13430
[h264 @ 0x5fcb418bd480] error while decoding MB 112 59, bytestream -7
[h264 @ 0x5fcb41c63980] error while decoding MB 114 30, bytestream -5
[h264 @ 0x5fcb3ebabe40] error while decoding MB 113 39, bytestream -5
[h264 @ 0x5fcb3f59f880] error while decoding MB 22 40, bytestream -12
[h264 @ 0x5fcb3e6560c0] error while decoding MB 69 40, bytestream -6
[h264 @ 0x5fcb3f60b140] error while decoding MB 41 52, bytestream -6
[h264 @ 0x5fcb3e6560c0] left block unavailable for requested intra mode
[h264 @ 0x5fcb3e6560c0] error while decoding MB 0 55, bytestream 12349
[h264 @ 0x5fcb41c63980] left block unavailable for requested intra mode
[h264 @ 0x5fcb41c63980] error while decoding MB 0 57, bytestream 14419
[h264 @ 0x5fcb412501c0] error while decoding MB 84 64, bytestream -9
[h264 @ 0x5fcb3c6fb500] error while decoding MB 37 59, bytestream -7
[h264 @ 0x5fcb3d1a5440] left block unavailable for requested intra mode
[h264 @ 0x5fcb3d1a5440] error while decoding MB 0 54, bytestream 2452
[h264 @ 0x5fcb412501c0] error while decoding MB 95 18, bytestream -6
[h264 @ 0x5fcb42025d40] error while decoding MB 119 29, bytestream -5
[h264 @ 0x5fcb418bd480] error while decoding MB 54 25, bytestream -18
[h264 @ 0x5fcb3ebabe40] error while decoding MB 35 52, bytestream -6
[h264 @ 0x5fcb41c63980] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x5fcb41c63980] error while decoding MB 0 29, bytestream 36442
[h264 @ 0x5fcb418c5380] error while decoding MB 33 40, bytestream -6
[h264 @ 0x5fcb3bc6ed40] error while decoding MB 98 59, bytestream -8
[h264 @ 0x5fcb42025d40] error while decoding MB 7 50, bytestream -5
[h264 @ 0x5fcb41c63980] left block unavailable for requested intra mode
[h264 @ 0x5fcb41c63980] error while decoding MB 0 9, bytestream 12626
[h264 @ 0x5fcb412501c0] error while decoding MB 43 35, bytestream -9
[h264 @ 0x5fcb42025d40] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x5fcb42025d40] error while decoding MB 0 42, bytestream 2638
[h264 @ 0x5fcb3bc6ed40] error while decoding MB 60 45, bytestream -8
[h264 @ 0x5fcb3bc6ed40] error while decoding MB 37 47, bytestream -5
[h264 @ 0x5fcb418c5380] error while decoding MB 97 26, bytestream -7
[h264 @ 0x5fcb418c5380] cabac decode of qscale diff failed at 61 4
[h264 @ 0x5fcb418c5380] error while decoding MB 61 4, bytestream -5
[h264 @ 0x5fcb3e6560c0] error while decoding MB 45 32, bytestream -10
[h264 @ 0x5fcb3ebabe40] error while decoding MB 108 29, bytestream -9
[h264 @ 0x5fcb42025d40] error while decoding MB 84 42, bytestream -10
[h264 @ 0x5fcb3c6fb500] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x5fcb3c6fb500] error while decoding MB 0 36, bytestream 45699
[h264 @ 0x5fcb41c63980] error while decoding MB 93 36, bytestream -5
[h264 @ 0x5fcb3f60b140] error while decoding MB 97 64, bytestream -5
[h264 @ 0x5fcb41c63980] left block unavailable for requested intra mode
[h264 @ 0x5fcb41c63980] error while decoding MB 0 39, bytestream 5816
[h264 @ 0x5fcb42025d40] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x5fcb42025d40] error while decoding MB 0 50, bytestream 3246
[h264 @ 0x5fcb3e6560c0] left block unavailable for requested intra mode
[h264 @ 0x5fcb3e6560c0] error while decoding MB 0 34, bytestream 1791
[h264 @ 0x5fcb418bd480] error while decoding MB 7 39, bytestream -5
[h264 @ 0x5fcb3f59f880] error while decoding MB 31 56, bytestream -6
[h264 @ 0x5fcb3f59f880] error while decoding MB 92 38, bytestream -7
[h264 @ 0x5fcb3ebabe40] cabac decode of qscale diff failed at 93 16
[h264 @ 0x5fcb3ebabe40] error while decoding MB 93 16, bytestream 278
[h264 @ 0x5fcb412501c0] error while decoding MB 42 39, bytestream -6
[h264 @ 0x5fcb3ebabe40] error while decoding MB 65 48, bytestream -5
[h264 @ 0x5fcb418c5380] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x5fcb418c5380] error while decoding MB 0 66, bytestream 12626
[h264 @ 0x5fcb42025d40] error while decoding MB 110 15, bytestream -11
[h264 @ 0x5fcb3bc6ed40] error while decoding MB 55 49, bytestream -7
[h264 @ 0x5fcb41c63980] error while decoding MB 90 45, bytestream -8
[h264 @ 0x5fcb42025d40] error while decoding MB 118 63, bytestream -10
[h264 @ 0x5fcb418c5380] error while decoding MB 91 15, bytestream -7
[h264 @ 0x5fcb41c63980] error while decoding MB 96 14, bytestream -9
[h264 @ 0x5fcb3bc6ed40] left block unavailable for requested intra mode
[h264 @ 0x5fcb3bc6ed40] error while decoding MB 0 58, bytestream 2662
[h264 @ 0x5fcb418c5380] error while decoding MB 60 56, bytestream -6
[h264 @ 0x5fcb3f60b140] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x5fcb3f60b140] error while decoding MB 0 39, bytestream 19076
[h264 @ 0x5fcb42025d40] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x5fcb42025d40] error while decoding MB 0 63, bytestream 11043
[h264 @ 0x5fcb3e6560c0] error while decoding MB 69 23, bytestream -5
[h264 @ 0x5fcb42025d40] left block unavailable for requested intra mode
[h264 @ 0x5fcb42025d40] error while decoding MB 0 67, bytestream 4596
[h264 @ 0x5fcb418bd480] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x5fcb418bd480] error while decoding MB 0 6, bytestream 9486
[h264 @ 0x5fcb3c6fb500] error while decoding MB 67 42, bytestream -5
[h264 @ 0x5fcb3c6fb500] error while decoding MB 1 49, bytestream -6
[h264 @ 0x5fcb41c63980] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x5fcb41c63980] error while decoding MB 0 47, bytestream 102
[h264 @ 0x5fcb412501c0] error while decoding MB 99 35, bytestream -10
[h264 @ 0x5fcb3bc6ed40] error while decoding MB 12 45, bytestream -5
[h264 @ 0x5fcb3e6560c0] error while decoding MB 70 45, bytestream -8
[h264 @ 0x5fcb3bc6ed40] left block unavailable for requested intra mode
[h264 @ 0x5fcb3bc6ed40] error while decoding MB 0 44, bytestream 9377
[h264 @ 0x5fcb418bd480] error while decoding MB 41 55, bytestream -7
[h264 @ 0x5fcb3c6fb500] error while decoding MB 87 38, bytestream -5
[h264 @ 0x5fcb42025d40] error while decoding MB 35 39, bytestream -5
[h264 @ 0x5fcb3f60b140] error while decoding MB 112 15, bytestream -5
[h264 @ 0x5fcb3d1a5440] error while decoding MB 31 38, bytestream -5
[h264 @ 0x5fcb412501c0] error while decoding MB 112 34, bytestream -7
[h264 @ 0x5fcb42025d40] error while decoding MB 112 60, bytestream -5
[h264 @ 0x5fcb3bc6ed40] error while decoding MB 47 31, bytestream -7
[h264 @ 0x5fcb3d1a5440] error while decoding MB 88 36, bytestream -7
[h264 @ 0x5fcb42025d40] error while decoding MB 88 14, bytestream -5
[h264 @ 0x5fcb412501c0] error while decoding MB 112 48, bytestream -5
[h264 @ 0x5fcb3c6fb500] error while decoding MB 106 14, bytestream -5
[h264 @ 0x5fcb3f59f880] error while decoding MB 57 32, bytestream -32
[h264 @ 0x5fcb418c5380] error while decoding MB 11 39, bytestream -5
[h264 @ 0x5fcb3e6560c0] error while decoding MB 119 57, bytestream -9
[h264 @ 0x5fcb3e6560c0] error while decoding MB 115 30, bytestream -7
[h264 @ 0x5fcb3d1a5440] error while decoding MB 72 65, bytestream -6
[h264 @ 0x5fcb3f60b140] error while decoding MB 104 30, bytestream -5
[h264 @ 0x5fcb3ebabe40] error while decoding MB 119 51, bytestream -10
[h264 @ 0x5fcb3d1a5440] error while decoding MB 28 36, bytestream -7
[h264 @ 0x5fcb3e6560c0] error while decoding MB 107 60, bytestream -5
[h264 @ 0x5fcb3e6560c0] error while decoding MB 67 34, bytestream -5
[h264 @ 0x5fcb3bc6ed40] error while decoding MB 16 52, bytestream -18
[h264 @ 0x5fcb3c6fb500] error while decoding MB 47 55, bytestream -6
[h264 @ 0x5fcb3bc6ed40] error while decoding MB 0 35, bytestream -9
[h264 @ 0x5fcb3ebabe40] error while decoding MB 57 30, bytestream -9
[h264 @ 0x5fcb41c63980] error while decoding MB 36 24, bytestream -10
[h264 @ 0x5fcb3f59f880] error while decoding MB 88 35, bytestream -6
[h264 @ 0x5fcb418c5380] error while decoding MB 26 48, bytestream -5
[h264 @ 0x5fcb3bc6ed40] error while decoding MB 74 56, bytestream -10
[h264 @ 0x5fcb41c63980] error while decoding MB 85 64, bytestream -5
[h264 @ 0x5fcb3c6fb500] error while decoding MB 115 15, bytestream -5
[h264 @ 0x5fcb418c5380] error while decoding MB 118 44, bytestream -5
[h264 @ 0x5fcb41c63980] error while decoding MB 43 23, bytestream -11
[h264 @ 0x5fcb3f60b140] error while decoding MB 104 53, bytestream -14
[h264 @ 0x5fcb412501c0] error while decoding MB 94 55, bytestream -5
[h264 @ 0x5fcb3c6fb500] error while decoding MB 53 30, bytestream -5
[h264 @ 0x5fcb3d1a5440] error while decoding MB 43 58, bytestream -12
[h264 @ 0x5fcb412501c0] error while decoding MB 4 27, bytestream -7
[h264 @ 0x5fcb3f59f880] error while decoding MB 68 23, bytestream -7
[h264 @ 0x5fcb418c5380] error while decoding MB 93 20, bytestream -5
[h264 @ 0x5fcb3f59f880] error while decoding MB 115 40, bytestream -8
[h264 @ 0x5fcb418c5380] error while decoding MB 66 14, bytestream -5
[h264 @ 0x5fcb41c63980] error while decoding MB 4 52, bytestream -5
[h264 @ 0x5fcb3f60b140] left block unavailable for requested intra mode
[h264 @ 0x5fcb3f60b140] error while decoding MB 0 23, bytestream 9072
[h264 @ 0x5fcb3bc6ed40] error while decoding MB 69 17, bytestream -5
[h264 @ 0x5fcb418c5380] error while decoding MB 33 39, bytestream -5
[h264 @ 0x5fcb418c5380] error while decoding MB 92 35, bytestream -5
[h264 @ 0x5fcb418bd480] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x5fcb418bd480] error while decoding MB 0 28, bytestream 22206
[h264 @ 0x5fcb418bd480] error while decoding MB 119 46, bytestream -6
[h264 @ 0x5fcb3f59f880] error while decoding MB 11 39, bytestream -5
[h264 @ 0x5fcb3e6560c0] error while decoding MB 8 46, bytestream -6
[h264 @ 0x5fcb3d1a5440] error while decoding MB 116 56, bytestream -5
[h264 @ 0x5fcb418bd480] left block unavailable for requested intra mode
[h264 @ 0x5fcb418bd480] error while decoding MB 0 28, bytestream 8787
[h264 @ 0x5fcb418bd480] left block unavailable for requested intra mode
[h264 @ 0x5fcb418bd480] error while decoding MB 0 13, bytestream 19466
[h264 @ 0x5fcb41c63980] error while decoding MB 88 57, bytestream -5
[h264 @ 0x5fcb412501c0] error while decoding MB 100 23, bytestream -9
[h264 @ 0x5fcb3c6fb500] left block unavailable for requested intra mode
[h264 @ 0x5fcb3c6fb500] error while decoding MB 0 28, bytestream 4199
[h264 @ 0x5fcb3bc6ed40] error while decoding MB 22 34, bytestream -7
[h264 @ 0x5fcb3bc6ed40] error while decoding MB 107 44, bytestream -7
[h264 @ 0x5fcb3d1a5440] error while decoding MB 89 14, bytestream -5
[h264 @ 0x5fcb3d1a5440] error while decoding MB 90 17, bytestream -9
[h264 @ 0x5fcb3bc6ed40] error while decoding MB 3 38, bytestream -14
[h264 @ 0x5fcb3f60b140] error while decoding MB 23 39, bytestream -5
[h264 @ 0x5fcb418bd480] error while decoding MB 115 35, bytestream -5
[h264 @ 0x5fcb3e6560c0] error while decoding MB 10 30, bytestream -5
[h264 @ 0x5fcb412501c0] left block unavailable for requested intra mode
[h264 @ 0x5fcb412501c0] error while decoding MB 0 26, bytestream 9569
[h264 @ 0x5fcb41c63980] error while decoding MB 98 15, bytestream -9
[h264 @ 0x5fcb412501c0] error while decoding MB 57 60, bytestream -5
[h264 @ 0x5fcb3c6fb500] error while decoding MB 111 59, bytestream -5
[h264 @ 0x5fcb418c5380] error while decoding MB 94 17, bytestream -7
[h264 @ 0x5fcb418bd480] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x5fcb418bd480] error while decoding MB 0 15, bytestream 19562
[h264 @ 0x5fcb41c63980] error while decoding MB 78 34, bytestream -5
[h264 @ 0x5fcb42025d40] error while decoding MB 113 35, bytestream -5
[h264 @ 0x5fcb3f59f880] left block unavailable for requested intra mode
[h264 @ 0x5fcb3f59f880] error while decoding MB 0 7, bytestream 10486
[h264 @ 0x5fcb41c63980] error while decoding MB 54 60, bytestream -7
[h264 @ 0x5fcb3e6560c0] error while decoding MB 44 31, bytestream -12
[h264 @ 0x5fcb3f59f880] error while decoding MB 73 64, bytestream -5
[h264 @ 0x5fcb418c5380] error while decoding MB 26 65, bytestream -7
[h264 @ 0x5fcb3e6560c0] error while decoding MB 7 16, bytestream -7
[h264 @ 0x5fcb3bc6ed40] error while decoding MB 68 28, bytestream -7
[h264 @ 0x5fcb412501c0] error while decoding MB 5 64, bytestream -5
[h264 @ 0x5fcb3f59f880] error while decoding MB 3 57, bytestream -10
[h264 @ 0x5fcb418c5380] error while decoding MB 66 60, bytestream -5
[h264 @ 0x5fcb3c6fb500] error while decoding MB 71 48, bytestream -5
[h264 @ 0x5fcb3f59f880] error while decoding MB 76 23, bytestream -7
[h264 @ 0x5fcb3bc6ed40] error while decoding MB 17 39, bytestream -8
[h264 @ 0x5fcb3ebabe40] error while decoding MB 12 52, bytestream -6
[h264 @ 0x5fcb3d1a5440] error while decoding MB 38 56, bytestream -5
[h264 @ 0x5fcb3f60b140] error while decoding MB 43 26, bytestream -5
[h264 @ 0x5fcb3ebabe40] error while decoding MB 71 17, bytestream -9
[h264 @ 0x5fcb3f60b140] left block unavailable for requested intra mode
[h264 @ 0x5fcb3f60b140] error while decoding MB 0 45, bytestream 44145
[h264 @ 0x5fcb3ebabe40] error while decoding MB 49 4, bytestream -11
[h264 @ 0x5fcb418c5380] left block unavailable for requested intra mode
[h264 @ 0x5fcb418c5380] error while decoding MB 0 44, bytestream 4606
[h264 @ 0x5fcb3d1a5440] error while decoding MB 7 30, bytestream -5
[h264 @ 0x5fcb3f59f880] error while decoding MB 2 40, bytestream -5
[h264 @ 0x5fcb3e6560c0] error while decoding MB 34 48, bytestream -5
[h264 @ 0x5fcb418bd480] error while decoding MB 29 48, bytestream -7
[h264 @ 0x5fcb412501c0] error while decoding MB 22 43, bytestream -5
[h264 @ 0x5fcb3d1a5440] error while decoding MB 15 45, bytestream -8
[h264 @ 0x5fcb3bc6ed40] left block unavailable for requested intra mode
[h264 @ 0x5fcb3bc6ed40] error while decoding MB 0 44, bytestream 11377
[h264 @ 0x5fcb3f60b140] error while decoding MB 3 39, bytestream -5
[h264 @ 0x5fcb3bc6ed40] error while decoding MB 68 14, bytestream -7
[h264 @ 0x5fcb3ebabe40] error while decoding MB 67 34, bytestream -5
[h264 @ 0x5fcb418bd480] error while decoding MB 57 4, bytestream -9
[h264 @ 0x5fcb3f59f880] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x5fcb3f59f880] error while decoding MB 0 62, bytestream 15312
[h264 @ 0x5fcb418bd480] left block unavailable for requested intra mode
[h264 @ 0x5fcb418bd480] error while decoding MB 0 50, bytestream 5167
[h264 @ 0x5fcb3f59f880] left block unavailable for requested intra mode
[h264 @ 0x5fcb3f59f880] error while decoding MB 0 26, bytestream 17916
[h264 @ 0x5fcb42025d40] error while decoding MB 111 52, bytestream -7
[h264 @ 0x5fcb3f59f880] error while decoding MB 87 55, bytestream -5
[h264 @ 0x5fcb3e6560c0] error while decoding MB 79 58, bytestream -9
[h264 @ 0x5fcb418c5380] error while decoding MB 81 39, bytestream -5
[h264 @ 0x5fcb3f60b140] error while decoding MB 76 48, bytestream -5
[h264 @ 0x5fcb418bd480] error while decoding MB 101 42, bytestream -7
[h264 @ 0x5fcb3ebabe40] error while decoding MB 7 41, bytestream -5
[h264 @ 0x5fcb418c5380] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x5fcb418c5380] error while decoding MB 0 43, bytestream 12582
[h264 @ 0x5fcb3e6560c0] error while decoding MB 105 30, bytestream -5
[h264 @ 0x5fcb3f60b140] error while decoding MB 45 20, bytestream -9
[h264 @ 0x5fcb3d1a5440] error while decoding MB 101 17, bytestream -9
[h264 @ 0x5fcb418bd480] left block unavailable for requested intra mode
[h264 @ 0x5fcb418bd480] error while decoding MB 0 19, bytestream 15682
[h264 @ 0x5fcb412501c0] error while decoding MB 58 44, bytestream -5
[h264 @ 0x5fcb3c6fb500] error while decoding MB 49 34, bytestream -9
[h264 @ 0x5fcb3c6fb500] error while decoding MB 61 4, bytestream -5
[h264 @ 0x5fcb3ebabe40] error while decoding MB 117 61, bytestream -6
[h264 @ 0x5fcb3f60b140] error while decoding MB 82 64, bytestream -5
[h264 @ 0x5fcb42025d40] error while decoding MB 31 39, bytestream -5
[h264 @ 0x5fcb42025d40] error while decoding MB 102 27, bytestream -28
[h264 @ 0x5fcb42025d40] error while decoding MB 90 51, bytestream -5
[h264 @ 0x5fcb3ebabe40] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x5fcb3ebabe40] error while decoding MB 0 51, bytestream 19482
[h264 @ 0x5fcb418bd480] error while decoding MB 63 15, bytestream -7
[h264 @ 0x5fcb41c63980] error while decoding MB 75 48, bytestream -6
[h264 @ 0x5fcb3c6fb500] error while decoding MB 60 65, bytestream -22
[h264 @ 0x5fcb418bd480] error while decoding MB 62 30, bytestream -5
[h264 @ 0x5fcb3c6fb500] error while decoding MB 98 15, bytestream -13
[h264 @ 0x5fcb3f59f880] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x5fcb3f59f880] error while decoding MB 0 21, bytestream 25192
[h264 @ 0x5fcb42025d40] error while decoding MB 83 64, bytestream -7
[h264 @ 0x5fcb3f60b140] error while decoding MB 30 34, bytestream -5
[h264 @ 0x5fcb3bc6ed40] error while decoding MB 10 16, bytestream -11
[h264 @ 0x5fcb3ebabe40] error while decoding MB 107 40, bytestream -10
[h264 @ 0x5fcb3e6560c0] error while decoding MB 6 41, bytestream -6
[h264 @ 0x5fcb418bd480] error while decoding MB 81 34, bytestream -5
[h264 @ 0x5fcb41c63980] error while decoding MB 94 17, bytestream -7
[h264 @ 0x5fcb412501c0] error while decoding MB 110 54, bytestream -8
[h264 @ 0x5fcb41c63980] error while decoding MB 66 64, bytestream -5
[h264 @ 0x5fcb418bd480] error while decoding MB 97 18, bytestream -5
[h264 @ 0x5fcb41c63980] error while decoding MB 29 17, bytestream -9
[h264 @ 0x5fcb3f60b140] error while decoding MB 62 55, bytestream -5
[h264 @ 0x5fcb3bc6ed40] error while decoding MB 37 52, bytestream -6
[h264 @ 0x5fcb3d1a5440] error while decoding MB 79 64, bytestream -5
[h264 @ 0x5fcb3e6560c0] error while decoding MB 28 18, bytestream -7
[h264 @ 0x5fcb418bd480] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x5fcb418bd480] error while decoding MB 0 49, bytestream 6304
[h264 @ 0x5fcb412501c0] error while decoding MB 93 49, bytestream -7
[h264 @ 0x5fcb3d1a5440] error while decoding MB 36 44, bytestream -11
[h264 @ 0x5fcb42025d40] error while decoding MB 90 39, bytestream -6
[h264 @ 0x5fcb3e6560c0] error while decoding MB 34 23, bytestream -5
[h264 @ 0x5fcb3bc6ed40] error while decoding MB 106 56, bytestream -7
[h264 @ 0x5fcb3c6fb500] error while decoding MB 108 43, bytestream -27
[h264 @ 0x5fcb3f59f880] error while decoding MB 0 58, bytestream -11
[h264 @ 0x5fcb3ebabe40] error while decoding MB 77 47, bytestream -8
[h264 @ 0x5fcb3d1a5440] error while decoding MB 46 56, bytestream -5
[h264 @ 0x5fcb3bc6ed40] error while decoding MB 4 24, bytestream -8
[h264 @ 0x5fcb412501c0] error while decoding MB 119 53, bytestream -16
[h264 @ 0x5fcb418c5380] error while decoding MB 33 52, bytestream -6
[h264 @ 0x5fcb3d1a5440] left block unavailable for requested intra mode
[h264 @ 0x5fcb3d1a5440] error while decoding MB 0 29, bytestream 9427
[h264 @ 0x5fcb42025d40] error while decoding MB 88 33, bytestream -5
[h264 @ 0x5fcb3bc6ed40] error while decoding MB 59 4, bytestream -7
[h264 @ 0x5fcb3c6fb500] error while decoding MB 23 52, bytestream -6
[h264 @ 0x5fcb41c63980] error while decoding MB 61 23, bytestream -5
[h264 @ 0x5fcb3d1a5440] error while decoding MB 110 17, bytestream -5
[h264 @ 0x5fcb3d1a5440] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x5fcb3d1a5440] error while decoding MB 0 46, bytestream 1568
[h264 @ 0x5fcb41c63980] error while decoding MB 21 26, bytestream -5
[h264 @ 0x5fcb418bd480] error while decoding MB 78 58, bytestream -5
[h264 @ 0x5fcb412501c0] error while decoding MB 77 46, bytestream -7
[h264 @ 0x5fcb3bc6ed40] error while decoding MB 78 58, bytestream -5
[h264 @ 0x5fcb3f60b140] error while decoding MB 22 34, bytestream -5
[h264 @ 0x5fcb3ebabe40] error while decoding MB 21 59, bytestream -25
[h264 @ 0x5fcb418bd480] error while decoding MB 13 48, bytestream -7
[h264 @ 0x5fcb41c63980] cabac decode of qscale diff failed at 5 7
[h264 @ 0x5fcb41c63980] error while decoding MB 5 7, bytestream 13144
[h264 @ 0x5fcb418c5380] error while decoding MB 89 38, bytestream -5
[h264 @ 0x5fcb3bc6ed40] error while decoding MB 5 61, bytestream -6
[h264 @ 0x5fcb3d1a5440] error while decoding MB 3 15, bytestream -5
[h264 @ 0x5fcb3f60b140] error while decoding MB 104 55, bytestream -19
[h264 @ 0x5fcb3bc6ed40] error while decoding MB 26 39, bytestream -5
[h264 @ 0x5fcb41c63980] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x5fcb41c63980] error while decoding MB 0 20, bytestream 22920
[h264 @ 0x5fcb412501c0] error while decoding MB 56 4, bytestream -5
[h264 @ 0x5fcb3e6560c0] error while decoding MB 37 39, bytestream -5
[h264 @ 0x5fcb3f60b140] error while decoding MB 67 14, bytestream -9
[h264 @ 0x5fcb3ebabe40] error while decoding MB 46 51, bytestream -6
[h264 @ 0x5fcb42025d40] error while decoding MB 53 42, bytestream -5
[h264 @ 0x5fcb41c63980] error while decoding MB 15 43, bytestream -5
[h264 @ 0x5fcb418bd480] error while decoding MB 60 39, bytestream -8
[h264 @ 0x5fcb412501c0] error while decoding MB 35 56, bytestream -5
[h264 @ 0x5fcb412501c0] error while decoding MB 82 61, bytestream -7
[h264 @ 0x5fcb3f59f880] error while decoding MB 0 61, bytestream -5
[h264 @ 0x5fcb3d1a5440] error while decoding MB 56 64, bytestream -6
[h264 @ 0x5fcb3d1a5440] error while decoding MB 81 47, bytestream -5
[h264 @ 0x5fcb418bd480] error while decoding MB 104 44, bytestream -5
[h264 @ 0x5fcb3e6560c0] error while decoding MB 22 26, bytestream -20
[h264 @ 0x5fcb3e6560c0] error while decoding MB 114 45, bytestream -6
[h264 @ 0x5fcb41c63980] error while decoding MB 61 33, bytestream -5
[h264 @ 0x5fcb412501c0] error while decoding MB 62 14, bytestream -13
[h264 @ 0x5fcb3f60b140] error while decoding MB 90 38, bytestream -5
[h264 @ 0x5fcb3c6fb500] error while decoding MB 110 17, bytestream -8
[h264 @ 0x5fcb3f59f880] error while decoding MB 97 58, bytestream -5
[h264 @ 0x5fcb418bd480] error while decoding MB 69 42, bytestream -5
[h264 @ 0x5fcb418bd480] left block unavailable for requested intra mode
[h264 @ 0x5fcb418bd480] error while decoding MB 0 17, bytestream 13937
[h264 @ 0x5fcb3e6560c0] error while decoding MB 105 62, bytestream -5
[h264 @ 0x5fcb3bc6ed40] error while decoding MB 95 14, bytestream -5
[h264 @ 0x5fcb3ebabe40] left block unavailable for requested intra mode
[h264 @ 0x5fcb3ebabe40] error while decoding MB 0 16, bytestream 1502
[h264 @ 0x5fcb3f60b140] error while decoding MB 86 63, bytestream -5
[h264 @ 0x5fcb3ebabe40] error while decoding MB 21 55, bytestream -8
[h264 @ 0x5fcb3d1a5440] error while decoding MB 116 41, bytestream -8
[h264 @ 0x5fcb3f60b140] error while decoding MB 43 20, bytestream -9
[h264 @ 0x5fcb41c63980] error while decoding MB 94 38, bytestream -16
[h264 @ 0x5fcb3bc6ed40] error while decoding MB 92 38, bytestream -5
[h264 @ 0x5fcb412501c0] error while decoding MB 101 43, bytestream -5
[h264 @ 0x5fcb3c6fb500] error while decoding MB 57 32, bytestream -19
[h264 @ 0x5fcb42025d40] error while decoding MB 93 46, bytestream -5
[h264 @ 0x5fcb418c5380] error while decoding MB 22 30, bytestream -7
[h264 @ 0x5fcb418c5380] error while decoding MB 86 17, bytestream -5
[h264 @ 0x5fcb3c6fb500] error while decoding MB 118 27, bytestream -9
[h264 @ 0x5fcb42025d40] error while decoding MB 26 56, bytestream -5
[h264 @ 0x5fcb3f60b140] error while decoding MB 89 54, bytestream -9
[h264 @ 0x5fcb3e6560c0] error while decoding MB 57 56, bytestream -7
[h264 @ 0x5fcb3d1a5440] left block unavailable for requested intra mode
[h264 @ 0x5fcb3d1a5440] error while decoding MB 0 30, bytestream 4521
[h264 @ 0x5fcb3c6fb500] error while decoding MB 34 20, bytestream -5
[h264 @ 0x5fcb3bc6ed40] error while decoding MB 31 42, bytestream -5
[h264 @ 0x5fcb418bd480] error while decoding MB 24 47, bytestream -8
[h264 @ 0x5fcb3d1a5440] error while decoding MB 109 59, bytestream -6
[h264 @ 0x5fcb41c63980] error while decoding MB 103 42, bytestream -5
[h264 @ 0x5fcb3ebabe40] error while decoding MB 93 17, bytestream -9
[h264 @ 0x5fcb3d1a5440] left block unavailable for requested intra mode
[h264 @ 0x5fcb3d1a5440] error while decoding MB 0 35, bytestream 9475
[h264 @ 0x5fcb3c6fb500] error while decoding MB 59 39, bytestream -6
[h264 @ 0x5fcb3f60b140] error while decoding MB 115 45, bytestream -24
[h264 @ 0x5fcb3f60b140] error while decoding MB 102 29, bytestream -9
[h264 @ 0x5fcb3bc6ed40] error while decoding MB 1 15, bytestream -6
[h264 @ 0x5fcb3d1a5440] error while decoding MB 41 51, bytestream -8
[h264 @ 0x5fcb412501c0] error while decoding MB 55 34, bytestream -7
[h264 @ 0x5fcb3d1a5440] error while decoding MB 106 45, bytestream -9
[h264 @ 0x5fcb3c6fb500] error while decoding MB 15 18, bytestream -5
[h264 @ 0x5fcb418c5380] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x5fcb418c5380] error while decoding MB 0 20, bytestream 41050
[h264 @ 0x5fcb42025d40] error while decoding MB 100 14, bytestream -9
[h264 @ 0x5fcb3e6560c0] error while decoding MB 4 52, bytestream -6
[h264 @ 0x5fcb3ebabe40] error while decoding MB 61 30, bytestream -5
[h264 @ 0x5fcb418c5380] left block unavailable for requested intra mode
[h264 @ 0x5fcb418c5380] error while decoding MB 0 51, bytestream 14308
[h264 @ 0x5fcb412501c0] error while decoding MB 34 21, bytestream -9
[h264 @ 0x5fcb3c6fb500] error while decoding MB 3 15, bytestream -11
[h264 @ 0x5fcb3bc6ed40] error while decoding MB 106 44, bytestream -8
[h264 @ 0x5fcb3c6fb500] error while decoding MB 95 43, bytestream -5
[h264 @ 0x5fcb42025d40] cabac decode of qscale diff failed at 77 47
[h264 @ 0x5fcb42025d40] error while decoding MB 77 47, bytestream -8
[h264 @ 0x5fcb3f60b140] error while decoding MB 14 26, bytestream -16
[h264 @ 0x5fcb418c5380] error while decoding MB 112 34, bytestream -7
[h264 @ 0x5fcb42025d40] left block unavailable for requested intra mode
[h264 @ 0x5fcb42025d40] error while decoding MB 0 41, bytestream 10071
[h264 @ 0x5fcb418bd480] left block unavailable for requested intra mode
[h264 @ 0x5fcb418bd480] error while decoding MB 0 47, bytestream -5
[h264 @ 0x5fcb3bc6ed40] error while decoding MB 97 19, bytestream -16
[h264 @ 0x5fcb418c5380] error while decoding MB 70 50, bytestream -8
[h264 @ 0x5fcb418bd480] left block unavailable for requested intra mode
[h264 @ 0x5fcb418bd480] error while decoding MB 0 23, bytestream 8205
[h264 @ 0x5fcb3c6fb500] error while decoding MB 105 47, bytestream -5
[h264 @ 0x5fcb3f59f880] error while decoding MB 3 40, bytestream -9
[h264 @ 0x5fcb3f60b140] error while decoding MB 11 51, bytestream -7
[h264 @ 0x5fcb418c5380] error while decoding MB 75 64, bytestream -5
[h264 @ 0x5fcb418bd480] error while decoding MB 28 46, bytestream -5
[h264 @ 0x5fcb3bc6ed40] error while decoding MB 16 46, bytestream -10
[h264 @ 0x5fcb418c5380] left block unavailable for requested intra mode
[h264 @ 0x5fcb418c5380] error while decoding MB 0 23, bytestream 6877
[h264 @ 0x5fcb3f59f880] error while decoding MB 8 44, bytestream -5
[h264 @ 0x5fcb412501c0] error while decoding MB 76 31, bytestream -5
[h264 @ 0x5fcb418c5380] error while decoding MB 23 27, bytestream -5
[h264 @ 0x5fcb418bd480] error while decoding MB 118 34, bytestream -7
[h264 @ 0x5fcb42025d40] error while decoding MB 107 16, bytestream -15
[h264 @ 0x5fcb3f60b140] error while decoding MB 9 16, bytestream -7
[h264 @ 0x5fcb3ebabe40] error while decoding MB 57 14, bytestream -7
[h264 @ 0x5fcb3f60b140] error while decoding MB 71 41, bytestream -16
[h264 @ 0x5fcb3bc6ed40] error while decoding MB 119 34, bytestream -5
[h264 @ 0x5fcb3bc6ed40] error while decoding MB 109 24, bytestream -5
[h264 @ 0x5fcb3f59f880] left block unavailable for requested intra mode
[h264 @ 0x5fcb3f59f880] error while decoding MB 0 35, bytestream 7201
[h264 @ 0x5fcb3f59f880] error while decoding MB 1 1, bytestream -8
[h264 @ 0x5fcb3bc6ed40] error while decoding MB 58 24, bytestream -5
[h264 @ 0x5fcb3bc6ed40] error while decoding MB 64 15, bytestream -6
[h264 @ 0x5fcb3f59f880] error while decoding MB 33 58, bytestream -9
[h264 @ 0x5fcb3ebabe40] error while decoding MB 76 62, bytestream -14
[h264 @ 0x5fcb3f59f880] error while decoding MB 89 15, bytestream -5
[h264 @ 0x5fcb3f59f880] error while decoding MB 60 21, bytestream -32
[h264 @ 0x5fcb418bd480] error while decoding MB 10 16, bytestream -16
[h264 @ 0x5fcb3d1a5440] left block unavailable for requested intra mode
[h264 @ 0x5fcb3d1a5440] error while decoding MB 0 65, bytestream 12410
[h264 @ 0x5fcb3f60b140] error while decoding MB 103 20, bytestream -5
[h264 @ 0x5fcb3e6560c0] error while decoding MB 55 52, bytestream -9
[h264 @ 0x5fcb42025d40] error while decoding MB 93 20, bytestream -7
[h264 @ 0x5fcb3e6560c0] error while decoding MB 22 60, bytestream -10
[h264 @ 0x5fcb41c63980] error while decoding MB 13 16, bytestream -7
[h264 @ 0x5fcb3ebabe40] left block unavailable for requested intra mode
[h264 @ 0x5fcb3ebabe40] error while decoding MB 0 23, bytestream 2049
[h264 @ 0x5fcb3f60b140] error while decoding MB 49 22, bytestream -7
[h264 @ 0x5fcb3d1a5440] error while decoding MB 8 50, bytestream -5
[h264 @ 0x5fcb3d1a5440] error while decoding MB 11 35, bytestream -26
[h264 @ 0x5fcb3f59f880] error while decoding MB 43 28, bytestream -7
[h264 @ 0x5fcb41c63980] error while decoding MB 84 24, bytestream -7
[h264 @ 0x5fcb3f59f880] error while decoding MB 66 43, bytestream -5
[h264 @ 0x5fcb3d1a5440] left block unavailable for requested intra mode
[h264 @ 0x5fcb3d1a5440] error while decoding MB 0 17, bytestream 8217
[h264 @ 0x5fcb3f60b140] error while decoding MB 8 65, bytestream -28
[h264 @ 0x5fcb418bd480] error while decoding MB 1 21, bytestream -5
[h264 @ 0x5fcb42025d40] error while decoding MB 5 51, bytestream -5
[h264 @ 0x5fcb41c63980] error while decoding MB 2 15, bytestream -7
[h264 @ 0x5fcb3bc6ed40] error while decoding MB 15 61, bytestream -16
[h264 @ 0x5fcb3f59f880] error while decoding MB 110 60, bytestream -40
[h264 @ 0x5fcb3ebabe40] left block unavailable for requested intra mode
[h264 @ 0x5fcb3ebabe40] error while decoding MB 0 64, bytestream 9421
[h264 @ 0x5fcb41c63980] error while decoding MB 24 50, bytestream -16
[h264 @ 0x5fcb3f59f880] error while decoding MB 45 58, bytestream -7
[h264 @ 0x5fcb3ebabe40] left block unavailable for requested intra mode
[h264 @ 0x5fcb3ebabe40] error while decoding MB 0 63, bytestream 7435
[h264 @ 0x5fcb3c6fb500] error while decoding MB 72 46, bytestream -16
[h264 @ 0x5fcb3f59f880] error while decoding MB 100 62, bytestream -5
[h264 @ 0x5fcb3d1a5440] error while decoding MB 63 43, bytestream -6
[h264 @ 0x5fcb3e6560c0] error while decoding MB 78 54, bytestream -27
[h264 @ 0x5fcb3f60b140] error while decoding MB 108 14, bytestream -7
[h264 @ 0x5fcb3ebabe40] error while decoding MB 15 48, bytestream -7
[h264 @ 0x5fcb41c63980] left block unavailable for requested intra mode
[h264 @ 0x5fcb41c63980] error while decoding MB 0 52, bytestream 1562
[h264 @ 0x5fcb3f59f880] error while decoding MB 34 18, bytestream -7
[h264 @ 0x5fcb42025d40] error while decoding MB 10 41, bytestream -6
[h264 @ 0x5fcb42025d40] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x5fcb42025d40] error while decoding MB 0 51, bytestream 3094
[h264 @ 0x5fcb3ebabe40] left block unavailable for requested intra mode
[h264 @ 0x5fcb3ebabe40] error while decoding MB 0 58, bytestream 6265
[h264 @ 0x5fcb42025d40] left block unavailable for requested intra mode
[h264 @ 0x5fcb42025d40] error while decoding MB 0 65, bytestream 4076
[h264 @ 0x5fcb3e6560c0] error while decoding MB 16 67, bytestream -13
[h264 @ 0x5fcb418bd480] error while decoding MB 39 18, bytestream -9
[h264 @ 0x5fcb418bd480] left block unavailable for requested intra mode
[h264 @ 0x5fcb418bd480] error while decoding MB 0 67, bytestream 5655
[h264 @ 0x5fcb3e6560c0] error while decoding MB 71 61, bytestream -7
[h264 @ 0x5fcb3f59f880] error while decoding MB 59 62, bytestream -16
[h264 @ 0x5fcb3e6560c0] error while decoding MB 26 59, bytestream -7
[h264 @ 0x5fcb3e6560c0] error while decoding MB 1 53, bytestream -28
[h264 @ 0x5fcb3f59f880] error while decoding MB 97 52, bytestream -5
[h264 @ 0x5fcb412501c0] error while decoding MB 0 54, bytestream -23
[h264 @ 0x5fcb42025d40] error while decoding MB 27 66, bytestream -9
[h264 @ 0x5fcb42025d40] error while decoding MB 116 27, bytestream -5
[h264 @ 0x5fcb41c63980] error while decoding MB 9 62, bytestream -20
[h264 @ 0x5fcb3f60b140] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x5fcb3f60b140] error while decoding MB 0 53, bytestream 4345
[h264 @ 0x5fcb3c6fb500] error while decoding MB 21 49, bytestream -5
[h264 @ 0x5fcb3f60b140] error while decoding MB 8 54, bytestream -7
[h264 @ 0x5fcb412501c0] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x5fcb412501c0] error while decoding MB 0 62, bytestream 8927
[h264 @ 0x5fcb3d1a5440] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x5fcb3d1a5440] error while decoding MB 0 64, bytestream 2850
[h264 @ 0x5fcb3d1a5440] error while decoding MB 2 54, bytestream -18
[h264 @ 0x5fcb3e6560c0] error while decoding MB 48 50, bytestream -16
[h264 @ 0x5fcb3bc6ed40] error while decoding MB 25 33, bytestream -5
[h264 @ 0x5fcb418bd480] error while decoding MB 66 64, bytestream -6
[h264 @ 0x5fcb3bc6ed40] error while decoding MB 70 61, bytestream -5
[h264 @ 0x5fcb418c5380] error while decoding MB 31 60, bytestream -35
[h264 @ 0x5fcb418c5380] error while decoding MB 48 17, bytestream -42
[h264 @ 0x5fcb41c63980] error while decoding MB 64 61, bytestream -5
[h264 @ 0x5fcb3e6560c0] left block unavailable for requested intra mode
[h264 @ 0x5fcb3e6560c0] error while decoding MB 0 20, bytestream 4518
[h264 @ 0x5fcb418bd480] error while decoding MB 50 25, bytestream -5
[h264 @ 0x5fcb3f59f880] error while decoding MB 59 62, bytestream -20
[h264 @ 0x5fcb3e6560c0] error while decoding MB 83 24, bytestream -11
[h264 @ 0x5fcb3e6560c0] error while decoding MB 2 35, bytestream -5
[h264 @ 0x5fcb3ebabe40] error while decoding MB 24 22, bytestream -30
[h264 @ 0x5fcb418bd480] left block unavailable for requested intra mode
[h264 @ 0x5fcb418bd480] error while decoding MB 0 29, bytestream 41933
[h264 @ 0x5fcb3c6fb500] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x5fcb3c6fb500] error while decoding MB 0 64, bytestream 3466
[h264 @ 0x5fcb42025d40] error while decoding MB 81 57, bytestream -21
[h264 @ 0x5fcb3ebabe40] error while decoding MB 66 67, bytestream -14
[h264 @ 0x5fcb3d1a5440] error while decoding MB 36 64, bytestream -8
[h264 @ 0x5fcb3ebabe40] error while decoding MB 75 34, bytestream -5
[h264 @ 0x5fcb412501c0] error while decoding MB 8 15, bytestream -7
[h264 @ 0x5fcb3c6fb500] error while decoding MB 50 36, bytestream -5
[h264 @ 0x5fcb3bc6ed40] error while decoding MB 2 18, bytestream -9
[h264 @ 0x5fcb3bc6ed40] left block unavailable for requested intra mode
[h264 @ 0x5fcb3bc6ed40] error while decoding MB 0 67, bytestream 6309
[h264 @ 0x5fcb41c63980] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x5fcb41c63980] error while decoding MB 0 53, bytestream 1333
[h264 @ 0x5fcb418c5380] error while decoding MB 34 56, bytestream -19
[h264 @ 0x5fcb3f59f880] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x5fcb3f59f880] error while decoding MB 0 61, bytestream 3765
[h264 @ 0x5fcb3f59f880] error while decoding MB 106 64, bytestream -15
[h264 @ 0x5fcb3ebabe40] error while decoding MB 56 53, bytestream -5
[h264 @ 0x5fcb418bd480] error while decoding MB 80 41, bytestream -5
[h264 @ 0x5fcb3c6fb500] error while decoding MB 36 65, bytestream -14
[h264 @ 0x5fcb42025d40] left block unavailable for requested intra mode
[h264 @ 0x5fcb42025d40] error while decoding MB 0 49, bytestream 39140
[h264 @ 0x5fcb3e6560c0] error while decoding MB 118 32, bytestream -5
[h264 @ 0x5fcb3bc6ed40] error while decoding MB 68 66, bytestream -17
[h264 @ 0x5fcb3bc6ed40] error while decoding MB 100 40, bytestream -8
[h264 @ 0x5fcb3f59f880] error while decoding MB 84 58, bytestream -7
[h264 @ 0x5fcb412501c0] error while decoding MB 53 40, bytestream -9
[h264 @ 0x5fcb3bc6ed40] error while decoding MB 4 62, bytestream -9
[h264 @ 0x5fcb3e6560c0] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x5fcb3e6560c0] error while decoding MB 0 53, bytestream 3278
[h264 @ 0x5fcb3f60b140] error while decoding MB 32 48, bytestream -11
[h264 @ 0x5fcb418c5380] error while decoding MB 38 25, bytestream -5
[h264 @ 0x5fcb412501c0] error while decoding MB 107 45, bytestream -30
[h264 @ 0x5fcb3e6560c0] error while decoding MB 57 14, bytestream -5
[h264 @ 0x5fcb418bd480] cabac decode of qscale diff failed at 104 51
[h264 @ 0x5fcb418bd480] error while decoding MB 104 51, bytestream 6977
[h264 @ 0x5fcb3e6560c0] error while decoding MB 100 66, bytestream -33
[h264 @ 0x5fcb3bc6ed40] error while decoding MB 87 57, bytestream -5
[h264 @ 0x5fcb412501c0] cabac decode of qscale diff failed at 44 23
[h264 @ 0x5fcb412501c0] error while decoding MB 44 23, bytestream 252
[h264 @ 0x5fcb3f60b140] error while decoding MB 37 24, bytestream -27
[h264 @ 0x5fcb3f60b140] error while decoding MB 66 62, bytestream -15
[h264 @ 0x5fcb3f60b140] error while decoding MB 55 14, bytestream -5
[h264 @ 0x5fcb3d1a5440] error while decoding MB 118 2, bytestream -20
[h264 @ 0x5fcb3d1a5440] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x5fcb3d1a5440] error while decoding MB 0 44, bytestream 3933
[h264 @ 0x5fcb42025d40] error while decoding MB 46 19, bytestream -5
[h264 @ 0x5fcb418c5380] left block unavailable for requested intra mode
[h264 @ 0x5fcb418c5380] error while decoding MB 0 26, bytestream 3268
[h264 @ 0x5fcb412501c0] error while decoding MB 76 53, bytestream -21
[h264 @ 0x5fcb3f59f880] left block unavailable for requested intra mode
[h264 @ 0x5fcb3f59f880] error while decoding MB 0 15, bytestream 59850
[h264 @ 0x5fcb41c63980] error while decoding MB 60 50, bytestream -15
[h264 @ 0x5fcb3c6fb500] error while decoding MB 29 40, bytestream -16
[h264 @ 0x5fcb3ebabe40] error while decoding MB 96 61, bytestream -5
[h264 @ 0x5fcb3d1a5440] error while decoding MB 85 59, bytestream -5
[h264 @ 0x5fcb42025d40] error while decoding MB 23 26, bytestream -5
[h264 @ 0x5fcb3f59f880] error while decoding MB 106 55, bytestream -36
[h264 @ 0x5fcb3ebabe40] error while decoding MB 70 61, bytestream -5
[h264 @ 0x5fcb3e6560c0] error while decoding MB 91 23, bytestream -15
[h264 @ 0x5fcb412501c0] error while decoding MB 3 63, bytestream -12
[h264 @ 0x5fcb3f59f880] error while decoding MB 78 46, bytestream -19
[h264 @ 0x5fcb418c5380] error while decoding MB 45 18, bytestream -7
[h264 @ 0x5fcb42025d40] error while decoding MB 56 31, bytestream -19
[h264 @ 0x5fcb3e6560c0] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x5fcb3e6560c0] error while decoding MB 0 65, bytestream 60844
[h264 @ 0x5fcb418bd480] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x5fcb418bd480] error while decoding MB 0 41, bytestream 41159
[h264 @ 0x5fcb3c6fb500] error while decoding MB 19 44, bytestream -5
[h264 @ 0x5fcb42025d40] error while decoding MB 24 54, bytestream -24
[h264 @ 0x5fcb418bd480] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x5fcb418bd480] error while decoding MB 0 19, bytestream 144127
[h264 @ 0x5fcb3ebabe40] error while decoding MB 11 63, bytestream -7
[h264 @ 0x5fcb3bc6ed40] error while decoding MB 105 66, bytestream -9
[h264 @ 0x5fcb412501c0] error while decoding MB 47 58, bytestream -10
[h264 @ 0x5fcb3c6fb500] error while decoding MB 7 18, bytestream -5
[h264 @ 0x5fcb3f59f880] error while decoding MB 105 62, bytestream -5
[h264 @ 0x5fcb3f60b140] left block unavailable for requested intra mode
[h264 @ 0x5fcb3f60b140] error while decoding MB 0 27, bytestream -5
[h264 @ 0x5fcb418c5380] error while decoding MB 68 61, bytestream -5
[h264 @ 0x5fcb418c5380] error while decoding MB 24 43, bytestream -9
[h264 @ 0x5fcb3d1a5440] error while decoding MB 89 14, bytestream -11
[h264 @ 0x5fcb42025d40] error while decoding MB 0 18, bytestream -15
[h264 @ 0x5fcb41c63980] error while decoding MB 55 26, bytestream -10
[h264 @ 0x5fcb3c6fb500] error while decoding MB 10 25, bytestream -5
[h264 @ 0x5fcb3f60b140] error while decoding MB 2 15, bytestream -5
[h264 @ 0x5fcb3f60b140] error while decoding MB 119 41, bytestream -5
[h264 @ 0x5fcb42025d40] error while decoding MB 27 60, bytestream -28
[h264 @ 0x5fcb3e6560c0] error while decoding MB 66 14, bytestream -11
[h264 @ 0x5fcb418c5380] error while decoding MB 15 63, bytestream -23
[h264 @ 0x5fcb3f60b140] error while decoding MB 49 17, bytestream -7
[h264 @ 0x5fcb3c6fb500] error while decoding MB 47 54, bytestream -23
[h264 @ 0x5fcb3e6560c0] error while decoding MB 106 55, bytestream -7
[h264 @ 0x5fcb3f59f880] error while decoding MB 100 62, bytestream -10
[h264 @ 0x5fcb41c63980] error while decoding MB 22 60, bytestream -5
[h264 @ 0x5fcb3c6fb500] error while decoding MB 53 43, bytestream -5
[h264 @ 0x5fcb42025d40] error while decoding MB 14 63, bytestream -23
[h264 @ 0x5fcb3f59f880] error while decoding MB 24 47, bytestream -13
[h264 @ 0x5fcb3d1a5440] left block unavailable for requested intra mode
[h264 @ 0x5fcb3d1a5440] error while decoding MB 0 43, bytestream 2022
[h264 @ 0x5fcb412501c0] error while decoding MB 107 42, bytestream -7
[h264 @ 0x5fcb3c6fb500] left block unavailable for requested intra mode
[h264 @ 0x5fcb3c6fb500] error while decoding MB 0 63, bytestream 3301
[h264 @ 0x5fcb418c5380] left block unavailable for requested intra mode
[h264 @ 0x5fcb418c5380] error while decoding MB 0 33, bytestream 6405
[h264 @ 0x5fcb412501c0] error while decoding MB 22 41, bytestream -23
[h264 @ 0x5fcb418c5380] error while decoding MB 57 32, bytestream -28
[h264 @ 0x5fcb418c5380] error while decoding MB 94 21, bytestream -28
[h264 @ 0x5fcb3c6fb500] error while decoding MB 19 52, bytestream -29
[h264 @ 0x5fcb3f59f880] error while decoding MB 70 55, bytestream -12
[h264 @ 0x5fcb412501c0] error while decoding MB 14 53, bytestream -20
[h264 @ 0x5fcb3c6fb500] error while decoding MB 71 17, bytestream -7
[h264 @ 0x5fcb41c63980] error while decoding MB 112 45, bytestream -6
[h264 @ 0x5fcb412501c0] error while decoding MB 12 63, bytestream -21
[h264 @ 0x5fcb418bd480] error while decoding MB 51 65, bytestream -5
[h264 @ 0x5fcb41c63980] error while decoding MB 25 18, bytestream -15
[h264 @ 0x5fcb42025d40] error while decoding MB 87 32, bytestream -5
[h264 @ 0x5fcb3d1a5440] error while decoding MB 56 67, bytestream -5
[h264 @ 0x5fcb412501c0] error while decoding MB 30 61, bytestream -5
[h264 @ 0x5fcb418bd480] error while decoding MB 21 61, bytestream -5
[h264 @ 0x5fcb3c6fb500] error while decoding MB 24 56, bytestream -11
[h264 @ 0x5fcb3f60b140] error while decoding MB 113 14, bytestream -5
[h264 @ 0x5fcb412501c0] error while decoding MB 101 48, bytestream -5
[h264 @ 0x5fcb3c6fb500] error while decoding MB 15 19, bytestream -7
[h264 @ 0x5fcb3c6fb500] error while decoding MB 110 43, bytestream -7
[h264 @ 0x5fcb3e6560c0] error while decoding MB 82 63, bytestream -23
[h264 @ 0x5fcb3c6fb500] left block unavailable for requested intra mode
[h264 @ 0x5fcb3c6fb500] error while decoding MB 0 64, bytestream 3756
[h264 @ 0x5fcb3ebabe40] error while decoding MB 114 43, bytestream -5
[h264 @ 0x5fcb41c63980] error while decoding MB 115 32, bytestream -5
[h264 @ 0x5fcb3ebabe40] error while decoding MB 99 52, bytestream -7
[h264 @ 0x5fcb3f60b140] error while decoding MB 10 26, bytestream -15
[h264 @ 0x5fcb3e6560c0] error while decoding MB 65 59, bytestream -5
[h264 @ 0x5fcb42025d40] error while decoding MB 33 51, bytestream -14
[h264 @ 0x5fcb3e6560c0] error while decoding MB 81 27, bytestream -14
[h264 @ 0x5fcb418c5380] error while decoding MB 5 15, bytestream -9
[h264 @ 0x5fcb3e6560c0] error while decoding MB 92 65, bytestream -7
[h264 @ 0x5fcb42025d40] error while decoding MB 1 58, bytestream -18
[h264 @ 0x5fcb412501c0] error while decoding MB 109 17, bytestream -5
[h264 @ 0x5fcb418bd480] error while decoding MB 61 48, bytestream -20
[h264 @ 0x5fcb3f60b140] left block unavailable for requested intra mode
[h264 @ 0x5fcb3f60b140] error while decoding MB 0 66, bytestream 2100
[h264 @ 0x5fcb3d1a5440] error while decoding MB 47 20, bytestream -25
[h264 @ 0x5fcb42025d40] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x5fcb42025d40] error while decoding MB 0 18, bytestream 106873
[h264 @ 0x5fcb3c6fb500] error while decoding MB 58 52, bytestream -7
[h264 @ 0x5fcb3c6fb500] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x5fcb3c6fb500] error while decoding MB 0 61, bytestream 3331
[h264 @ 0x5fcb3d1a5440] left block unavailable for requested intra mode
[h264 @ 0x5fcb3d1a5440] error while decoding MB 0 59, bytestream 325
[h264 @ 0x5fcb42025d40] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x5fcb42025d40] error while decoding MB 0 24, bytestream 5878
[h264 @ 0x5fcb412501c0] error while decoding MB 77 61, bytestream -5
[h264 @ 0x5fcb3d1a5440] error while decoding MB 32 52, bytestream -7
[h264 @ 0x5fcb3bc6ed40] error while decoding MB 105 58, bytestream -5
[h264 @ 0x5fcb3d1a5440] error while decoding MB 98 20, bytestream -32
[h264 @ 0x5fcb3e6560c0] error while decoding MB 95 44, bytestream -5
[h264 @ 0x5fcb3d1a5440] error while decoding MB 43 18, bytestream -5
[h264 @ 0x5fcb3f60b140] error while decoding MB 38 38, bytestream -5
[h264 @ 0x5fcb41c63980] error while decoding MB 27 58, bytestream -18
[h264 @ 0x5fcb418c5380] error while decoding MB 96 14, bytestream -9
[h264 @ 0x5fcb418c5380] error while decoding MB 18 59, bytestream -21
[h264 @ 0x5fcb42025d40] error while decoding MB 44 18, bytestream -9
[h264 @ 0x5fcb3ebabe40] error while decoding MB 104 61, bytestream -17
[h264 @ 0x5fcb418bd480] error while decoding MB 55 14, bytestream -7
[h264 @ 0x5fcb418c5380] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x5fcb418c5380] error while decoding MB 0 45, bytestream 41354
[h264 @ 0x5fcb412501c0] error while decoding MB 58 61, bytestream -5
[h264 @ 0x5fcb3ebabe40] error while decoding MB 10 59, bytestream -9
[h264 @ 0x5fcb3bc6ed40] error while decoding MB 33 32, bytestream -5
[h264 @ 0x5fcb3d1a5440] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x5fcb3d1a5440] error while decoding MB 0 17, bytestream 2314
[h264 @ 0x5fcb3f60b140] error while decoding MB 55 61, bytestream -5
[h264 @ 0x5fcb3bc6ed40] error while decoding MB 66 61, bytestream -5
[h264 @ 0x5fcb3ebabe40] error while decoding MB 111 37, bytestream -6
[h264 @ 0x5fcb41c63980] error while decoding MB 44 26, bytestream -7
[h264 @ 0x5fcb418c5380] error while decoding MB 33 32, bytestream -7
[h264 @ 0x5fcb3d1a5440] error while decoding MB 34 17, bytestream -5
[h264 @ 0x5fcb3f59f880] error while decoding MB 78 14, bytestream -9
[h264 @ 0x5fcb412501c0] error while decoding MB 64 49, bytestream -19
[h264 @ 0x5fcb42025d40] error while decoding MB 90 32, bytestream -5
[h264 @ 0x5fcb3c6fb500] error while decoding MB 70 21, bytestream -6
[h264 @ 0x5fcb42025d40] left block unavailable for requested intra mode
[h264 @ 0x5fcb42025d40] error while decoding MB 0 64, bytestream 958
[h264 @ 0x5fcb418c5380] left block unavailable for requested intra mode
[h264 @ 0x5fcb418c5380] error while decoding MB 0 54, bytestream 4947
[h264 @ 0x5fcb3c6fb500] error while decoding MB 44 44, bytestream -10
[h264 @ 0x5fcb418bd480] error while decoding MB 104 30, bytestream -5
[h264 @ 0x5fcb3e6560c0] error while decoding MB 62 14, bytestream -7
[h264 @ 0x5fcb3bc6ed40] error while decoding MB 85 64, bytestream -15
[h264 @ 0x5fcb418c5380] error while decoding MB 17 53, bytestream -24
[h264 @ 0x5fcb3c6fb500] error while decoding MB 57 49, bytestream -23
[h264 @ 0x5fcb3e6560c0] error while decoding MB 54 60, bytestream -14
[h264 @ 0x5fcb3c6fb500] error while decoding MB 39 14, bytestream -9
[h264 @ 0x5fcb3bc6ed40] error while decoding MB 78 18, bytestream -36
[h264 @ 0x5fcb41c63980] error while decoding MB 30 14, bytestream -11
[h264 @ 0x5fcb41c63980] error while decoding MB 51 2, bytestream -24
[h264 @ 0x5fcb3ebabe40] error while decoding MB 92 52, bytestream -5
[h264 @ 0x5fcb3ebabe40] left block unavailable for requested intra mode
[h264 @ 0x5fcb3ebabe40] error while decoding MB 0 47, bytestream 5540
[h264 @ 0x5fcb3ebabe40] error while decoding MB 92 44, bytestream -19
[h264 @ 0x5fcb3e6560c0] error while decoding MB 82 15, bytestream -8
Processed 25902 frames before detection.
Processed 132406 frames before detection.
Saved successfully
Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
-- <re.Match object; span=(0, 8), match='06:41:17'>
Extracted Time: 06:41:17
06:41:17
Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
-- <re.Match object; span=(0, 8), match='17:00:12'>
Extracted Time: 17:00:12
17:00:12
***26-03-2025***
Trying start time: 06:00:00
Connecting to recorded video at 1742949000
URL: rtsp://admin:rmc%4012345@103.168.199.92:554/c1/b1742949000/e1742952600/replay/
[rtsp @ 0x5fcb3dd43340] getaddrinfo(): Name or service not known
[rtsp @ 0x5fcb3dd43340] getaddrinfo(): Name or service not known
Stream found at 06:00:00
Trying start time: 15:00:20
Connecting to recorded video at 1742981420
URL: rtsp://admin:rmc%4012345@103.168.199.92:554/c1/b1742981420/e1742990400/replay/
[rtsp @ 0x5fcb3dd43340] getaddrinfo(): Name or service not known
[rtsp @ 0x5fcb3dd43340] getaddrinfo(): Name or service not known
Stream found at 15:00:20
#####################
[rtsp @ 0x5fcb41fe8380] getaddrinfo(): Name or service not known
[rtsp @ 0x5fcb41fe8380] getaddrinfo(): Name or service not known
[h264 @ 0x5fcb41faccc0] error while decoding MB 117 41, bytestream -34
[h264 @ 0x5fcb3f028940] left block unavailable for requested intra mode
[h264 @ 0x5fcb3f028940] error while decoding MB 0 51, bytestream 51851
[h264 @ 0x5fcb3d52aa80] error while decoding MB 85 50, bytestream -13
[h264 @ 0x5fcb404665c0] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x5fcb404665c0] error while decoding MB 0 51, bytestream 6866
[h264 @ 0x5fcb3beef4c0] error while decoding MB 95 28, bytestream -5
[h264 @ 0x5fcb41244300] left block unavailable for requested intra mode
[h264 @ 0x5fcb41244300] error while decoding MB 0 56, bytestream 13044
[h264 @ 0x5fcb3f5080c0] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x5fcb3f5080c0] error while decoding MB 0 55, bytestream 23716
[h264 @ 0x5fcb40d33d80] error while decoding MB 37 59, bytestream -30
[h264 @ 0x5fcb41faccc0] left block unavailable for requested intra mode
[h264 @ 0x5fcb41faccc0] error while decoding MB 0 54, bytestream 6672
[h264 @ 0x5fcb41faccc0] error while decoding MB 25 66, bytestream -9
[h264 @ 0x5fcb3e5f6d00] error while decoding MB 74 62, bytestream -39
[h264 @ 0x5fcb3d52aa80] error while decoding MB 106 58, bytestream -14
[h264 @ 0x5fcb404665c0] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x5fcb404665c0] error while decoding MB 0 60, bytestream 5398
[h264 @ 0x5fcb3beef4c0] error while decoding MB 10 66, bytestream -14
[h264 @ 0x5fcb3d52aa80] error while decoding MB 90 54, bytestream -9
[h264 @ 0x5fcb404665c0] error while decoding MB 53 61, bytestream -11
[h264 @ 0x5fcb3d52aa80] error while decoding MB 11 62, bytestream -11
[h264 @ 0x5fcb404665c0] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x5fcb404665c0] error while decoding MB 0 55, bytestream 1429
[h264 @ 0x5fcb3d52aa80] error while decoding MB 100 67, bytestream -18
[h264 @ 0x5fcb3d52aa80] error while decoding MB 36 40, bytestream -13
[h264 @ 0x5fcb404665c0] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x5fcb404665c0] error while decoding MB 0 46, bytestream 71267
[h264 @ 0x5fcb3d52aa80] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x5fcb3d52aa80] error while decoding MB 0 43, bytestream 22590
[h264 @ 0x5fcb41faccc0] error while decoding MB 66 5, bytestream -5
[h264 @ 0x5fcb3d52aa80] error while decoding MB 92 60, bytestream -6
[h264 @ 0x5fcb41faccc0] error while decoding MB 58 63, bytestream -7
[h264 @ 0x5fcb4faba900] left block unavailable for requested intra mode
[h264 @ 0x5fcb4faba900] error while decoding MB 0 41, bytestream 68221
[h264 @ 0x5fcb3c062940] error while decoding MB 0 25, bytestream -9
[h264 @ 0x5fcb41244300] left block unavailable for requested intra mode
[h264 @ 0x5fcb41244300] error while decoding MB 0 24, bytestream 16706
[h264 @ 0x5fcb404665c0] error while decoding MB 35 44, bytestream -5
[h264 @ 0x5fcb41244300] left block unavailable for requested intra mode
[h264 @ 0x5fcb41244300] error while decoding MB 0 63, bytestream 10154
[h264 @ 0x5fcb41244300] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x5fcb41244300] error while decoding MB 0 47, bytestream 76961
[h264 @ 0x5fcb3d52aa80] error while decoding MB 15 16, bytestream -5
[h264 @ 0x5fcb3f5080c0] left block unavailable for requested intra mode
[h264 @ 0x5fcb3f5080c0] error while decoding MB 0 55, bytestream 34140
[h264 @ 0x5fcb3e5f6d00] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x5fcb3e5f6d00] error while decoding MB 0 23, bytestream 135415
[h264 @ 0x5fcb41faccc0] left block unavailable for requested intra mode
[h264 @ 0x5fcb41faccc0] error while decoding MB 0 2, bytestream 222771
[h264 @ 0x5fcb3f028940] left block unavailable for requested intra mode
[h264 @ 0x5fcb3f028940] error while decoding MB 0 8, bytestream 210314
[h264 @ 0x5fcb3d52aa80] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x5fcb3d52aa80] error while decoding MB 0 18, bytestream 8373
[h264 @ 0x5fcb41faccc0] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x5fcb41faccc0] error while decoding MB 0 55, bytestream 33772
[h264 @ 0x5fcb3f028940] left block unavailable for requested intra mode
[h264 @ 0x5fcb3f028940] error while decoding MB 0 35, bytestream 80908
[h264 @ 0x5fcb3beef4c0] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x5fcb3beef4c0] error while decoding MB 0 19, bytestream 164637
[h264 @ 0x5fcb4faba900] error while decoding MB 1 49, bytestream -7
[h264 @ 0x5fcb40d33d80] left block unavailable for requested intra mode
[h264 @ 0x5fcb40d33d80] error while decoding MB 0 52, bytestream 50362
[h264 @ 0x5fcb40d33d80] left block unavailable for requested intra mode
[h264 @ 0x5fcb40d33d80] error while decoding MB 0 59, bytestream 13625
[h264 @ 0x5fcb40d33d80] error while decoding MB 104 58, bytestream -7
[h264 @ 0x5fcb4faba900] error while decoding MB 40 61, bytestream -9
[h264 @ 0x5fcb3f5080c0] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x5fcb3f5080c0] error while decoding MB 0 51, bytestream 11674
[h264 @ 0x5fcb3e5f6d00] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x5fcb3e5f6d00] error while decoding MB 0 41, bytestream 16670
[h264 @ 0x5fcb3f028940] error while decoding MB 38 57, bytestream -24
[h264 @ 0x5fcb4faba900] error while decoding MB 24 62, bytestream -22
[h264 @ 0x5fcb41faccc0] error while decoding MB 81 59, bytestream -6
[h264 @ 0x5fcb3c062940] error while decoding MB 22 65, bytestream -23
[h264 @ 0x5fcb404665c0] error while decoding MB 82 16, bytestream -7
[h264 @ 0x5fcb4faba900] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x5fcb4faba900] error while decoding MB 0 52, bytestream 6356
[h264 @ 0x5fcb3c062940] error while decoding MB 5 64, bytestream -18
[h264 @ 0x5fcb4faba900] error while decoding MB 108 48, bytestream -37
[h264 @ 0x5fcb4faba900] left block unavailable for requested intra mode
[h264 @ 0x5fcb4faba900] error while decoding MB 0 55, bytestream 9746
[h264 @ 0x5fcb3c062940] error while decoding MB 51 62, bytestream -15
[h264 @ 0x5fcb3c062940] error while decoding MB 20 63, bytestream -5
[h264 @ 0x5fcb4faba900] error while decoding MB 117 66, bytestream -28
[h264 @ 0x5fcb41faccc0] error while decoding MB 57 65, bytestream -18
[h264 @ 0x5fcb3e5f6d00] error while decoding MB 5 61, bytestream -10
[h264 @ 0x5fcb3e5f6d00] error while decoding MB 19 60, bytestream -9
[h264 @ 0x5fcb3e5f6d00] left block unavailable for requested intra mode
[h264 @ 0x5fcb3e5f6d00] error while decoding MB 0 59, bytestream 20040
#####################
[rtsp @ 0x5fcb41858300] getaddrinfo(): Name or service not known
[rtsp @ 0x5fcb41858300] getaddrinfo(): Name or service not known
[h264 @ 0x5fcb3ed70000] error while decoding MB 45 44, bytestream -5
[h264 @ 0x5fcb3eff9780] error while decoding MB 14 66, bytestream -18
[h264 @ 0x5fcb4fab7bc0] left block unavailable for requested intra mode
[h264 @ 0x5fcb4fab7bc0] error while decoding MB 0 22, bytestream 5670
[h264 @ 0x5fcb3f51fa40] error while decoding MB 25 50, bytestream -5
[h264 @ 0x5fcb3ed70000] error while decoding MB 9 67, bytestream -8
[h264 @ 0x5fcb4fab7bc0] left block unavailable for requested intra mode
[h264 @ 0x5fcb4fab7bc0] error while decoding MB 0 58, bytestream 13235
[h264 @ 0x5fcb3bd8d880] error while decoding MB 110 66, bytestream -5
[h264 @ 0x5fcb4fab7bc0] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x5fcb4fab7bc0] error while decoding MB 0 42, bytestream 28895
[h264 @ 0x5fcb4fab7bc0] cabac decode of qscale diff failed at 6 54
[h264 @ 0x5fcb4fab7bc0] error while decoding MB 6 54, bytestream 2325
[h264 @ 0x5fcb4fab7bc0] error while decoding MB 60 35, bytestream -5
[h264 @ 0x5fcb4fab7bc0] error while decoding MB 40 49, bytestream -6
[h264 @ 0x5fcb3eff66c0] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x5fcb3eff66c0] error while decoding MB 0 29, bytestream 58766
[h264 @ 0x5fcb3bf7d1c0] error while decoding MB 79 58, bytestream -5
[h264 @ 0x5fcb3bda0b40] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x5fcb3bda0b40] error while decoding MB 0 19, bytestream 120138
[h264 @ 0x5fcb417bc580] error while decoding MB 76 35, bytestream -5
[h264 @ 0x5fcb417bc580] left block unavailable for requested intra mode
[h264 @ 0x5fcb417bc580] error while decoding MB 0 2, bytestream 130407
[h264 @ 0x5fcb4029c240] left block unavailable for requested intra mode
[h264 @ 0x5fcb4029c240] error while decoding MB 0 18, bytestream 11450
[h264 @ 0x5fcb3eff66c0] left block unavailable for requested intra mode
[h264 @ 0x5fcb3eff66c0] error while decoding MB 0 37, bytestream 2616
[h264 @ 0x5fcb417bc580] error while decoding MB 73 59, bytestream -8
[h264 @ 0x5fcb3f51fa40] error while decoding MB 78 50, bytestream -6
[h264 @ 0x5fcb3ebac000] error while decoding MB 94 67, bytestream -6
[h264 @ 0x5fcb3ebac000] error while decoding MB 55 53, bytestream -19
[h264 @ 0x5fcb3eff9780] error while decoding MB 23 66, bytestream -8
[h264 @ 0x5fcb3eff9780] error while decoding MB 46 62, bytestream -12
[h264 @ 0x5fcb4fab7bc0] left block unavailable for requested intra mode
[h264 @ 0x5fcb4fab7bc0] error while decoding MB 0 15, bytestream 120101
[h264 @ 0x5fcb4fab7bc0] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x5fcb4fab7bc0] error while decoding MB 0 20, bytestream 75981
[h264 @ 0x5fcb417bc580] left block unavailable for requested intra mode
[h264 @ 0x5fcb417bc580] error while decoding MB 0 22, bytestream 94474
[h264 @ 0x5fcb417bc580] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x5fcb417bc580] error while decoding MB 0 67, bytestream 86
[h264 @ 0x5fcb3bd8d880] left block unavailable for requested intra mode
[h264 @ 0x5fcb3bd8d880] error while decoding MB 0 25, bytestream 67314
[h264 @ 0x5fcb3ed70000] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x5fcb3ed70000] error while decoding MB 0 18, bytestream 8402
Processed 53673 frames before detection.
Processed 60239 frames before detection.
Saved successfully
Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
-- <re.Match object; span=(0, 8), match='06:44:47'>
Extracted Time: 06:44:47
06:44:47
Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
-- <re.Match object; span=(0, 8), match='15:50:36'>
Extracted Time: 15:50:36
15:50:36
***27-03-2025***
Trying start time: 06:00:00
Connecting to recorded video at 1743035400
URL: rtsp://admin:rmc%4012345@103.168.199.92:554/c1/b1743035400/e1743039000/replay/
[rtsp @ 0x5fcb4fabafc0] getaddrinfo(): Name or service not known
[rtsp @ 0x5fcb4fabafc0] getaddrinfo(): Name or service not known
Stream found at 06:00:00
Trying start time: 15:00:20
Connecting to recorded video at 1743067820
URL: rtsp://admin:rmc%4012345@103.168.199.92:554/c1/b1743067820/e1743076800/replay/
[rtsp @ 0x5fcb41858300] getaddrinfo(): Name or service not known
[rtsp @ 0x5fcb41858300] getaddrinfo(): Name or service not known
Stream found at 15:00:20
#####################
[rtsp @ 0x5fcb3f6774c0] getaddrinfo(): Name or service not known
[rtsp @ 0x5fcb3f6774c0] getaddrinfo(): Name or service not known
[h264 @ 0x5fcb3bf7d1c0] error while decoding MB 95 52, bytestream -8
[h264 @ 0x5fcb4fcd6900] error while decoding MB 46 16, bytestream -5
[h264 @ 0x5fcb3d6c4f80] left block unavailable for requested intra mode
[h264 @ 0x5fcb3d6c4f80] error while decoding MB 0 54, bytestream 11442
[h264 @ 0x5fcb3f0c95c0] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x5fcb3f0c95c0] error while decoding MB 0 58, bytestream 17012
[h264 @ 0x5fcb4fcd6900] left block unavailable for requested intra mode
[h264 @ 0x5fcb4fcd6900] error while decoding MB 0 39, bytestream 52056
#####################
[rtsp @ 0x5fcb3d7c5040] getaddrinfo(): Name or service not known
[ WARN:0@18640.500] global cap.cpp:175 open VIDEOIO(CV_IMAGES): raised OpenCV exception:

OpenCV(4.11.0) /io/opencv/modules/videoio/src/cap_images.cpp:237: error: (-5:Bad argument) CAP_IMAGES: error, expected '0?[1-9][du]' pattern, got: rtsp://admin:rmc%4012345@103.168.199.92:554/c1/b1743067820/e1743076800/replay/ in function 'icvExtractPattern'


No person detected in the video.
Processed 32113 frames before detection.
No person detected in the video.
Saved successfully
Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
-- <re.Match object; span=(0, 8), match='06:26:49'>
Extracted Time: 06:26:49
06:26:49
***28-03-2025***
Trying start time: 06:00:00
Connecting to recorded video at 1743121800
URL: rtsp://admin:rmc%4012345@103.168.199.92:554/c1/b1743121800/e1743125400/replay/
[rtsp @ 0x5fcb41858300] getaddrinfo(): Name or service not known
[ WARN:0@18648.094] global cap.cpp:175 open VIDEOIO(CV_IMAGES): raised OpenCV exception:

OpenCV(4.11.0) /io/opencv/modules/videoio/src/cap_images.cpp:237: error: (-5:Bad argument) CAP_IMAGES: error, expected '0?[1-9][du]' pattern, got: rtsp://admin:rmc%4012345@103.168.199.92:554/c1/b1743121800/e1743125400/replay/ in function 'icvExtractPattern'


Stream not available for 06:00:00, trying next second...
Trying start time: 06:00:01
Connecting to recorded video at 1743121801
URL: rtsp://admin:rmc%4012345@103.168.199.92:554/c1/b1743121801/e1743125400/replay/
[rtsp @ 0x5fcb4fabafc0] getaddrinfo(): Name or service not known
[rtsp @ 0x5fcb4fabafc0] getaddrinfo(): Name or service not known
Stream found at 06:00:01
Trying start time: 15:00:20
Connecting to recorded video at 1743154220
URL: rtsp://admin:rmc%4012345@103.168.199.92:554/c1/b1743154220/e1743163200/replay/
[rtsp @ 0x5fcb41858300] getaddrinfo(): Name or service not known
[rtsp @ 0x5fcb41858300] getaddrinfo(): Name or service not known
Stream found at 15:00:20
#####################
[rtsp @ 0x5fcb41e28800] getaddrinfo(): Name or service not known
[rtsp @ 0x5fcb41e28800] getaddrinfo(): Name or service not known
[h264 @ 0x5fcb40ccd580] error while decoding MB 51 19, bytestream -35
[h264 @ 0x5fcb4124b900] error while decoding MB 19 65, bytestream -23
[h264 @ 0x5fcb3ed5af80] left block unavailable for requested intra mode
[h264 @ 0x5fcb3ed5af80] error while decoding MB 0 52, bytestream 52429
[h264 @ 0x5fcb40436e80] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x5fcb40436e80] error while decoding MB 0 51, bytestream 50887
[h264 @ 0x5fcb3ed5af80] left block unavailable for requested intra mode
[h264 @ 0x5fcb3ed5af80] error while decoding MB 0 35, bytestream 99804
[h264 @ 0x5fcb3beeb840] error while decoding MB 35 63, bytestream -6
[h264 @ 0x5fcb3beeb840] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x5fcb3beeb840] error while decoding MB 0 51, bytestream 58638
[h264 @ 0x5fcb3bc6e300] left block unavailable for requested intra mode
[h264 @ 0x5fcb3bc6e300] error while decoding MB 0 59, bytestream 21621
[h264 @ 0x5fcb4124b900] left block unavailable for requested intra mode
[h264 @ 0x5fcb4124b900] error while decoding MB 0 8, bytestream 8577
#####################
[rtsp @ 0x5fcb3ffffb40] getaddrinfo(): Name or service not known
[rtsp @ 0x5fcb3ffffb40] getaddrinfo(): Name or service not known
[h264 @ 0x5fcb3be8a440] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x5fcb3be8a440] error while decoding MB 0 67, bytestream 14145
[h264 @ 0x5fcb3be8a440] error while decoding MB 95 62, bytestream -5
[h264 @ 0x5fcb4121b880] left block unavailable for requested intra mode
[h264 @ 0x5fcb4121b880] error while decoding MB 0 41, bytestream 15067
[h264 @ 0x5fcb4fbbbc80] error while decoding MB 28 33, bytestream -7
[h264 @ 0x5fcb41fa1540] left block unavailable for requested intra mode
[h264 @ 0x5fcb41fa1540] error while decoding MB 0 17, bytestream 7490
[h264 @ 0x5fcb41172380] error while decoding MB 8 18, bytestream -5
[h264 @ 0x5fcb3bd8e100] left block unavailable for requested intra mode
[h264 @ 0x5fcb3bd8e100] error while decoding MB 0 50, bytestream 3623
Processed 33285 frames before detection.
Processed 118113 frames before detection.
Saved successfully
Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
-- <re.Match object; span=(0, 8), match='06:27:47'>
Extracted Time: 06:27:47
06:27:47
Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
-- <re.Match object; span=(0, 8), match='16:38:49'>
Extracted Time: 16:38:49
16:38:49
***29-03-2025***
Trying start time: 06:00:00
Connecting to recorded video at 1743208200
URL: rtsp://admin:rmc%4012345@103.168.199.92:554/c1/b1743208200/e1743211800/replay/
[rtsp @ 0x5fcb400ce100] getaddrinfo(): Name or service not known
[rtsp @ 0x5fcb400ce100] getaddrinfo(): Name or service not known
Stream found at 06:00:00
Trying start time: 15:00:20
Connecting to recorded video at 1743240620
URL: rtsp://admin:rmc%4012345@103.168.199.92:554/c1/b1743240620/e1743249600/replay/
[rtsp @ 0x5fcb3be84d00] getaddrinfo(): Name or service not known
[rtsp @ 0x5fcb3be84d00] getaddrinfo(): Name or service not known
Stream found at 15:00:20
#####################
[rtsp @ 0x5fcb3f5ed000] getaddrinfo(): Name or service not known
[rtsp @ 0x5fcb3f5ed000] getaddrinfo(): Name or service not known
[h264 @ 0x5fcb40cce800] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x5fcb40cce800] error while decoding MB 0 20, bytestream 7286
[h264 @ 0x5fcb4028a440] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x5fcb4028a440] error while decoding MB 0 57, bytestream 8263
[h264 @ 0x5fcb40cce800] left block unavailable for requested intra mode
[h264 @ 0x5fcb40cce800] error while decoding MB 0 45, bytestream 301
[h264 @ 0x5fcb41f3eb00] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x5fcb41f3eb00] error while decoding MB 0 57, bytestream 2417
[h264 @ 0x5fcb41fe6c40] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x5fcb41fe6c40] error while decoding MB 0 62, bytestream 4037
[h264 @ 0x5fcb3f0dba80] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x5fcb3f0dba80] error while decoding MB 0 58, bytestream 9106
[h264 @ 0x5fcb41242b00] left block unavailable for requested intra mode
[h264 @ 0x5fcb41242b00] error while decoding MB 0 59, bytestream 18872
[h264 @ 0x5fcb41242b00] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x5fcb41242b00] error while decoding MB 0 31, bytestream 140533
[h264 @ 0x5fcb50d17100] error while decoding MB 64 66, bytestream -17
[h264 @ 0x5fcb41f3eb00] left block unavailable for requested intra mode
[h264 @ 0x5fcb41f3eb00] error while decoding MB 0 63, bytestream 811
[h264 @ 0x5fcb416272c0] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x5fcb416272c0] error while decoding MB 0 53, bytestream 43871
[h264 @ 0x5fcb3ec69580] error while decoding MB 106 59, bytestream -8
[h264 @ 0x5fcb4028a440] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x5fcb4028a440] error while decoding MB 0 55, bytestream 62985
#####################
[rtsp @ 0x5fcb3fd7e200] getaddrinfo(): Name or service not known
[rtsp @ 0x5fcb3fd7e200] getaddrinfo(): Name or service not known
[h264 @ 0x5fcb3f584340] left block unavailable for requested intra mode
[h264 @ 0x5fcb3f584340] error while decoding MB 0 57, bytestream 22806
[h264 @ 0x5fcb3d52afc0] left block unavailable for requested intra mode
[h264 @ 0x5fcb3d52afc0] error while decoding MB 0 42, bytestream 53593
Processed 43855 frames before detection.
Processed 80823 frames before detection.
Saved successfully
Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
-- <re.Match object; span=(0, 8), match='06:36:35'>
Extracted Time: 06:36:35
06:36:35
Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
***30-03-2025***
Trying start time: 06:00:00
Connecting to recorded video at 1743294600
URL: rtsp://admin:rmc%4012345@103.168.199.92:554/c1/b1743294600/e1743298200/replay/
[rtsp @ 0x5fcb3c19b480] getaddrinfo(): Name or service not known
[ WARN:0@32521.315] global cap.cpp:175 open VIDEOIO(CV_IMAGES): raised OpenCV exception:

OpenCV(4.11.0) /io/opencv/modules/videoio/src/cap_images.cpp:237: error: (-5:Bad argument) CAP_IMAGES: error, expected '0?[1-9][du]' pattern, got: rtsp://admin:rmc%4012345@103.168.199.92:554/c1/b1743294600/e1743298200/replay/ in function 'icvExtractPattern'


Stream not available for 06:00:00, trying next second...
Trying start time: 06:00:01
Connecting to recorded video at 1743294601
URL: rtsp://admin:rmc%4012345@103.168.199.92:554/c1/b1743294601/e1743298200/replay/
[rtsp @ 0x5fcb3c19b480] getaddrinfo(): Name or service not known
[ WARN:0@32521.986] global cap.cpp:175 open VIDEOIO(CV_IMAGES): raised OpenCV exception:

OpenCV(4.11.0) /io/opencv/modules/videoio/src/cap_images.cpp:237: error: (-5:Bad argument) CAP_IMAGES: error, expected '0?[1-9][du]' pattern, got: rtsp://admin:rmc%4012345@103.168.199.92:554/c1/b1743294601/e1743298200/replay/ in function 'icvExtractPattern'


Stream not available for 06:00:01, trying next second...
Trying start time: 06:00:02
Connecting to recorded video at 1743294602
URL: rtsp://admin:rmc%4012345@103.168.199.92:554/c1/b1743294602/e1743298200/replay/
[rtsp @ 0x5fcb3c19b480] getaddrinfo(): Name or service not known
[rtsp @ 0x5fcb3c19b480] getaddrinfo(): Name or service not known
Stream found at 06:00:02
Trying start time: 15:00:20
Connecting to recorded video at 1743327020
URL: rtsp://admin:rmc%4012345@103.168.199.92:554/c1/b1743327020/e1743336000/replay/
[rtsp @ 0x5fcb3ebac440] getaddrinfo(): Name or service not known
[rtsp @ 0x5fcb3ebac440] getaddrinfo(): Name or service not known
Stream found at 15:00:20
#####################
[rtsp @ 0x5fcb411f5c00] getaddrinfo(): Name or service not known
[rtsp @ 0x5fcb411f5c00] getaddrinfo(): Name or service not known
[h264 @ 0x5fcb4184b2c0] error while decoding MB 110 58, bytestream -7
[h264 @ 0x5fcb418749c0] left block unavailable for requested intra mode
[h264 @ 0x5fcb418749c0] error while decoding MB 0 65, bytestream 293
[h264 @ 0x5fcb407d95c0] left block unavailable for requested intra mode
[h264 @ 0x5fcb407d95c0] error while decoding MB 0 63, bytestream 10815
[h264 @ 0x5fcb407d95c0] error while decoding MB 48 64, bytestream -17
[h264 @ 0x5fcb418749c0] left block unavailable for requested intra mode
[h264 @ 0x5fcb418749c0] error while decoding MB 0 59, bytestream 10898
[h264 @ 0x5fcb3f2bd780] error while decoding MB 87 22, bytestream -8
[h264 @ 0x5fcb418749c0] left block unavailable for requested intra mode
[h264 @ 0x5fcb418749c0] error while decoding MB 0 61, bytestream 14758
[h264 @ 0x5fcb3d526180] error while decoding MB 18 60, bytestream -5
[h264 @ 0x5fcb407d95c0] left block unavailable for requested intra mode
[h264 @ 0x5fcb407d95c0] error while decoding MB 0 61, bytestream 4552
[h264 @ 0x5fcb41565640] left block unavailable for requested intra mode
[h264 @ 0x5fcb41565640] error while decoding MB 0 56, bytestream 15529
[h264 @ 0x5fcb3d526180] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x5fcb3d526180] error while decoding MB 0 53, bytestream 31327
[h264 @ 0x5fcb41565640] error while decoding MB 76 5, bytestream -6
[h264 @ 0x5fcb4fcd8880] left block unavailable for requested intra mode
[h264 @ 0x5fcb4fcd8880] error while decoding MB 0 31, bytestream 77491
[h264 @ 0x5fcb41565640] error while decoding MB 62 32, bytestream -7
[h264 @ 0x5fcb505583c0] error while decoding MB 18 15, bytestream -7
[h264 @ 0x5fcb4fcd8880] error while decoding MB 98 61, bytestream -6
[h264 @ 0x5fcb3d526180] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x5fcb3d526180] error while decoding MB 0 59, bytestream 1607
[h264 @ 0x5fcb40f8af40] left block unavailable for requested intra mode
[h264 @ 0x5fcb40f8af40] error while decoding MB 0 62, bytestream 7573
#####################
[rtsp @ 0x5fcb417bd0c0] getaddrinfo(): Name or service not known
[rtsp @ 0x5fcb417bd0c0] getaddrinfo(): Name or service not known
[h264 @ 0x5fcb407aac40] error while decoding MB 10 25, bytestream -7
Processed 44322 frames before detection.
Processed 90672 frames before detection.
Saved successfully
Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
-- <re.Match object; span=(11, 19), match='06:37:02'>
Extracted Time: 06:37:02
06:37:02
Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
-- <re.Match object; span=(0, 8), match='16:15:56'>
Extracted Time: 16:15:56
16:15:56
***31-03-2025***
Trying start time: 06:00:00
Connecting to recorded video at 1743381000
URL: rtsp://admin:rmc%4012345@103.168.199.92:554/c1/b1743381000/e1743384600/replay/
[rtsp @ 0x5fcb417bd0c0] getaddrinfo(): Name or service not known
[rtsp @ 0x5fcb417bd0c0] getaddrinfo(): Name or service not known
Stream found at 06:00:00
Trying start time: 15:00:20
Connecting to recorded video at 1743413420
URL: rtsp://admin:rmc%4012345@103.168.199.92:554/c1/b1743413420/e1743422400/replay/
[rtsp @ 0x5fcb417bd0c0] getaddrinfo(): Name or service not known
[rtsp @ 0x5fcb417bd0c0] getaddrinfo(): Name or service not known
Stream found at 15:00:20
#####################
[rtsp @ 0x5fcb3fd7e200] getaddrinfo(): Name or service not known
[ WARN:0@39318.368] global cap.cpp:175 open VIDEOIO(CV_IMAGES): raised OpenCV exception:

OpenCV(4.11.0) /io/opencv/modules/videoio/src/cap_images.cpp:237: error: (-5:Bad argument) CAP_IMAGES: error, expected '0?[1-9][du]' pattern, got: rtsp://admin:rmc%4012345@103.168.199.92:554/c1/b1743381000/e1743384600/replay/ in function 'icvExtractPattern'


No person detected in the video.
#####################
[rtsp @ 0x5fcb3fd7e200] getaddrinfo(): Name or service not known
[rtsp @ 0x5fcb3fd7e200] getaddrinfo(): Name or service not known
[h264 @ 0x5fcb3cf1b780] error while decoding MB 34 21, bytestream -8
[h264 @ 0x5fcb4ec9fd00] left block unavailable for requested intra mode
[h264 @ 0x5fcb4ec9fd00] error while decoding MB 0 3, bytestream 128486
[h264 @ 0x5fcb3e6446c0] error while decoding MB 36 35, bytestream -5
[h264 @ 0x5fcb3e6446c0] left block unavailable for requested intra4x4 mode -1
[h264 @ 0x5fcb3e6446c0] error while decoding MB 0 32, bytestream 87128
[h264 @ 0x5fcb3e6446c0] error while decoding MB 116 64, bytestream -30
No person detected in the video.
Processed 86886 frames before detection.
Saved successfully
Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
-- <re.Match object; span=(0, 8), match='16:12:49'>
Extracted Time: 16:12:49
16:12:49
====== 0Nc_01 completed ========
(nc_env) hepl@HCUDT0177:~/Desktop/New_Folder/Keerthanaa/Keerthii/MAR_2025/VA_research_task/NCS/NC_00$

# %%
import torch
import cv2
import os
import numpy as np
from detectron2.engine import DefaultPredictor
from detectron2.config import get_cfg
from detectron2 import model_zoo

class Process:
    
    def __init__(self):
        # Load Detectron2 model
        self.cfg = get_cfg()
        self.cfg.merge_from_file(model_zoo.get_config_file("COCO-Detection/faster_rcnn_R_50_FPN_3x.yaml"))
        self.cfg.MODEL.WEIGHTS = "path/to/your/model.pth"  # Replace with your model path
        self.cfg.MODEL.ROI_HEADS.SCORE_THRESH_TEST = 0.8  # Set threshold
        self.cfg.MODEL.DEVICE = "cuda" if torch.cuda.is_available() else "cpu"
        self.predictor = DefaultPredictor(self.cfg)

    def save_first_frame_with_person(self, video_path, formatted_date, output_folder):
        os.makedirs(output_folder, exist_ok=True)
        cap = cv2.VideoCapture(video_path)

        frame_count = 0
        saved_frame = False

        while cap.isOpened():
            ret, frame = cap.read()
            if not ret:
                break

            frame_count += 1
            outputs = self.predictor(frame)

            instances = outputs["instances"].to("cpu")
            pred_classes = instances.pred_classes.numpy()
            pred_boxes = instances.pred_boxes.tensor.numpy()

            for i, cls in enumerate(pred_classes):
                if cls == 0:  # COCO class "person"
                    xyxy = pred_boxes[i].astype(int)
                    cv2.rectangle(frame, (xyxy[0], xyxy[1]), (xyxy[2], xyxy[3]), (0, 255, 0), 2)
                    frame_path = os.path.join(output_folder, f"{formatted_date}.jpg")
                    cv2.imwrite(frame_path, frame)
                    saved_frame = True
                    break

            if saved_frame:
                break

        cap.release()

        if not saved_frame:
            print("No person detected in the video.")
            return "No person detected in the video."
        else:
            return f"Processed {frame_count} frames before detection."

# %%
a = 'A man, a plan, a canal, Panama'
a[::-1]
# Out:
# 'amanaP ,lanac a ,nalp a ,nam A'

# %%
s = ""
for i in a:
    s = i+s

# %%
s = "Hello, World!"

a = ['a','e','i','o','u','A','E','I','O','U']
c = 0
for i in range(len(s)):
    if s[i] in a:
        c+=1
print(c)
# Out:
# 3

# %%
def f(n):
    if n ==0:
        return(1)

    else:
        return n*f(n-1)

# %%
print(f(5))
# Out:
# 120

# %%
def prime_num(n):
    if n<2:
        return False
    else:
        for i in range(2,int(n**0.5)+1):
            if n%i ==0:
                return False

# %%
a = [12,24,35,70,88,120,155]

# %%
for i in range(len(a)):
    if i%2!=0:
        print(a[i])
# Out:
# 24
# 70
# 120

# %%
# Out:
# [1]

# %%
input_sentence = "This is a sample sentence."
m = (input_sentence.split(" "))
len(m)
# Out:
# 5

# %%
def decimal_to_binary(decimal):
    binary = ""
    quotient = decimal
    print(quotient)
    while quotient > 0:
        remainder = quotient % 2
        print(remainder)
        binary = str(remainder) + binary
        print(binary)
        quotient //= 2
        print(quotient)
    return binary

decimal_to_binary(10)
# Out:
# 10
# 0
# 0
# 5
# 1
# 10
# 2
# 0
# 010
# 1
# 1
# 1010
# 0
# '1010'

# %%
numbers = [10, 30, 20, 40, 50]
l = sorted(numbers)[-2]
print(l)
# Out:
# 40

# %%
number = 16

# %%
def is_power_of_two(number):
    if number <= 0:
        return False  # Numbers less than or equal to 0 are not powers of two
    while number > 1:
        if number % 2 != 0:
            return False  # If the number is not divisible by 2, it's not a power of two
        number //= 2
    return True

# Example usage
number = 16
if is_power_of_two(number):
    print(number, "is a power of two.")
else:
    print(number, "is not a power of two.")
# Out:
# 16 is a power of two.

# %%
# from icrawler.builtin import BingImageCrawler

# crawler = BingImageCrawler(storage={'root_dir': '/home/hepl/Desktop/New_Folder/Keerthanaa/Keerthii/MAR_2025/VA_research_task/NCS/NC_00/code/incharge_images'})
# crawler.crawl(keyword='Dr. A.P.J. Abdul Kalam', max_num=20)

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense
from tensorflow.keras.optimizers import Adam

# Data
train_path = '/home/hepl/Desktop/New_Folder/Keerthanaa/Keerthii/MAR_2025/VA_research_task/NCS/NC_00/code/incharge_images/'

datagen = ImageDataGenerator(rescale=1./255, validation_split=0.2)

train_data = datagen.flow_from_directory(train_path, target_size=(128, 128), batch_size=16, class_mode='binary', subset='training')
val_data = datagen.flow_from_directory(train_path, target_size=(128, 128), batch_size=16, class_mode='binary', subset='validation')

# Model
model = Sequential([
    Conv2D(32, (3,3), activation='relu', input_shape=(128,128,3)),
    MaxPooling2D(2,2),
    Conv2D(64, (3,3), activation='relu'),
    MaxPooling2D(2,2),
    Flatten(),
    Dense(64, activation='relu'),
    Dense(1, activation='sigmoid')
])

model.compile(optimizer=Adam(), loss='binary_crossentropy', metrics=['accuracy'])
model.fit(train_data, validation_data=val_data, epochs=10)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 from tensorflow.keras.preprocessing.image import ImageDataGenerator
#       2 from tensorflow.keras.models import Sequential
#       3 from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense
#
# ModuleNotFoundError: No module named 'tensorflow'

# %%
from ultralytics.utils.plotting import Annotator

# %%
import face_recognition
import cv2
import os
# from google.colab.patches import cv2_imshow
import os
# os.environ["CUDA_VISIBLE_DEVICES"] = "-1"

# Step 1: Load reference images
known_encodings = []
known_names = []

reference_path = "dataset/APJ"
for filename in os.listdir(reference_path):
    if filename.lower().endswith(('.jpg', '.jpeg', '.png')):
        image_path = os.path.join(reference_path, filename)
        image = face_recognition.load_image_file(image_path)
        encodings = face_recognition.face_encodings(image)
        if encodings:
            known_encodings.append(encodings[0])
            known_names.append("Kalam")

# Step 2: Load test image
test_image_path = "/content/Image_5.jpg"
frame = cv2.imread(test_image_path)
rgb_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)  # Ensure correct color format

# Step 3: Detect faces
face_locations = face_recognition.face_locations(rgb_frame)

# Safeguard: Make sure face locations are found
if face_locations:
    face_encodings = face_recognition.face_encodings(rgb_frame, face_locations)

    # Step 4: Compare and annotate
    for face_encoding, face_location in zip(face_encodings, face_locations):
        matches = face_recognition.compare_faces(known_encodings, face_encoding)
        name = "Unknown"

        if True in matches:
            name = "Kalam"

        top, right, bottom, left = face_location
        cv2.rectangle(frame, (left, top), (right, bottom), (0, 255, 0), 2)
        cv2.putText(frame, name, (left, top - 10), cv2.FONT_HERSHEY_SIMPLEX,
                    0.9, (0, 255, 0), 2)
else:
    print("No faces detected in the test image.")

# Step 5: Show the result
cv2.imshow('g',frame)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 import face_recognition
#       2 import cv2
#       3 import os
#
# ModuleNotFoundError: No module named 'face_recognition'
